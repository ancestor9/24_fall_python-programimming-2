# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/24_fall_python-programimming-2/blob/main/Capstone_Design_01_rocket_launch_with_mage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pipeline = Blocks**
#
# - **Block 1. Create a Temporary Folder (create_tmp_folder) & Download Launches Data(download_launches):**
# > This step will ensure that the necessary directories exist before proceeding with downloading and processing data. In this step, we'll fetch data from an external API and save it to a local JSON file.
# - **Block 2. Get Pictures (get_pictures):**
# > This part involves reading the downloaded JSON, extracting image URLs, and downloading these images to a specified directory.
# - **Block 3. Notify (notify):**
# > Finally, a simple notification step that counts the images downloaded and outputs a message.
#
#
# <img src ='https://t4.ftcdn.net/jpg/05/39/88/87/360_F_539888762_pU6WAEuRv8sWB3Paqae7J0lHdPprEdoJ.jpg'>

# %% [markdown]
# ## **Block 1: Create a Temporary Folder & Download Launches Data**
# > ### **@data_loader**

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
cur_dir = os.getcwd()
cur_dir
# Out:
# '/content'

# %%
print(cur_dir)
print(f"{cur_dir}/rocket")
# Out:
# /content
# /content/rocket

# %%
#os.makedirs(f"rocket1/rocke2/rocke3", exist_ok=True)
os.makedirs('rocket', exist_ok = True)

# %%
import requests
url = 'https://ll.thespacedevs.com/2.0.0/launch/upcoming'
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
print(type(response.content))
# Out:
# <class 'bytes'>

# %%
print(response.content) # binary file
# Out:
# b'{"count":326,"next":"https://ll.thespacedevs.com/2.0.0/launch/upcoming/?limit=10&offset=10","previous":null,"results":[{"id":"acc6cddc-0c34-4d64-9cbe-1d8fa1833544","url":"https://ll.thespacedevs.com/2.0.0/launch/acc6cddc-0c34-4d64-9cbe-1d8fa1833544/","launch_library_id":null,"slug":"long-march-2d-unknown-payload","name":"Long March 2D | Unknown Payload","status":{"id":1,"name":"Go"},"net":"2024-09-20T04:10:00Z","window_end":"2024-09-20T04:26:00Z","window_start":"2024-09-20T04:01:00Z","inhold":false,"tbdtime":true,"tbddate":false,"probability":null,"holdreason":"","failreason":"","hashtag":null,"launch_service_provider":{"id":88,"url":"https://ll.thespacedevs.com/2.0.0/agencies/88/","name":"China Aerospace Science and Technology Corporation","type":"Government"},"rocket":{"id":8355,"configuration":{"id":17,"launch_library_id":73,"url":"https://ll.thespacedevs.com/2.0.0/config/launcher/17/","name":"Long March 2D","family":"Long March","full_name":"Long March 2D","variant":"2D"}},"mission":{"id":6936,"launch_library_id":null,"name":"Unknown Payload","description":"Details TBD.","launch_designator":null,"type":"Unknown","orbit":{"id":25,"name":"Unknown","abbrev":"N/A"}},"pad":{"id":25,"url":"https://ll.thespacedevs.com/2.0.0/pad/25/","agency_id":null,"name":"Launch Complex 9","info_url":null,"wiki_url":null,"map_url":"https://www.google.com/maps?q=38.863128,111.589567","latitude":"38.863128","longitude":"111.589567","location":{"id":19,"url":"https://ll.thespacedevs.com/2.0.0/location/19/","name":"Taiyuan Satellite Launch Center, People\'s Republic of China","country_code":"CHN","map_image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/location_19_20200803142421.jpg","total_launch_count":131,"total_landing_count":0},"map_image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/pad_25_20200803143501.jpg","total_launch_count":73},"webcast_live":false,"image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/long2520march25202d_image_20190222031211.jpeg","infographic":null,"program":[]},{"id":"f9c16ec7-7592-4ec0-ab1e-f753b96d23fb","url":"https://ll.thespacedevs.com/2.0.0/launch/f9c16ec7-7592-4ec0-ab1e-f753b96d23fb/","launch_library_id":null,"slug":"kuaizhou-1a-unknown-payload","name":"Kuaizhou-1A | Unknown Payload","status":{"id":1,"name":"Go"},"net":"2024-09-20T09:45:00Z","window_end":"2024-09-20T09:58:00Z","window_start":"2024-09-20T09:33:00Z","inhold":false,"tbdtime":true,"tbddate":false,"probability":null,"holdreason":"","failreason":"","hashtag":null,"launch_service_provider":{"id":194,"url":"https://ll.thespacedevs.com/2.0.0/agencies/194/","name":"ExPace","type":"Commercial"},"rocket":{"id":8356,"configuration":{"id":135,"launch_library_id":155,"url":"https://ll.thespacedevs.com/2.0.0/config/launcher/135/","name":"Kuaizhou","family":"Kuaizhou","full_name":"Kuaizhou-1A","variant":"1A"}},"mission":{"id":6937,"launch_library_id":null,"name":"Unknown Payload","description":"Details TBD.","launch_designator":null,"type":"Unknown","orbit":{"id":25,"name":"Unknown","abbrev":"N/A"}},"pad":{"id":157,"url":"https://ll.thespacedevs.com/2.0.0/pad/157/","agency_id":null,"name":"Mobile Launcher Pad","info_url":null,"wiki_url":"https://en.wikipedia.org/wiki/Xichang_Satellite_Launch_Center","map_url":"https://www.google.com/maps?q=28.242774,102.032944","latitude":"28.242774","longitude":"102.032944","location":{"id":16,"url":"https://ll.thespacedevs.com/2.0.0/location/16/","name":"Xichang Satellite Launch Center, People\'s Republic of China","country_code":"CHN","map_image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/location_16_20200803142513.jpg","total_launch_count":211,"total_landing_count":0},"map_image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/pad_157_20200803143359.jpg","total_launch_count":5},"webcast_live":false,"image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/kuaizhou_image_20191027 ...

# %%
print(response.text)   # text file
# Out:
# {"count":326,"next":"https://ll.thespacedevs.com/2.0.0/launch/upcoming/?limit=10&offset=10","previous":null,"results":[{"id":"acc6cddc-0c34-4d64-9cbe-1d8fa1833544","url":"https://ll.thespacedevs.com/2.0.0/launch/acc6cddc-0c34-4d64-9cbe-1d8fa1833544/","launch_library_id":null,"slug":"long-march-2d-unknown-payload","name":"Long March 2D | Unknown Payload","status":{"id":1,"name":"Go"},"net":"2024-09-20T04:10:00Z","window_end":"2024-09-20T04:26:00Z","window_start":"2024-09-20T04:01:00Z","inhold":false,"tbdtime":true,"tbddate":false,"probability":null,"holdreason":"","failreason":"","hashtag":null,"launch_service_provider":{"id":88,"url":"https://ll.thespacedevs.com/2.0.0/agencies/88/","name":"China Aerospace Science and Technology Corporation","type":"Government"},"rocket":{"id":8355,"configuration":{"id":17,"launch_library_id":73,"url":"https://ll.thespacedevs.com/2.0.0/config/launcher/17/","name":"Long March 2D","family":"Long March","full_name":"Long March 2D","variant":"2D"}},"mission":{"id":6936,"launch_library_id":null,"name":"Unknown Payload","description":"Details TBD.","launch_designator":null,"type":"Unknown","orbit":{"id":25,"name":"Unknown","abbrev":"N/A"}},"pad":{"id":25,"url":"https://ll.thespacedevs.com/2.0.0/pad/25/","agency_id":null,"name":"Launch Complex 9","info_url":null,"wiki_url":null,"map_url":"https://www.google.com/maps?q=38.863128,111.589567","latitude":"38.863128","longitude":"111.589567","location":{"id":19,"url":"https://ll.thespacedevs.com/2.0.0/location/19/","name":"Taiyuan Satellite Launch Center, People's Republic of China","country_code":"CHN","map_image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/location_19_20200803142421.jpg","total_launch_count":131,"total_landing_count":0},"map_image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/pad_25_20200803143501.jpg","total_launch_count":73},"webcast_live":false,"image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/long2520march25202d_image_20190222031211.jpeg","infographic":null,"program":[]},{"id":"f9c16ec7-7592-4ec0-ab1e-f753b96d23fb","url":"https://ll.thespacedevs.com/2.0.0/launch/f9c16ec7-7592-4ec0-ab1e-f753b96d23fb/","launch_library_id":null,"slug":"kuaizhou-1a-unknown-payload","name":"Kuaizhou-1A | Unknown Payload","status":{"id":1,"name":"Go"},"net":"2024-09-20T09:45:00Z","window_end":"2024-09-20T09:58:00Z","window_start":"2024-09-20T09:33:00Z","inhold":false,"tbdtime":true,"tbddate":false,"probability":null,"holdreason":"","failreason":"","hashtag":null,"launch_service_provider":{"id":194,"url":"https://ll.thespacedevs.com/2.0.0/agencies/194/","name":"ExPace","type":"Commercial"},"rocket":{"id":8356,"configuration":{"id":135,"launch_library_id":155,"url":"https://ll.thespacedevs.com/2.0.0/config/launcher/135/","name":"Kuaizhou","family":"Kuaizhou","full_name":"Kuaizhou-1A","variant":"1A"}},"mission":{"id":6937,"launch_library_id":null,"name":"Unknown Payload","description":"Details TBD.","launch_designator":null,"type":"Unknown","orbit":{"id":25,"name":"Unknown","abbrev":"N/A"}},"pad":{"id":157,"url":"https://ll.thespacedevs.com/2.0.0/pad/157/","agency_id":null,"name":"Mobile Launcher Pad","info_url":null,"wiki_url":"https://en.wikipedia.org/wiki/Xichang_Satellite_Launch_Center","map_url":"https://www.google.com/maps?q=28.242774,102.032944","latitude":"28.242774","longitude":"102.032944","location":{"id":16,"url":"https://ll.thespacedevs.com/2.0.0/location/16/","name":"Xichang Satellite Launch Center, People's Republic of China","country_code":"CHN","map_image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/location_16_20200803142513.jpg","total_launch_count":211,"total_landing_count":0},"map_image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/pad_157_20200803143359.jpg","total_launch_count":5},"webcast_live":false,"image":"https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/kuaizhou_image_201910270944 ...

# %%
# 바이너리 I/O
with open(f"rocket/launches.json", "wb") as f:
    f.write(response.content)

# %%
# 텍스트 I/O
with open(f"rocket/launches.json", "w") as f:
    f.write(response.text)

# %%
import requests

def download_launches():
    cur_dir = '/content'
    url = 'https://ll.thespacedevs.com/2.0.0/launch/upcoming'
    os.makedirs(f"rocket", exist_ok=True)

    print(f"wahrer r u? : {cur_dir}/rocket")

    response = requests.get(url)

    with open(f"rocket/launches.json", "wb") as f:
        f.write(response.content)

    data = response.json()

    return pd.DataFrame(data)

# %%
import pandas as pd
download_launches()
# Out:
# wahrer r u? : /content/rocket
#    count                                               next previous  \
# 0    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
# 1    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
# 2    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
# 3    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
# 4    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
# 5    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
# 6    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
# 7    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
# 8    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
# 9    326  https://ll.thespacedevs.com/2.0.0/launch/upcom...     None
#
#                                              results
# 0  {'id': 'acc6cddc-0c34-4d64-9cbe-1d8fa1833544',...
# 1  {'id': 'f9c16ec7-7592-4ec0-ab1e-f753b96d23fb',...
# 2  {'id': 'facd46c6-5197-4c27-939a-2b6b3f08d39d',...
# 3  {'id': '1fae2781-87aa-4a0a-a023-af689a9c5d79',...
# 4  {'id': '0102940a-4a60-4686-b34d-ced3fed6c595',...
# 5  {'id': '2de44368-01af-448f-b0fb-d7aacdd86c0e',...
# 6  {'id': '525ed290-dd97-4187-9118-d71f0b8285be',...
# 7  {'id': 'c5c59136-3554-45e7-9583-9d5611bed7b4',...
# 8  {'id': 'f97e9181-c9cd-4e68-9c19-68ddb5e80763',...
# 9  {'id': 'ca78b818-63d5-4280-853e-478db107b022',...

# %% [markdown]
# ## **Block 2: Get Pictures**
# - This block will be a direct translation of the _get_pictures function from your Airflow script.
# > ### **@data_transformer**

# %%
import json
os.makedirs(f"images", exist_ok=True)
with open("./rocket/launches.json") as f:
    launches = json.load(f)

launches.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
print(type(launches["results"]))
# Out:
# <class 'list'>

# %%
launches["results"][0].keys()
# Out:
# dict_keys(['id', 'url', 'launch_library_id', 'slug', 'name', 'status', 'net', 'window_end', 'window_start', 'inhold', 'tbdtime', 'tbddate', 'probability', 'holdreason', 'failreason', 'hashtag', 'launch_service_provider', 'rocket', 'mission', 'pad', 'webcast_live', 'image', 'infographic', 'program'])

# %%
len(launches["results"])
# Out:
# 10

# %%
print(type(launches["results"][0]))
# Out:
# <class 'dict'>

# %%
launches["results"][0]['image']
# Out:
# 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/long2520march25202d_image_20190222031211.jpeg'

# %%
for launch in launches["results"]:
    print(launch["image"])
# Out:
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/long2520march25202d_image_20190222031211.jpeg
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/kuaizhou_image_20191027094423.jpeg
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20221009234147.png
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/electron_image_20190705175640.jpeg
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20220301072106.jpeg
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/ceres-1_image_20230722081939.jpeg
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20240101100955.jpeg
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soyuz_2.1b_image_20230802085331.jpg
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20221009234147.png
# https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/h-iia_202_lifto_image_20240325123250.jpg

# %%
import json
import requests
import requests.exceptions as requests_exceptions
import os

def get_pictures(*args, **kwargs):
    os.makedirs(f"image", exist_ok=True)
    with open("./rocket/launches.json") as f:
        launches = json.load(f)

    image_urls = [launch["image"] for launch in launches["results"]]
    print(image_urls)

    for image_url in image_urls:
        try:
            response = requests.get(image_url)
            image_filename = image_url.split("/")[-1]
            target_file = f"./image/{image_filename}"

            with open(target_file, "wb") as f:
                f.write(response.content)

            print(f"Downloaded {image_url} to {target_file}")

        except requests_exceptions.MissingSchema:
            print(f"{image_url} appears to be an invalid URL.")

        except requests_exceptions.ConnectionError:
            print(f"Could not connect to {image_url}.")

# %%
get_pictures()
# Out:
# ['https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/long2520march25202d_image_20190222031211.jpeg', 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/kuaizhou_image_20191027094423.jpeg', 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20221009234147.png', 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/electron_image_20190705175640.jpeg', 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20220301072106.jpeg', 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/ceres-1_image_20230722081939.jpeg', 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20240101100955.jpeg', 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soyuz_2.1b_image_20230802085331.jpg', 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20221009234147.png', 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/h-iia_202_lifto_image_20240325123250.jpg']
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/long2520march25202d_image_20190222031211.jpeg to ./image/long2520march25202d_image_20190222031211.jpeg
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/kuaizhou_image_20191027094423.jpeg to ./image/kuaizhou_image_20191027094423.jpeg
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20221009234147.png to ./image/falcon2520925_image_20221009234147.png
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/electron_image_20190705175640.jpeg to ./image/electron_image_20190705175640.jpeg
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20220301072106.jpeg to ./image/falcon2520925_image_20220301072106.jpeg
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/ceres-1_image_20230722081939.jpeg to ./image/ceres-1_image_20230722081939.jpeg
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20240101100955.jpeg to ./image/falcon2520925_image_20240101100955.jpeg
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soyuz_2.1b_image_20230802085331.jpg to ./image/soyuz_2.1b_image_20230802085331.jpg
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/falcon2520925_image_20221009234147.png to ./image/falcon2520925_image_20221009234147.png
# Downloaded https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/h-iia_202_lifto_image_20240325123250.jpg to ./image/h-iia_202_lifto_image_20240325123250.jpg

# %% [markdown]
# ## **@data_exporter**

# %%
len(os.listdir("./images/"))
# Out:
# 0

# %%
import os

def notify(*args, **kwargs):
    images_count = len(os.listdir("./images/"))
    if images_count > 0:
        print(f"There are now {images_count} images.")
    else :
        print("No images downloaded")

# %%
notify()
# Out:
# No images downloaded

# %% [markdown]
# ### **이미지 시각화하기**
# - chat GPT 에게 "이미지 파일을 불러와서 시각화하는 코드 한 줄에 5장씩" prompt로 문의

# %%
import glob
glob.glob('./image/*')
# Out:
# ['./image/falcon2520925_image_20221009234147.png',
#  './image/soyuz_2.1b_image_20230802085331.jpg',
#  './image/h-iia_202_lifto_image_20240325123250.jpg',
#  './image/falcon2520925_image_20220301072106.jpeg',
#  './image/ceres-1_image_20230722081939.jpeg',
#  './image/kuaizhou_image_20191027094423.jpeg',
#  './image/falcon2520925_image_20240101100955.jpeg',
#  './image/long2520march25202d_image_20190222031211.jpeg',
#  './image/electron_image_20190705175640.jpeg']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_files = glob.glob('./image/*')

plt.figure(figsize=(15, 7))
for i, file in enumerate(image_files):
    plt.subplot(3, 4, i+1)  # 3행 4열의 그림 위치를 지정
    img = mpimg.imread(file)
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %% [markdown]
# # END

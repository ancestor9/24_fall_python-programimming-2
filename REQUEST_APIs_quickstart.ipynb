# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/24_fall_python-programimming-2/blob/main/REQUEST_APIs_quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Requests_Quickstart**
# > - https://docs.python-requests.org/en/latest/user/quickstart/

# %% [markdown]
# >> ### **Make a Request**

# %%
import requests

# %%
# HTTP GET 요청은 웹 서버에서 정보를 검색하는 데 사용됩니다. 이 요청은 데이터를 서버로 보내지 않고,
# 서버에서 제공하는 정보나 리소스를 가져옵니다.
r = requests.get('https://api.github.com/events')
r
# Out:
# <Response [200]>

# %%
# HTTP POST 요청을 'https://httpbin.org/post URL로 보냅니다. '.
# 이 요청으로 보내는 데이터는 {'key': 'value'} 사전 형식입니다. 이 데이터는 요청 본문의 일부로 서버에 전송됩니다.

r = requests.post('https://httpbin.org/post', data={'key': 'value'})
r
# Out:
# <Response [200]>

# %%
# HTTP PUT 요청을 'https://httpbin.org/put URL로 보냅니다. '.
# POST 요청과 마찬가지로 요청 본문에 이 요청과 함께 {'key': 'value'} 데이터도 전송합니다.
# PUT 요청은 일반적으로 서버의 기존 리소스를 업데이트하는 데 사용됩니다. POST와 유사하지만 기존 데이터를 업데이트하는 데 자주 사용됩니다.
r = requests.put('https://httpbin.org/put', data={'key': 'value'})
r
# Out:
# <Response [200]>

# %%
r = requests.delete('https://httpbin.org/delete')
r
# Out:
# <Response [200]>

# %%
# HTTP HEAD 방법은 리소스의 본문 내용을 실제로 요청하지 않고 웹 서버에서 리소스의 헤더를 요청하는 데 사용됩니다.
# HTTP HEAD 요청을 보내면 서버는 콘텐츠 유형, 콘텐츠 길이, 다양한 메타데이터 등의 정보를 포함하여 리소스와 관련된 헤더로 응답하지만
# 리소스의 실제 콘텐츠를 보내지는 않습니다. 이는 리소스에 대한 메타데이터만 필요하고 전체 리소스를 다운로드하고 싶지 않을 때 유용합니다.
r = requests.head('https://httpbin.org/get')
r
# Out:
# <Response [200]>

# %%
r.headers
# Out:
# {'Date': 'Thu, 03 Oct 2024 12:53:31 GMT', 'Content-Type': 'application/json', 'Content-Length': '308', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
# HTTP OPTIONS 메서드는 서버에서 지원하는 HTTP 메서드 및 헤더 옵션을 조회하기 위해 사용됩니다.
# OPTIONS 요청을 보내면 서버는 해당 엔드포인트 또는 리소스에 대한 지원되는 HTTP 메서드 목록과 다른 헤더 옵션을 반환합니다.
# 이 메서드는 주로 CORS (Cross-Origin Resource Sharing)와 같은 웹 보안 및 권한 관련 설정을 확인하기 위해 사용됩니다.
r = requests.options('https://httpbin.org/get')
r
# Out:
# <Response [200]>

# %% [markdown]
# >> ### **Passing Parameters In URLs**

# %%
r = requests.get('https://httpbin.org/get')
print(r.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-66fe93d2-5c18b5897a8420011cd18dd7"
#   },
#   "origin": "34.173.227.208",
#   "url": "https://httpbin.org/get"
# }

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)
r
# Out:
# <Response [200]>

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %%
print(r.text)
# Out:
# {
#   "args": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-66fe93d7-07c77d7d54e2d27f0efba4e1"
#   },
#   "origin": "34.173.227.208",
#   "url": "https://httpbin.org/get?key1=value1&key2=value2"
# }

# %%
r = requests.get('https://httpbin.org/get')
r
# Out:
# <Response [200]>

# %%
print(r.url)
# Out:
# https://httpbin.org/get

# %%
print(r.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-66fe93e0-496bf1b4454edf6205402a6f"
#   },
#   "origin": "34.173.227.208",
#   "url": "https://httpbin.org/get"
# }

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}

r = requests.get('https://httpbin.org/get', params=payload)

print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %%
print(r.text)
# Out:
# {
#   "args": {
#     "key1": "value1",
#     "key2": [
#       "value2",
#       "value3"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-66fe93e4-7462f16f7c8f4ca615a3c578"
#   },
#   "origin": "34.173.227.208",
#   "url": "https://httpbin.org/get?key1=value1&key2=value2&key2=value3"
# }

# %% [markdown]
# >> ### **Response Content**

# %%
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"42509437768","type":"PushEvent","actor":{"id":161367810,"login":"aimme14","display_login":"aimme14","gravatar_id":"","url":"https://api.github.com/users/aimme14","avatar_url":"https://avatars.githubusercontent.com/u/161367810?"},"repo":{"id":867058423,"name":"aimme14/estudio-primer-parcial","url":"https://api.github.com/repos/aimme14/estudio-primer-parcial"},"payload":{"repository_id":867058423,"push_id":20536498670,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"ef0c13c38c0a1be7ac4dd43331cd401a29d6c692","before":"c015c1ee8f671a66b1f57824072ef8544a3460ad","commits":[{"sha":"ef0c13c38c0a1be7ac4dd43331cd401a29d6c692","author":{"email":"aylopezm@ufpso.edu.co","name":"aime"},"message":"estudio","distinct":true,"url":"https://api.github.com/repos/aimme14/estudio-primer-parcial/commits/ef0c13c38c0a1be7ac4dd43331cd401a29d6c692"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437745","type":"IssueCommentEvent","actor":{"id":178772239,"login":"suresh06-lv","display_login":"suresh06-lv","gravatar_id":"","url":"https://api.github.com/users/suresh06-lv","avatar_url":"https://avatars.githubusercontent.com/u/178772239?"},"repo":{"id":312372049,"name":"ni/grpc-labview","url":"https://api.github.com/repos/ni/grpc-labview"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/ni/grpc-labview/issues/374","repository_url":"https://api.github.com/repos/ni/grpc-labview","labels_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/labels{/name}","comments_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/comments","events_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/events","html_url":"https://github.com/ni/grpc-labview/issues/374","id":2472747684,"node_id":"I_kwDOEp5rUc6TYyKk","number":374,"title":"Error when connecting LabVIEW gRPC client to C# server","user":{"login":"suresh06-lv","id":178772239,"node_id":"U_kgDOCqfZDw","avatar_url":"https://avatars.githubusercontent.com/u/178772239?v=4","gravatar_id":"","url":"https://api.github.com/users/suresh06-lv","html_url":"https://github.com/suresh06-lv","followers_url":"https://api.github.com/users/suresh06-lv/followers","following_url":"https://api.github.com/users/suresh06-lv/following{/other_user}","gists_url":"https://api.github.com/users/suresh06-lv/gists{/gist_id}","starred_url":"https://api.github.com/users/suresh06-lv/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/suresh06-lv/subscriptions","organizations_url":"https://api.github.com/users/suresh06-lv/orgs","repos_url":"https://api.github.com/users/suresh06-lv/repos","events_url":"https://api.github.com/users/suresh06-lv/events{/privacy}","received_events_url":"https://api.github.com/users/suresh06-lv/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":7,"created_at":"2024-08-19T08:17:58Z","updated_at":"2024-10-03T12:49:08Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"body":"**Description**\\r\\nTimeout error when trying to connect LabVIEW gRPC client to C# gRPC Server.  \\r\\nEncountered this problem when attempting to use the LabVIEW client to simulate TestStand operations by connecting to a C# server.  This issue was first seen when trying to connect to the C# server provided in https://github.com/ni/grpc-teststand-api.  I discovered that the problem persists even with a basic C# greeter gRPC service.\\r\\n\\r\\n**Steps to Reproduce**\\r\\n1. Create a C# greeter service based on the tutorial from https://learn.microsoft.com/en-us/aspnet/core/tutorials/grpc/grpc-start?view=aspnetcore-8.0&tabs=visual-studio.\\r\\n2. Create a LabVIEW client using the proto file generated from step1.\\r\\n3. Build a sample gRPC client VI. \\r\\n4. Run the service.  \\r\\n5. Connect LabVIEW greeter client using the address shown in the terminal and Run VI.\\r\\n\\r\\n**Expected Result**\\r\\nGreeter response string  ...

# %%
print(r.text)
# Out:
# [{"id":"42509437768","type":"PushEvent","actor":{"id":161367810,"login":"aimme14","display_login":"aimme14","gravatar_id":"","url":"https://api.github.com/users/aimme14","avatar_url":"https://avatars.githubusercontent.com/u/161367810?"},"repo":{"id":867058423,"name":"aimme14/estudio-primer-parcial","url":"https://api.github.com/repos/aimme14/estudio-primer-parcial"},"payload":{"repository_id":867058423,"push_id":20536498670,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"ef0c13c38c0a1be7ac4dd43331cd401a29d6c692","before":"c015c1ee8f671a66b1f57824072ef8544a3460ad","commits":[{"sha":"ef0c13c38c0a1be7ac4dd43331cd401a29d6c692","author":{"email":"aylopezm@ufpso.edu.co","name":"aime"},"message":"estudio","distinct":true,"url":"https://api.github.com/repos/aimme14/estudio-primer-parcial/commits/ef0c13c38c0a1be7ac4dd43331cd401a29d6c692"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437745","type":"IssueCommentEvent","actor":{"id":178772239,"login":"suresh06-lv","display_login":"suresh06-lv","gravatar_id":"","url":"https://api.github.com/users/suresh06-lv","avatar_url":"https://avatars.githubusercontent.com/u/178772239?"},"repo":{"id":312372049,"name":"ni/grpc-labview","url":"https://api.github.com/repos/ni/grpc-labview"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/ni/grpc-labview/issues/374","repository_url":"https://api.github.com/repos/ni/grpc-labview","labels_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/labels{/name}","comments_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/comments","events_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/events","html_url":"https://github.com/ni/grpc-labview/issues/374","id":2472747684,"node_id":"I_kwDOEp5rUc6TYyKk","number":374,"title":"Error when connecting LabVIEW gRPC client to C# server","user":{"login":"suresh06-lv","id":178772239,"node_id":"U_kgDOCqfZDw","avatar_url":"https://avatars.githubusercontent.com/u/178772239?v=4","gravatar_id":"","url":"https://api.github.com/users/suresh06-lv","html_url":"https://github.com/suresh06-lv","followers_url":"https://api.github.com/users/suresh06-lv/followers","following_url":"https://api.github.com/users/suresh06-lv/following{/other_user}","gists_url":"https://api.github.com/users/suresh06-lv/gists{/gist_id}","starred_url":"https://api.github.com/users/suresh06-lv/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/suresh06-lv/subscriptions","organizations_url":"https://api.github.com/users/suresh06-lv/orgs","repos_url":"https://api.github.com/users/suresh06-lv/repos","events_url":"https://api.github.com/users/suresh06-lv/events{/privacy}","received_events_url":"https://api.github.com/users/suresh06-lv/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":7,"created_at":"2024-08-19T08:17:58Z","updated_at":"2024-10-03T12:49:08Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"body":"**Description**\r\nTimeout error when trying to connect LabVIEW gRPC client to C# gRPC Server.  \r\nEncountered this problem when attempting to use the LabVIEW client to simulate TestStand operations by connecting to a C# server.  This issue was first seen when trying to connect to the C# server provided in https://github.com/ni/grpc-teststand-api.  I discovered that the problem persists even with a basic C# greeter gRPC service.\r\n\r\n**Steps to Reproduce**\r\n1. Create a C# greeter service based on the tutorial from https://learn.microsoft.com/en-us/aspnet/core/tutorials/grpc/grpc-start?view=aspnetcore-8.0&tabs=visual-studio.\r\n2. Create a LabVIEW client using the proto file generated from step1.\r\n3. Build a sample gRPC client VI. \r\n4. Run the service.  \r\n5. Connect LabVIEW greeter client using the address shown in the terminal and Run VI.\r\n\r\n**Expected Result**\r\nGreeter response string concatenated with 'Hello' ...

# %% [markdown]
# >>> **"pretty-print"를 의미하는 pprint 모듈을 가져옵니다. 'pprint' 모듈은 데이터 구조(예: 사전 또는 JSON)를 보다 읽기 쉽고 형식화된 방식으로 인쇄하는 모듈**

# %%
import pprint

pprint.pprint(r.text)
# Out:
# ('[{"id":"42509437768","type":"PushEvent","actor":{"id":161367810,"login":"aimme14","display_login":"aimme14","gravatar_id":"","url":"https://api.github.com/users/aimme14","avatar_url":"https://avatars.githubusercontent.com/u/161367810?"},"repo":{"id":867058423,"name":"aimme14/estudio-primer-parcial","url":"https://api.github.com/repos/aimme14/estudio-primer-parcial"},"payload":{"repository_id":867058423,"push_id":20536498670,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"ef0c13c38c0a1be7ac4dd43331cd401a29d6c692","before":"c015c1ee8f671a66b1f57824072ef8544a3460ad","commits":[{"sha":"ef0c13c38c0a1be7ac4dd43331cd401a29d6c692","author":{"email":"aylopezm@ufpso.edu.co","name":"aime"},"message":"estudio","distinct":true,"url":"https://api.github.com/repos/aimme14/estudio-primer-parcial/commits/ef0c13c38c0a1be7ac4dd43331cd401a29d6c692"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437745","type":"IssueCommentEvent","actor":{"id":178772239,"login":"suresh06-lv","display_login":"suresh06-lv","gravatar_id":"","url":"https://api.github.com/users/suresh06-lv","avatar_url":"https://avatars.githubusercontent.com/u/178772239?"},"repo":{"id":312372049,"name":"ni/grpc-labview","url":"https://api.github.com/repos/ni/grpc-labview"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/ni/grpc-labview/issues/374","repository_url":"https://api.github.com/repos/ni/grpc-labview","labels_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/labels{/name}","comments_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/comments","events_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/events","html_url":"https://github.com/ni/grpc-labview/issues/374","id":2472747684,"node_id":"I_kwDOEp5rUc6TYyKk","number":374,"title":"Error '
#  'when connecting LabVIEW gRPC client to C# '
#  'server","user":{"login":"suresh06-lv","id":178772239,"node_id":"U_kgDOCqfZDw","avatar_url":"https://avatars.githubusercontent.com/u/178772239?v=4","gravatar_id":"","url":"https://api.github.com/users/suresh06-lv","html_url":"https://github.com/suresh06-lv","followers_url":"https://api.github.com/users/suresh06-lv/followers","following_url":"https://api.github.com/users/suresh06-lv/following{/other_user}","gists_url":"https://api.github.com/users/suresh06-lv/gists{/gist_id}","starred_url":"https://api.github.com/users/suresh06-lv/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/suresh06-lv/subscriptions","organizations_url":"https://api.github.com/users/suresh06-lv/orgs","repos_url":"https://api.github.com/users/suresh06-lv/repos","events_url":"https://api.github.com/users/suresh06-lv/events{/privacy}","received_events_url":"https://api.github.com/users/suresh06-lv/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":7,"created_at":"2024-08-19T08:17:58Z","updated_at":"2024-10-03T12:49:08Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"body":"**Description**\\r\\nTimeout '
#  'error when trying to connect LabVIEW gRPC client to C# gRPC Server.  '
#  '\\r\\nEncountered this problem when attempting to use the LabVIEW client to '
#  'simulate TestStand operations by connecting to a C# server.  This issue was '
#  'first seen when trying to connect to the C# server provided in '
#  'https://github.com/ni/grpc-teststand-api.  I discovered that the problem '
#  'persists even with a basic C# greeter gRPC service.\\r\\n\\r\\n**Steps to '
#  'Reproduce**\\r\\n1. Create a C# greeter service based on the tutorial from '
#  'https://learn.microsoft.com/en-us/aspnet/core/tutorials/grpc/grpc-start?view=aspnetcore-8.0&tabs=visual-studio.\\r\\n2. '
#  'Create a LabVIEW client using the proto file generated from step1.\\r\\n3. '
#  'Build a sample gRPC client VI. \\r\\n4. Run the service.  \\r\\n5. Connect '
#  'LabVIEW greeter client using the address shown in the terminal and Run '
#  'VI.\\r\\n\\r\\n**Expected Result**\\r\\nGreeter response string concatenated '
#  'with \'Hello\' as prefix to client message input.\\r\\n\\"Hello \\" + Client '
#  'Message\\r\\n\\r\\n**Actual '
#  'Result**\\r\\n![image](https://github.com/user-attachments/assets/677d5a1c-ec8a-4606-9914-be0c1ebf5aac)\\r\\n\\r\\n**Version**\\r\\nLabVIEW '
#  '- 2023 '
#  'Q3\\r\\n\\r\\n**Images**\\r\\n![image](https://github.com/user-attachments/assets/2546c951-08b0-4faf-808b-2abe5c9b3523)\\r\\n\\r\\n\\r\\nAB#2832543","reactions":{"url":"https://api.github.com/repos/ni/grpc-labview/issues/374/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"timeline_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/timeline","performed_via_github_app":null,"state_reason":null},"comment":{"url":"https://api.github.com/repos/ni/grpc-labview/issues/comments/2391338408","html_url":"https://github.com/ni/grpc-labview/issues/374#issuecomment-2391338408","issue_url":"https://api.github.com/repos/ni/grpc-labview/issues/374","id":2391338408,"node_id":"IC_kwDOEp5rUc6OiO2o","user":{"login":"suresh06-lv","id":178772239,"node_id":"U_kgDOCqfZDw","avatar_url":"https://avatars.githubusercontent.com/u/178772239?v=4","gravatar_id":"","url":"https://api.github.com/users/suresh06-lv","html_url":"https://github.com/suresh06-lv","followers_url":"https://api.github.com/users/suresh06-lv/followers","following_url":"https://api.github.com/users/suresh06-lv/following{/other_user}","gists_url":"https://api.github.com/users/suresh06-lv/gists{/gist_id}","starred_url":"https://api.github.com/users/suresh06-lv/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/suresh06-lv/subscriptions","organizations_url":"https://api.github.com/users/suresh06-lv/orgs","repos_url":"https://api.github.com/users/suresh06-lv/repos","events_url":"https://api.github.com/users/suresh06-lv/events{/privacy}","received_events_url":"https://api.github.com/users/suresh06-lv/received_events","type":"User","site_admin":false},"created_at":"2024-10-03T12:49:06Z","updated_at":"2024-10-03T12:49:06Z","author_association":"NONE","body":"Hi '
#  'Jason, Thanks for the reply.  We were able to connect the LV client to the '
#  'C# GRPC server for a sample greeter service.  It works fine and the message '
#  'were passed as expected.  \\r\\nMay I know whether you tried connecting to '
#  'the GRPC server given at '
#  '[grpc-teststand-api](https://github.com/ni/grpc-teststand-api).  We also '
#  'tried this case by providing the certificate files to the client and still '
#  'got no luck.  All these tests were done by disabling the firewalls.  '
#  '","reactions":{"url":"https://api.github.com/repos/ni/grpc-labview/issues/comments/2391338408/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"performed_via_github_app":null}},"public":true,"created_at":"2024-10-03T12:49:08Z","org":{"id":5598284,"login":"ni","gravatar_id":"","url":"https://api.github.com/orgs/ni","avatar_url":"https://avatars.githubusercontent.com/u/5598284?"}},{"id":"42509437723","type":"PushEvent","actor":{"id":29139614,"login":"renovate[bot]","display_login":"renovate","gravatar_id":"","url":"https://api.github.com/users/renovate[bot]","avatar_url":"https://avatars.githubusercontent.com/u/29139614?"},"repo":{"id":340385345,"name":"DFE-Digital/prepare-academy-conversions","url":"https://api.github.com/repos/DFE-Digital/prepare-academy-conversions"},"payload":{"repository_id":340385345,"push_id":20536498633,"size":8,"distinct_size":1,"ref":"refs/heads/renovate/github.com-dfe-digital-terraform-azurerm-key-vault-tfvars-0.x","head":"dddf95f9324652416706a60b96bb45a17b94060a","before":"c0e85951efdb7bb1d08ec8a00dd19578edd573ab","commits":[{"sha":"dd6f1a1e7e8d9338b21fb587f92db5bcc7db6f73","author":{"email":"Muhammad.SHAKIR@EDUCATION.GOV.UK","name":"SHAKIR, '
#  'Muhammad"},"message":"Updated cookie '
#  'banner","distinct":false,"url":"https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/dd6f1a1e7e8d9338b21fb587f92db5bcc7db6f73"},{"sha":"1a5cdbd156811953899f7b4de6bae4f2abb648f3","author":{"email":"Muhammad.SHAKIR@EDUCATION.GOV.UK","name":"SHAKIR, '
#  'Muhammad"},"message":"Updated '
#  'wording","distinct":false,"url":"https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/1a5cdbd156811953899f7b4de6bae4f2abb648f3"},{"sha":"068aa28e348f50626c6921e6762f11dda2655745","author":{"email":"Muhammad.SHAKIR@EDUCATION.GOV.UK","name":"SHAKIR, '
#  'Muhammad"},"message":"Merge branch \'main\' of '
#  'https://github.com/DFE-Digital/prepare-academy-conversions into '
#  'feature/182329-update-cookie-banner","distinct":false,"url":"https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/068aa28e348f50626c6921e6762f11dda2655745"},{"sha":"7859b8a5172942409b49306f65a30e4d41c934e1","author":{"email":"Muhammad.SHAKIR@EDUCATION.GOV.UK","name":"SHAKIR, '
#  'Muhammad"},"message":"Fixed tests and tidy up '
#  'code","distinct":false,"url":"https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/7859b8a5172942409b49306f65a30e4d41c934e1"},{"sha":"c20f8aead25eb2a4a10857a9bb4ce599f19cdb24","author":{"email":"Muhammad.SHAKIR@EDUCATION.GOV.UK","name":"SHAKIR, '
#  'Muhammad"},"message":"Fixed cypress '
#  'tests","distinct":false,"url":"https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/c20f8aead25eb2a4a10857a9bb4ce599f19cdb24"},{"sha":"141022026e180091196a22216ff31f4f0d6faeda","author":{"email":"Muhammad.SHAKIR@EDUCATION.GOV.UK","name":"SHAKIR, '
#  'Muhammad"},"message":"Fixed '
#  'tests","distinct":false,"url":"https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/141022026e180091196a22216ff31f4f0d6faeda"},{"sha":"465a0ead188ddc5a699444bcfb0beaf2291d4687","author":{"email":"muhammad.shakir@education.gov.uk","name":"mshakirdfe"},"message":"Merge '
#  'pull request #1199 from '
#  'DFE-Digital/feature/182329-update-cookie-banner\\n\\nFeature/182329 update '
#  'cookie '
#  'banner","distinct":false,"url":"https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/465a0ead188ddc5a699444bcfb0beaf2291d4687"},{"sha":"dddf95f9324652416706a60b96bb45a17b94060a","author":{"email":"29139614+renovate[bot]@users.noreply.github.com","name":"renovate[bot]"},"message":"Update '
#  'Terraform github.com/DFE-Digital/terraform-azurerm-key-vault-tfvars to '
#  'v0.5.0","distinct":true,"url":"https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/dddf95f9324652416706a60b96bb45a17b94060a"}]},"public":true,"created_at":"2024-10-03T12:49:08Z","org":{"id":30029772,"login":"DFE-Digital","gravatar_id":"","url":"https://api.github.com/orgs/DFE-Digital","avatar_url":"https://avatars.githubusercontent.com/u/30029772?"}},{"id":"42509437737","type":"CreateEvent","actor":{"id":146189912,"login":"Shivanand-hulikatti","display_login":"Shivanand-hulikatti","gravatar_id":"","url":"https://api.github.com/users/Shivanand-hulikatti","avatar_url":"https://avatars.githubusercontent.com/u/146189912?"},"repo":{"id":867094419,"name":"Shivanand-hulikatti/assignmentsWebDev","url":"https://api.github.com/repos/Shivanand-hulikatti/assignmentsWebDev"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437721","type":"PushEvent","actor":{"id":120438850,"login":"1992513","display_login":"1992513","gravatar_id":"","url":"https://api.github.com/users/1992513","avatar_url":"https://avatars.githubusercontent.com/u/120438850?"},"repo":{"id":583676719,"name":"1992513/djy","url":"https://api.github.com/repos/1992513/djy"},"payload":{"repository_id":583676719,"push_id":20536498638,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7383edd5acd7c16631e12174098076b0c5a63f6e","before":"1e93d5e1e3451f390fcc340cec047559ea4d9062","commits":[{"sha":"7383edd5acd7c16631e12174098076b0c5a63f6e","author":{"email":"120438850+1992513@users.noreply.github.com","name":"1992513"},"message":"2024-10-03","distinct":true,"url":"https://api.github.com/repos/1992513/djy/commits/7383edd5acd7c16631e12174098076b0c5a63f6e"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437720","type":"PullRequestReviewEvent","actor":{"id":1436948,"login":"radeusgd","display_login":"radeusgd","gravatar_id":"","url":"https://api.github.com/users/radeusgd","avatar_url":"https://avatars.githubusercontent.com/u/1436948?"},"repo":{"id":76672223,"name":"enso-org/enso","url":"https://api.github.com/repos/enso-org/enso"},"payload":{"action":"created","review":{"id":2345525742,"node_id":"PRR_kwDOBJHs386LzeHu","user":{"login":"radeusgd","id":1436948,"node_id":"MDQ6VXNlcjE0MzY5NDg=","avatar_url":"https://avatars.githubusercontent.com/u/1436948?v=4","gravatar_id":"","url":"https://api.github.com/users/radeusgd","html_url":"https://github.com/radeusgd","followers_url":"https://api.github.com/users/radeusgd/followers","following_url":"https://api.github.com/users/radeusgd/following{/other_user}","gists_url":"https://api.github.com/users/radeusgd/gists{/gist_id}","starred_url":"https://api.github.com/users/radeusgd/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/radeusgd/subscriptions","organizations_url":"https://api.github.com/users/radeusgd/orgs","repos_url":"https://api.github.com/users/radeusgd/repos","events_url":"https://api.github.com/users/radeusgd/events{/privacy}","received_events_url":"https://api.github.com/users/radeusgd/received_events","type":"User","site_admin":false},"body":null,"commit_id":"40d06cce37e659f8ca38bf4fb53bb1c125a23ad9","submitted_at":"2024-10-03T12:49:07Z","state":"commented","html_url":"https://github.com/enso-org/enso/pull/11163#pullrequestreview-2345525742","pull_request_url":"https://api.github.com/repos/enso-org/enso/pulls/11163","author_association":"MEMBER","_links":{"html":{"href":"https://github.com/enso-org/enso/pull/11163#pullrequestreview-2345525742"},"pull_request":{"href":"https://api.github.com/repos/enso-org/enso/pulls/11163"}}},"pull_request":{"url":"https://api.github.com/repos/enso-org/enso/pulls/11163","id":2090749538,"node_id":"PR_kwDOBJHs3858nk5i","html_url":"https://github.com/enso-org/enso/pull/11163","diff_url":"https://github.com/enso-org/enso/pull/11163.diff","patch_url":"https://github.com/enso-org/enso/pull/11163.patch","issue ...
#  'DB_Table feature '
#  'flags","user":{"login":"AdRiley","id":1720119,"node_id":"MDQ6VXNlcjE3MjAxMTk=","avatar_url":"https://avatars.githubusercontent.com/u/1720119?v=4","gravatar_id":"","url":"https://api.github.com/users/AdRiley","html_url":"https://github.com/AdRiley","followers_url":"https://api.github.com/users/AdRiley/followers","following_url":"https://api.github.com/users/AdRiley/following{/other_user}","gists_url":"https://api.github.com/users/AdRiley/gists{/gist_id}","starred_url":"https://api.github.com/users/AdRiley/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/AdRiley/subscriptions","organizations_url":"https://api.github.com/users/AdRiley/orgs","repos_url":"https://api.github.com/users/AdRiley/repos","events_url":"https://api.github.com/users/AdRiley/events{/privacy}","received_events_url":"https://api.github.com/users/AdRiley/received_events","type":"User","site_admin":false},"body":"### '
#  'Pull Request Description\\r\\n\\r\\nThis MR:\\r\\n- Introduces the framework '
#  'for feature flags for the In Database processing engine\\r\\n- For '
#  'everything other than SQLServer continues to have the same functionality and '
#  'tests that they did before\\r\\n- For SQLServer removes all In-DB '
#  'functionality other than being able to read a table and provides user '
#  'friendly errors messages for all other In database '
#  'funtionality\\r\\n\\r\\n### Important Notes\\r\\n\\r\\nNote the current set '
#  'of flags may not be the final set and some of the flagging out of tests is '
#  'probably coarser than it will eventually be. As we work through SQLServer '
#  'enbaling functionality and tests we will clean these up.\\r\\n\\r\\nNext '
#  'steps after this MR will be:\\r\\n- Decide on an order to approach adding '
#  'SQLServer features\\r\\n- Enable flags for SQLServer one at a time and make '
#  'the corresponding tests pass\\r\\n- I imagines we will need to extend the '
#  'flags to Column level functionality\\r\\n- Look if we can swap some of the '
#  'existing DB test flags for the new Feature flag system\\r\\n\\r\\n\\r\\n### '
#  'Checklist\\r\\n\\r\\nPlease ensure that the following checklist has been '
#  'satisfied before submitting the PR:\\r\\n\\r\\n- [ ] The documentation has '
#  'been updated, if necessary.\\r\\n- [ ] Screenshots/screencasts have been '
#  'attached, if there are any visual changes. For interactive or animated '
#  'visual changes, a screencast is preferred.\\r\\n- [ ] All code follows '
#  'the\\r\\n      '
#  '[Scala](https://github.com/enso-org/enso/blob/develop/docs/style-guide/scala.md),\\r\\n      '
#  '[Java](https://github.com/enso-org/enso/blob/develop/docs/style-guide/java.md),\\r\\n      '
#  '[TypeScript](https://github.com/enso-org/enso/blob/develop/docs/style-guide/typescript.md),\\r\\n      '
#  'and\\r\\n      '
#  '[Rust](https://github.com/enso-org/enso/blob/develop/docs/style-guide/rust.md)\\r\\n      '
#  'style guides. In case you are using a language not listed above, follow the '
#  '[Rust](https://github.com/enso-org/enso/blob/develop/docs/style-guide/rust.md) '
#  'style guide.\\r\\n- [ ] Unit tests have been written where '
#  'possible.\\r\\n","created_at":"2024-09-25T08:02:24Z","updated_at":"2024-10-03T12:49:07Z","closed_at":null,"merged_at":null,"merge_commit_sha":"9c7ea67bc90dae721aee05af3eaa4534deee2204","assignee":null,"assignees":[],"requested_reviewers":[{"login":"radeusgd","id":1436948,"node_id":"MDQ6VXNlcjE0MzY5NDg=","avatar_url":"https://avatars.githubusercontent.com/u/1436948?v=4","gravatar_id":"","url":"https://api.github.com/users/radeusgd","html_url":"https://github.com/radeusgd","followers_url":"https://api.github.com/users/radeusgd/followers","following_url":"https://api.github.com/users/radeusgd/following{/other_user}","gists_url":"https://api.github.com/users/radeusgd/gists{/gist_id}","starred_url":"https://api.github.com/users/radeusgd/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/radeusgd/subscriptions","organizations_url":"https://api.github.com/users/radeusgd/orgs","repos_url":"https://api.github.com/users/radeusgd/repos","events_url":"https://api.github.com/users/radeusgd/events{/privacy}","received_events_url":"https://api.github.com/users/radeusgd/received_events","type":"User","site_admin":false},{"login":"marthasharkey","id":170310417,"node_id":"U_kgDOCia7EQ","avatar_url":"https://avatars.githubusercontent.com/u/170310417?v=4","gravatar_id":"","url":"https://api.github.com/users/marthasharkey","html_url":"https://github.com/marthasharkey","followers_url":"https://api.github.com/users/marthasharkey/followers","following_url":"https://api.github.com/users/marthasharkey/following{/other_user}","gists_url":"https://api.github.com/users/marthasharkey/gists{/gist_id}","starred_url":"https://api.github.com/users/marthasharkey/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/marthasharkey/subscriptions","organizations_url":"https://api.github.com/users/marthasharkey/orgs","repos_url":"https://api.github.com/users/marthasharkey/repos","events_url":"https://api.github.com/users/marthasharkey/events{/privacy}","received_events_url":"https://api.github.com/users/marthasharkey/received_events","type":"User","site_admin":false}],"requested_teams":[],"labels":[{"id":4569515226,"node_id":"LA_kwDOBJHs388AAAABEF1E2g","url":"https://api.github.com/repos/enso-org/enso/labels/CI:%20No%20changelog%20needed","name":"CI: '
#  'No changelog needed","color":"ffffff","default":false,"description":"Do not '
#  'require a changelog entry for this '
#  'PR."}],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/enso-org/enso/pulls/11163/commits","review_comments_url":"https://api.github.com/repos/enso-org/enso/pulls/11163/comments","review_comment_url":"https://api.github.com/repos/enso-org/enso/pulls/comments{/number}","comments_url":"https://api.github.com/repos/enso-org/enso/issues/11163/comments","statuses_url":"https://api.github.com/repos/enso-org/enso/statuses/40d06cce37e659f8ca38bf4fb53bb1c125a23ad9","head":{"label":"enso-org:wip/adr/add-db-feature-flags","ref":"wip/adr/add-db-feature-flags","sha":"40d06cce37e659f8ca38bf4fb53bb1c125a23ad9","user":{"login":"enso-org","id":17415943,"node_id":"MDEyOk9yZ2FuaXphdGlvbjE3NDE1OTQz","avatar_url":"https://avatars.githubusercontent.com/u/17415943?v=4","gravatar_id":"","url":"https://api.github.com/users/enso-org","html_url":"https://github.com/enso-org","followers_url":"https://api.github.com/users/enso-org/followers","following_url":"https://api.github.com/users/enso-org/following{/other_user}","gists_url":"https://api.github.com/users/enso-org/gists{/gist_id}","starred_url":"https://api.github.com/users/enso-org/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/enso-org/subscriptions","organizations_url":"https://api.github.com/users/enso-org/orgs","repos_url":"https://api.github.com/users/enso-org/repos","events_url":"https://api.github.com/users/enso-org/events{/privacy}","received_events_url":"https://api.github.com/users/enso-org/received_events","type":"Organization","site_admin":false},"repo":{"id":76672223,"node_id":"MDEwOlJlcG9zaXRvcnk3NjY3MjIyMw==","name":"enso","full_name":"enso-org/enso","private":false}},"base":{"label":"enso-org:develop","ref":"develop","sha":"7f9cf7a916d82e1e5b16feb27c20969014964945","user":{"login":"enso-org","id":17415943,"node_id":"MDEyOk9yZ2FuaXphdGlvbjE3NDE1OTQz","avatar_url":"https://avatars.githubusercontent.com/u/17415943?v=4","gravatar_id":"","url":"https://api.github.com/users/enso-org","html_url":"https://github.com/enso-org","followers_url":"https://api.github.com/users/enso-org/followers","following_url":"https://api.github.com/users/enso-org/following{/other_user}","gists_url":"https://api.github.com/users/enso-org/gists{/gist_id}","starred_url":"https://api.github.com/users/enso-org/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/enso-org/subscriptions","organizations_url":"https://api.github.com/users/enso-org/orgs","repos_url":"https://api.github.com/users/enso-org/repos","events_url":"https://api.github.com/users/enso-org/events{/privacy}","received_events_url":"https://api.github.com/users/enso-org/received_events","type":"Organization","site_admin":false},"repo":{"id":76672223,"node_id":"MDEwOlJlcG9zaXRvcnk3NjY3MjIyMw==","name":"enso","full_name":"enso-org/enso","private":false}},"_links":{"self":{"href":"https://api.github.com/repos/enso-org/enso/pulls/11163"},"html":{"href":"https://github.com/enso-org/enso/pull/11163"},"issue":{"href":"https://api.github.com/repos/enso-org/enso/issues/11163"},"comments":{"href":"https://api.github.com/repos/enso-org/enso/issues/11163/comments"},"review_comments":{"href":"https://api.github.com/repos/enso-org/enso/pulls/11163/comments"},"review_comment":{"href":"https://api.github.com/repos/enso-org/enso/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/enso-org/enso/pulls/11163/commits"},"statuses":{"href":"https://api.github.com/repos/enso-org/enso/statuses/40d06cce37e659f8ca38bf4fb53bb1c125a23ad9"}},"author_association":"MEMBER","auto_merge":null,"active_lock_reason":null}},"public":true,"created_at":"2024-10-03T12:49:08Z","org":{"id":17415943,"login":"enso-org","gravatar_id":"","url":"https://api.github.com/orgs/enso-org","avatar_url":"https://avatars.githubusercontent.com/u/17415943?"}},{"id":"42509437709","type":"PullRequestReviewCommentEvent","actor":{"id":77981300,"login":"dgodinez-dh","display_login":"dgodinez-dh","gravatar_id":"","url ...
#  '-374,6 +382,32 @@ def no_error_date_callable(date: Date) -> None:\\n     '
#  'return no_error_date_callable\\n \\n \\n+def '
#  'wrap_local_date_callable(\\n+    date_callable: '
#  'Callable[[LocalDateConvertible], None],\\n+) -> Callable[[LocalDate], '
#  'None]:\\n+    \\"\\"\\"\\n+    Wrap a callable to convert the Date argument '
#  'to a Java date type.\\n+    This maintains the original callable signature '
#  'so that the Date argument can be dropped.\\n+\\n+    Args:\\n+        '
#  'date_callable: The callable to wrap.\\n+        converter: The date '
#  'converter to use.\\n+\\n+    Returns:\\n+        The wrapped '
#  'callable.\\n+    \\"\\"\\"\\n+    # When the user is typing a date, they may '
#  'enter a value that does not parse\\n+    # This will skip those errors '
#  'rather than printing them to the screen\\n+    def '
#  'no_error_date_callable(date: LocalDateConvertible) -> None:\\n+        '
#  'wrapped_date_callable = wrap_callable(date_callable)\\n+        '
#  'try:\\n+            wrapped_date_callable(to_j_local_date(date))\\n+        '
#  'except Exception:\\n+            '
#  'pass\\n+","path":"plugins/ui/src/deephaven/ui/_internal/utils.py","commit_id":"a67c800012c357d61f8c13d695ec41fb3ae20deb","original_commit_id":"1766eda874b261149b460c334855c3b4979d8b55","user":{"login":"dgodinez-dh","id":77981300,"node_id":"MDQ6VXNlcjc3OTgxMzAw","avatar_url":"https://avatars.githubusercontent.com/u/77981300?v=4","gravatar_id":"","url":"https://api.github.com/users/dgodinez-dh","html_url":"https://github.com/dgodinez-dh","followers_url":"https://api.github.com/users/dgodinez-dh/followers","following_url":"https://api.github.com/users/dgodinez-dh/following{/other_user}","gists_url":"https://api.github.com/users/dgodinez-dh/gists{/gist_id}","starred_url":"https://api.github.com/users/dgodinez-dh/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dgodinez-dh/subscriptions","organizations_url":"https://api.github.com/users/dgodinez-dh/orgs","repos_url":"https://api.github.com/users/dgodinez-dh/repos","events_url":"https://api.github.com/users/dgodinez-dh/events{/privacy}","received_events_url":"https://api.github.com/users/dgodinez-dh/received_events","type":"User","site_admin":false},"body":"Do '
#  'you mean create a new function called `_wrap_date_time_callable_skip_errors` '
#  "that encapsulates the `try/except`? I'm not sure I see the advantage of "
#  'this. I think it will create a bunch of single use functions that are only '
#  'called in one '
#  'place.","created_at":"2024-10-03T12:49:07Z","updated_at":"2024-10-03T12:49:07Z","html_url":"https://github.com/deephaven/deephaven-plugins/pull/918#discussion_r1786168349","pull_request_url":"https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918","author_association":"CONTRIBUTOR","_links":{"self":{"href":"https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments/1786168349"},"html":{"href":"https://github.com/deephaven/deephaven-plugins/pull/918#discussion_r1786168349"},"pull_request":{"href":"https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918"}},"reactions":{"url":"https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments/1786168349/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"start_line":401,"original_start_line":401,"start_side":"RIGHT","line":407,"original_line":407,"side":"RIGHT","in_reply_to_id":1784942407,"original_position":43,"position":43,"subject_type":"line"},"pull_request":{"url":"https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918","id":2102178306,"node_id":"PR_kwDOKQpEtc59TLIC","html_url":"https://github.com/deephaven/deephaven-plugins/pull/918","diff_url":"https://github.com/deephaven/deephaven-plugins/pull/918.diff","patch_url":"https://github.com/deephaven/deephaven-plugins/pull/918.patch","issue_url":"https://api.github.com/repos/deephaven/deephaven-plugins/issues/918","number":918,"state":"open","locked":false,"title":"feat: '
#  'UI Calendar '
#  'Component","user":{"login":"dgodinez-dh","id":77981300,"node_id":"MDQ6VXNlcjc3OTgxMzAw","avatar_url":"https://avatars.githubusercontent.com/u/77981300?v=4","gravatar_id":"","url":"https://api.github.com/users/dgodinez-dh","html_url":"https://github.com/dgodinez-dh","followers_url":"https://api.github.com/users/dgodinez-dh/followers","following_url":"https://api.github.com/users/dgodinez-dh/following{/other_user}","gists_url":"https://api.github.com/users/dgodinez-dh/gists{/gist_id}","starred_url":"https://api.github.com/users/dgodinez-dh/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dgodinez-dh/subscriptions","organizations_url":"https://api.github.com/users/dgodinez-dh/orgs","repos_url":"https://api.github.com/users/dgodinez-dh/repos","events_url":"https://api.github.com/users/dgodinez-dh/events{/privacy}","received_events_url":"https://api.github.com/users/dgodinez-dh/received_events","type":"User","site_admin":false},"body":"Closes '
#  'https://github.com/deephaven/deephaven-plugins/issues/905 for '
#  'implementation.\\r\\nCloses '
#  'https://github.com/deephaven/deephaven-plugins/issues/851 for '
#  'docs.","created_at":"2024-10-01T19:45:45Z","updated_at":"2024-10-03T12:49:07Z","closed_at":null,"merged_at":null,"merge_commit_sha":"accf4aca5171f1edc2086c9c60b81b0369ffcde3","assignee":null,"assignees":[],"requested_reviewers":[{"login":"margaretkennedy","id":82049573,"node_id":"MDQ6VXNlcjgyMDQ5NTcz","avatar_url":"https://avatars.githubusercontent.com/u/82049573?v=4","gravatar_id":"","url":"https://api.github.com/users/margaretkennedy","html_url":"https://github.com/margaretkennedy","followers_url":"https://api.github.com/users/margaretkennedy/followers","following_url":"https://api.github.com/users/margaretkennedy/following{/other_user}","gists_url":"https://api.github.com/users/margaretkennedy/gists{/gist_id}","starred_url":"https://api.github.com/users/margaretkennedy/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/margaretkennedy/subscriptions","organizations_url":"https://api.github.com/users/margaretkennedy/orgs","repos_url":"https://api.github.com/users/margaretkennedy/repos","events_url":"https://api.github.com/users/margaretkennedy/events{/privacy}","received_events_url":"https://api.github.com/users/margaretkennedy/received_events","type":"User","site_admin":false}],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918/commits","review_comments_url":"https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918/comments","review_comment_url":"https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments{/number}","comments_url":"https://api.github.com/repos/deephaven/deephaven-plugins/issues/918/comments","statuses_url":"https://api.github.com/repos/deephaven/deephaven-plugins/statuses/a67c800012c357d61f8c13d695ec41fb3ae20deb","head":{"label":"dgodinez-dh:dag_Calendar","ref":"dag_Calendar","sha":"a67c800012c357d61f8c13d695ec41fb3ae20deb","user":{"login":"dgodinez-dh","id":77981300,"node_id":"MDQ6VXNlcjc3OTgxMzAw","avatar_url":"https://avatars.githubusercontent.com/u/77981300?v=4","gravatar_id":"","url":"https://api.github.com/users/dgodinez-dh","html_url":"https://github.com/dgodinez-dh","followers_url":"https://api.github.com/users/dgodinez-dh/followers","following_url":"https://api.github.com/users/dgodinez-dh/following{/other_user}","gists_url":"https://api.github.com/users/dgodinez-dh/gists{/gist_id}","starred_url":"https://api.github.com/users/dgodinez-dh/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dgodinez-dh/subscriptions","organizations_url":"https://api.github.com/users/dgodinez-dh/orgs","repos_url":"https://api.github.com/users/dgodinez-dh/repos","events_url":"https://api.github.com/users/dgodinez-dh/events{/privacy}","received_events_url":"https://api.github.com/users/dgodinez-dh/received_events","type":"User","site_admin":false},"repo":{"id":832656531,"node_id":"R_kgDOMaFUkw","name":"deephaven-plugins","full_name":"dgodinez-dh/deephaven-plugins","private":false}},"base":{"label":"deephaven:main","ref":"main","sha":"863655b391424bc23bf7fc50faaae28ef213c4a6","user":{"login":"deephaven","id":44370703,"node_id":"MDEyOk9yZ2FuaXphdGlvbjQ0MzcwNzAz","avatar_url":"https://avatars.githubusercontent.com/u/44370703?v=4","gravatar_id":"","url":"https://api.github.com/users/deephaven","html_url":"https://github.com/deephaven","followers_url":"https://api.github.com/users/deephaven/followers","following_url":"https://api.github.com/users/deephaven/following{/other_user}","gists_url":"https://api.github.com/users/deephaven/gists{/gist_id}","starred_url":"https://api.github.com/users/deephaven/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/deephaven/subscriptions","organizations_url":"https://api.github.com/users/deephaven/orgs","repos_url":"https://api.github.com/users/deephaven/repos","events_url":"https://api.github.com/users/deephaven/events{/privacy}","received_events_url":"https://api.github.com/users/deephaven/received_events ...
#  'Feliciano"},"message":"Update '
#  'README.md","distinct":true,"url":"https://api.github.com/repos/GoncaloaaF-ATEC/PIPL0923/commits/b2201d13d1bb9cfb995149ba21c3ae944c2a7a83"}]},"public":true,"created_at":"2024-10-03T12:49:08Z","org":{"id":172500943,"login":"GoncaloaaF-ATEC","gravatar_id":"","url":"https://api.github.com/orgs/GoncaloaaF-ATEC","avatar_url":"https://avatars.githubusercontent.com/u/172500943?"}},{"id":"42509437663","type":"PushEvent","actor":{"id":63259982,"login":"JotaPrimo","display_login":"JotaPrimo","gravatar_id":"","url":"https://api.github.com/users/JotaPrimo","avatar_url":"https://avatars.githubusercontent.com/u/63259982?"},"repo":{"id":866758374,"name":"JotaPrimo/selectores","url":"https://api.github.com/repos/JotaPrimo/selectores"},"payload":{"repository_id":866758374,"push_id":20536498610,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"4d35ab2d5ae472cd64a1352ac3813e161a2ad4a5","before":"7af0b9ecf3ef2d0208e49707d6a117e1ee21d7d3","commits":[{"sha":"4d35ab2d5ae472cd64a1352ac3813e161a2ad4a5","author":{"email":"gestald118@email.com","name":"jota '
#  'santos"},"message":"273. Información de las '
#  'fronteras","distinct":true,"url":"https://api.github.com/repos/JotaPrimo/selectores/commits/4d35ab2d5ae472cd64a1352ac3813e161a2ad4a5"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437632","type":"CreateEvent","actor":{"id":156696627,"login":"Ruslan0192","display_login":"Ruslan0192","gravatar_id":"","url":"https://api.github.com/users/Ruslan0192","avatar_url":"https://avatars.githubusercontent.com/u/156696627?"},"repo":{"id":867094418,"name":"Ruslan0192/TradeVisualization","url":"https://api.github.com/repos/Ruslan0192/TradeVisualization"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437609","type":"PushEvent","actor":{"id":99333578,"login":"M7-M7-M7","display_login":"M7-M7-M7","gravatar_id":"","url":"https://api.github.com/users/M7-M7-M7","avatar_url":"https://avatars.githubusercontent.com/u/99333578?"},"repo":{"id":843638456,"name":"M7-M7-M7/m7777","url":"https://api.github.com/repos/M7-M7-M7/m7777"},"payload":{"repository_id":843638456,"push_id":20536498595,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"0ba3a81242b92ce1e86742427559e9431cf2e90a","before":"434fd260cb378c3b3ce81a817d4ba9b96d8a9654","commits":[{"sha":"0ba3a81242b92ce1e86742427559e9431cf2e90a","author":{"email":"you@example.com","name":"Your '
#  'Name"},"message":"Update '
#  'files","distinct":true,"url":"https://api.github.com/repos/M7-M7-M7/m7777/commits/0ba3a81242b92ce1e86742427559e9431cf2e90a"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437606","type":"PushEvent","actor":{"id":97571741,"login":"alfianto21","display_login":"alfianto21","gravatar_id":"","url":"https://api.github.com/users/alfianto21","avatar_url":"https://avatars.githubusercontent.com/u/97571741?"},"repo":{"id":864189659,"name":"alfianto21/poem.github.io","url":"https://api.github.com/repos/alfianto21/poem.github.io"},"payload":{"repository_id":864189659,"push_id":20536498589,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"836e1073abb33ea17f1d41353928973b798e66b7","before":"3ce53a2dcee48a0f5ad9648be2952273072eaf32","commits":[{"sha":"836e1073abb33ea17f1d41353928973b798e66b7","author":{"email":"97571741+alfianto21@users.noreply.github.com","name":"alfianto21"},"message":"Update '
#  'README.md","distinct":true,"url":"https://api.github.com/repos/alfianto21/poem.github.io/commits/836e1073abb33ea17f1d41353928973b798e66b7"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437572","type":"PushEvent","actor":{"id":93773753,"login":"BlaaSwe","display_login":"BlaaSwe","gravatar_id":"","url":"https://api.github.com/users/BlaaSwe","avatar_url":"https://avatars.githubusercontent.com/u/93773753?"},"repo":{"id":544882036,"name":"BlaaSwe/Trend-Soaring-1min","url":"https://api.github.com/repos/BlaaSwe/Trend-Soaring-1min"},"payload":{"repository_id":544882036,"push_id":20536498581,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"aff92883e792d72497a87e2a44a5a6b87010f746","before":"3eed84ed59dd38921eb8e7c40b51525f6fa40ce4","commits":[{"sha":"aff92883e792d72497a87e2a44a5a6b87010f746","author":{"email":"93773753+BlaaSwe@users.noreply.github.com","name":"Blaa"},"message":"Open '
#  'Storage: New '
#  'File.","distinct":true,"url":"https://api.github.com/repos/BlaaSwe/Trend-Soaring-1min/commits/aff92883e792d72497a87e2a44a5a6b87010f746"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437593","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":661535205,"name":"thedoggybrad/easylist-mirror","url":"https://api.github.com/repos/thedoggybrad/easylist-mirror"},"payload":{"repository_id":661535205,"push_id":20536498587,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"fb6b6682d93640e883edf1ac17298f4d153f6cd5","before":"9e5513e280daa89ee1dd35cd1f92038dc164a50e","commits":[{"sha":"fb6b6682d93640e883edf1ac17298f4d153f6cd5","author":{"email":"142152315+syncbot-easylistmirror@users.noreply.github.com","name":"syncbot-easylistmirror"},"message":"Sync '
#  'rolist.txt","distinct":true,"url":"https://api.github.com/repos/thedoggybrad/easylist-mirror/commits/fb6b6682d93640e883edf1ac17298f4d153f6cd5"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437582","type":"IssueCommentEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":637784737,"name":"equinor/nrresqml","url":"https://api.github.com/repos/equinor/nrresqml"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/equinor/nrresqml/issues/17","repository_url":"https://api.github.com/repos/equinor/nrresqml","labels_url":"https://api.github.com/repos/equinor/nrresqml/issues/17/labels{/name}","comments_url":"https://api.github.com/repos/equinor/nrresqml/issues/17/comments","events_url":"https://api.github.com/repos/equinor/nrresqml/issues/17/events","html_url":"https://github.com/equinor/nrresqml/pull/17","id":2563971127,"node_id":"PR_kwDOJgPSoc59fyh4","number":17,"title":"chore(main): '
#  'release '
#  '1.2.2","user":{"login":"github-actions[bot]","id":41898282,"node_id":"MDM6Qm90NDE4OTgyODI=","avatar_url":"https://avatars.githubusercontent.com/in/15368?v=4","gravatar_id":"","url":"https://api.github.com/users/github-actions%5Bbot%5D","html_url":"https://github.com/apps/github-actions","followers_url":"https://api.github.com/users/github-actions%5Bbot%5D/followers","following_url":"https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/github-actions%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/github-actions%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/github-actions%5Bbot%5D/repos","events_url":"https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/github-actions%5Bbot%5D/received_events","type":"Bot","site_admin":false},"labels":[{"id":5927284411,"node_id":"LA_kwDOJgPSoc8AAAABYUsuuw","url":"https://api.github.com/repos/equinor/nrresqml/labels/autorelease:%20tagged","name":"autorelease: '
#  'tagged","color":"ededed","default":false,"description":null}],"state":"closed","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":1,"created_at":"2024-10-03T12:45:01Z","updated_at":"2024-10-03T12:49:08Z","closed_at":"2024-10-03T12:48:53Z","author_association":"CONTRIBUTOR","active_lock_reason":null,"draft":false,"pull_request":{"url":"https://api.github.com/repos/equinor/nrresqml/pulls/17","html_url":"https://github.com/equinor/nrresqml/pull/17","diff_url":"https://github.com/equinor/nrresqml/pull/17.diff","patch_url":"https://github.com/equinor/nrresqml/pull/17.patch","merged_at":"2024-10-03T12:48:53Z"},"body":":robot: '
#  'I have created a release *beep* *boop*\\n---\\n\\n\\n## '
#  '[1.2.2](https://github.com/equinor/nrresqml/compare/v1.2.1...v1.2.2) '
#  '(2024-10-03)\\n\\n\\n### Bug Fixes\\n\\n* Fix issue with wrong archel count '
#  '([ca78d67](https://github.com/equinor/nrresqml/commit/ca78d677e6f904b87034e492fb691ee2dcf3c797))\\n\\n---\\nThis '
#  'PR was generated with [Release '
#  'Please](https://github.com/googleapis/release-please). See '
#  '[documentation](https://github.com/googleapis/release-please#release-please).","reactions":{"url":"https://api.github.com/repos/equinor/nrresqml/issues/17/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"timeline_url":"https://api.github.com/repos/equinor/nrresqml/issues/17/timeline","performed_via_github_app":null,"state_reason":null},"comment":{"url":"https://api.github.com/repos/equinor/nrresqml/issues/comments/2391338412","html_url":"https://github.com/equinor/nrresqml/pull/17#issuecomment-2391338412","issue_url":"https://api.github.com/repos/equinor/nrresqml/issues/17","id":2391338412,"node_id":"IC_kwDOJgPSoc6OiO2s","user":{"login":"github-actions[bot]","id":41898282,"node_id":"MDM6Qm90NDE4OTgyODI=","avatar_url":"https://avatars.githubusercontent.com/in/15368?v=4","gravatar_id":"","url":"https://api.github.com/users/github-actions%5Bbot%5D","html_url":"https://github.com/apps/github-actions","followers_url":"https://api.github.com/users/github-actions%5Bbot%5D/followers","following_url":"https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/github-actions%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/github-actions%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/github-actions%5Bbot%5D/repos","events_url":"https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/github-actions%5Bbot%5D/received_events","type":"Bot","site_admin":false},"created_at":"2024-10-03T12:49:06Z","updated_at":"2024-10-03T12:49:06Z","author_association":"CONTRIBUTOR","body":":robot: '
#  'Release is at https://github.com/equinor/nrresqml/releases/tag/v1.2.2 '
#  ':sunflower:","reactions":{"url":"https://api.github.com/repos/equinor/nrresqml/issues/comments/2391338412/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"performed_via_github_app":{"id":15368,"client_id":"Iv1.05c79e9ad1f6bdfa","slug":"github-actions","node_id":"MDM6QXBwMTUzNjg=","owner":{"login":"github","id":9919,"node_id":"MDEyOk9yZ2FuaXphdGlvbjk5MTk=","avatar_url":"https://avatars.githubusercontent.com/u/9919?v=4","gravatar_id":"","url":"https://api.github.com/users/github","html_url":"https://github.com/github","followers_url":"https://api.github.com/users/github/followers","following_url":"https://api.github.com/users/github/following{/other_user}","gists_url":"https://api.github.com/users/github/gists{/gist_id}","starred_url":"https://api.github.com/users/github/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/github/subscriptions","organizations_url":"https://api.github.com/users/github/orgs","repos_url":"https://api.github.com/users/github/repos","events_url":"https://api.github.com/users/github/events{/privacy}","received_events_url":"https://api.github.com/users/github/received_events","type":"Organization","site_admin":false},"name":"GitHub '
#  'Actions","description":"Automate your workflow from idea to '
#  'production","external_url":"https://help.github.com/en/actions","html_url":"https://github.com/apps/github-actions","created_at":"2018-07-30T09:30:17Z","updated_at":"2024-04-10T20:33:16Z","permissions":{"actions":"write","administration":"read","attestations":"write","checks":"write","contents":"write","deployments":"write","discussions":"write","issues":"write","merge_queues":"write","metadata":"read","packages":"write","pages":"write","pull_requests":"write","repository_hooks":"write","repository_projects":"write","security_events":"write","statuses":"write","vulnerability_alerts":"read"},"events":["branch_protection_rule","check_run","check_suite","create","delete","deployment","deployment_status","discussion","discussion_comment","fork","gollum","issues","issue_comment","label","merge_group","milestone","page_build","project","project_card","project_column","public","pull_request","pull_request_review","pull_request_review_comment","push","registry_package","release","repository","repository_dispatch","status","watch","workflow_dispatch","workflow_run"]}}},"public":true,"created_at":"2024-10-03T12:49:08Z","org":{"id":525862,"login":"equinor","gravatar_id":"","url":"https://api.github.com/orgs/equinor","avatar_url":"https://avatars.githubusercontent.com/u/525862?"}},{"id":"42509437561","type":"IssueCommentEvent","actor":{"id":107444360,"login":"ocpdocs-previewbot","display_login":"ocpdocs-previewbot","gravatar_id":"","url":"https://api.github.com/users/ocpdocs-previewbot","avatar_url":"https://avatars.githubusercontent.com/u/107444360?"},"repo":{"id":21740844,"name":"openshift/openshift-docs","url":"https://api.github.com/repos/openshift/openshift-docs"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/openshift/openshift-docs/issues/82959","repository_url":"https://api.github.com/repos/openshift/openshift-docs","labels_url":"https://api.github.com/repos/openshift/openshift-docs/issues/82959/labels{/name}","comments_url":"https://api.github.com/repos/openshift/openshift-docs/issues/82959/comments","events_url":"https://api.github.com/repos/openshift/openshift-docs/issues/82959/events","html_url":"https://github.com/openshift/openshift-docs/pull/82959","id":2563941042,"node_id":"PR_kwDOAUu9LM59fsEZ","number":82959,"title":"OBSDOCS-1356/TRACING-4621: '
#  "Max's "
# ...
#  'responsive shopping cart built with React, featuring a modal confirmation '
#  'dialog for viewing selected items and confirming checkout, optimized for all '
#  'screen '
#  'sizes.","pusher_type":"user"},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437475","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":460805243,"name":"luanjubica/statuspage","url":"https://api.github.com/repos/luanjubica/statuspage"},"payload":{"repository_id":460805243,"push_id":20536498537,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"7a50257fda104fcf18470c20a2e5a0735d3399f0","before":"07c439bf5c7d5284e54f6cc9fb3c6aef50912956","commits":[{"sha":"7a50257fda104fcf18470c20a2e5a0735d3399f0","author":{"email":"luanjubica@gmail.com","name":"Luan '
#  'Jubica"},"message":"[Automated] Update Health Check '
#  'Logs","distinct":true,"url":"https://api.github.com/repos/luanjubica/statuspage/commits/7a50257fda104fcf18470c20a2e5a0735d3399f0"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437451","type":"CreateEvent","actor":{"id":104969449,"login":"vishal230503","display_login":"vishal230503","gravatar_id":"","url":"https://api.github.com/users/vishal230503","avatar_url":"https://avatars.githubusercontent.com/u/104969449?"},"repo":{"id":867094417,"name":"vishal230503/terraform-repo","url":"https://api.github.com/repos/vishal230503/terraform-repo"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2024-10-03T12:49:07Z"},{"id":"42509437405","type":"PushEvent","actor":{"id":111508010,"login":"LiquidSi1k","display_login":"LiquidSi1k","gravatar_id":"","url":"https://api.github.com/users/LiquidSi1k","avatar_url":"https://avatars.githubusercontent.com/u/111508010?"},"repo":{"id":867093144,"name":"LiquidSi1k/LiquidSi1k","url":"https://api.github.com/repos/LiquidSi1k/LiquidSi1k"},"payload":{"repository_id":867093144,"push_id":20536498509,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"23308566f8c34a4b7781a90215b343788906629b","before":"8f44dfe9b6e97f360d5b05499ec8164017c32407","commits":[{"sha":"23308566f8c34a4b7781a90215b343788906629b","author":{"email":"vince_voo@yahoo.com","name":"Voo '
#  'Tzuen Hau"},"message":"Update '
#  'README.md","distinct":true,"url":"https://api.github.com/repos/LiquidSi1k/LiquidSi1k/commits/23308566f8c34a4b7781a90215b343788906629b"}]},"public":true,"created_at":"2024-10-03T12:49:07Z"},{"id":"42509437418","type":"PushEvent","actor":{"id":125495087,"login":"ndahtems","display_login":"ndahtems","gravatar_id":"","url":"https://api.github.com/users/ndahtems","avatar_url":"https://avatars.githubusercontent.com/u/125495087?"},"repo":{"id":858291574,"name":"ndahtems/Terraform-Jenkins","url":"https://api.github.com/repos/ndahtems/Terraform-Jenkins"},"payload":{"repository_id":858291574,"push_id":20536498505,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"21250c8e7a370c35efad5d45f23da06f6be1ffbe","before":"8488ba297cf26b839a34106e01660c06fcbbfcd0","commits":[{"sha":"21250c8e7a370c35efad5d45f23da06f6be1ffbe","author":{"email":"ndahtembi@gmail.com","name":"Tembi"},"message":"updated '
#  'repo","distinct":true,"url":"https://api.github.com/repos/ndahtems/Terraform-Jenkins/commits/21250c8e7a370c35efad5d45f23da06f6be1ffbe"}]},"public":true,"created_at":"2024-10-03T12:49:07Z"},{"id":"42509437404","type":"PushEvent","actor":{"id":36563672,"login":"Mmx233","display_login":"Mmx233","gravatar_id":"","url":"https://api.github.com/users/Mmx233","avatar_url":"https://avatars.githubusercontent.com/u/36563672?"},"repo":{"id":850380663,"name":"Mmx233/BackoffCli","url":"https://api.github.com/repos/Mmx233/BackoffCli"},"payload":{"repository_id":850380663,"push_id":20536498511,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"657194ccba996d0026c64db7b1f50c41483c3290","before":"d3a8dd34d1ca34dd5879aeb9a3bd4756a281dd4f","commits":[{"sha":"657194ccba996d0026c64db7b1f50c41483c3290","author":{"email":"green.dusk8264@fastmail.com","name":"Mmx"},"message":"sync: '
#  'backoff","distinct":true,"url":"https://api.github.com/repos/Mmx233/BackoffCli/commits/657194ccba996d0026c64db7b1f50c41483c3290"}]},"public":true,"created_at":"2024-10-03T12:49:07Z"},{"id":"42509437414","type":"PushEvent","actor":{"id":76231708,"login":"nicholasalvesx","display_login":"nicholasalvesx","gravatar_id":"","url":"https://api.github.com/users/nicholasalvesx","avatar_url":"https://avatars.githubusercontent.com/u/76231708?"},"repo":{"id":852190273,"name":"Ranbu100/Projeto-Estacionamento","url":"https://api.github.com/repos/Ranbu100/Projeto-Estacionamento"},"payload":{"repository_id":852190273,"push_id":20536498520,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"e70a98f5308ebd588e2a3763c9abc729bb11b808","before":"459fa0ff0c1b4d36e538d936d2781dc15e4da8a8","commits":[{"sha":"e70a98f5308ebd588e2a3763c9abc729bb11b808","author":{"email":"nicholas.alves2007@gmail.com","name":"Nicholas"},"message":"att '
#  'backend '
#  '3/10","distinct":true,"url":"https://api.github.com/repos/Ranbu100/Projeto-Estacionamento/commits/e70a98f5308ebd588e2a3763c9abc729bb11b808"}]},"public":true,"created_at":"2024-10-03T12:49:07Z"},{"id":"42509437385","type":"PushEvent","actor":{"id":136606032,"login":"theanujsinha01","display_login":"theanujsinha01","gravatar_id":"","url":"https://api.github.com/users/theanujsinha01","avatar_url":"https://avatars.githubusercontent.com/u/136606032?"},"repo":{"id":867076636,"name":"theanujsinha01/Data-Analysis-Projects","url":"https://api.github.com/repos/theanujsinha01/Data-Analysis-Projects"},"payload":{"repository_id":867076636,"push_id":20536498482,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"1e3d3e1ace4d088361d04b56cd01ea07250f901e","before":"62be5faa7fb64327fe958eec3c96b0e1c87d2d3a","commits":[{"sha":"1e3d3e1ace4d088361d04b56cd01ea07250f901e","author":{"email":"136606032+theanujsinha01@users.noreply.github.com","name":"Anuj '
#  'Kumar"},"message":"Add files via '
#  'upload","distinct":true,"url":"https://api.github.com/repos/theanujsinha01/Data-Analysis-Projects/commits/1e3d3e1ace4d088361d04b56cd01ea07250f901e"}]},"public":true,"created_at":"2024-10-03T12:49:07Z"},{"id":"42509437410","type":"PullRequestEvent","actor":{"id":99863853,"login":"CodeItpython","display_login":"CodeItpython","gravatar_id":"","url":"https://api.github.com/users/CodeItpython","avatar_url":"https://avatars.githubusercontent.com/u/99863853?"},"repo":{"id":862142178,"name":"prgrms-be-devcourse/NBE1_2_Team07","url":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07"},"payload":{"action":"closed","number":23,"pull_request":{"url":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23","id":2102913367,"node_id":"PR_kwDOM2M-4s59V-lX","html_url":"https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23","diff_url":"https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23.diff","patch_url":"https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23.patch","issue_url":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/issues/23","number":23,"state":"closed","locked":false,"title":"Feat/#2 '
#  '유저 회원가입 및 로그인 '
#  '구현","user":{"login":"CodeItpython","id":99863853,"node_id":"U_kgDOBfPNLQ","avatar_url":"https://avatars.githubusercontent.com/u/99863853?v=4","gravatar_id":"","url":"https://api.github.com/users/CodeItpython","html_url":"https://github.com/CodeItpython","followers_url":"https://api.github.com/users/CodeItpython/followers","following_url":"https://api.github.com/users/CodeItpython/following{/other_user}","gists_url":"https://api.github.com/users/CodeItpython/gists{/gist_id}","starred_url":"https://api.github.com/users/CodeItpython/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/CodeItpython/subscriptions","organizations_url":"https://api.github.com/users/CodeItpython/orgs","repos_url":"https://api.github.com/users/CodeItpython/repos","events_url":"https://api.github.com/users/CodeItpython/events{/privacy}","received_events_url":"https://api.github.com/users/CodeItpython/received_events","type":"User","site_admin":false},"body":"## '
#  '📌 과제 설명 <!-- 어떤 걸 만들었는지 대략적으로 설명해주세요 -->\\r\\n- #2 \\r\\n\\r\\n- 유저의 회원가입기능을 '
#  '개발\\r\\n- 관리자계정과 일반사용자를 구분하여 회원가입\\r\\n- 이메일 인증을 통한 회원가입\\r\\n\\r\\n\\r\\n## '
#  '👩\u200d💻 요구 사항과 구현 내용 <!-- 기능을 Commit 별로 잘개 쪼개고, Commit 별로 설명해주세요 -->\\r\\n- '
#  '아이디 중복체크기능\\r\\n- 이메일 발송기능\\r\\n- 이메일 발송코드 검증기능\\r\\n- 회원가입기능(+ROLE_USER, '
#  'ROLE_ADMIN 선택)\\r\\n- 로그인기능\\r\\n\\r\\n## ✅ PR 포인트 & 궁금한 점 <!-- 리뷰어 분들이 '
#  '집중적으로 보셨으면 하는 내용을 적어주세요 -->\\r\\n- fe 코드와 함께 카카오, 네이버 로그인 구현 '
#  '예정\\r\\n","created_at":"2024-10-02T08:11:37Z","updated_at":"2024-10-03T12:49:07Z","closed_at":"2024-10-03T12:49:06Z","merged_at":null,"merge_commit_sha":"454e259127886ab88c560ce8af870232253e0341","assignee":{"login":"CodeItpython","id":99863853,"node_id":"U_kgDOBfPNLQ","avatar_url":"https://avatars.githubusercontent.com/u/99863853?v=4","gravatar_id":"","url":"https://api.github.com/users/CodeItpython","html_url":"https://github.com/CodeItpython","followers_url":"https://api.github.com/users/CodeItpython/followers","following_url":"https://api.github.com/users/CodeItpython/following{/other_user}","gists_url":"https://api.github.com/users/CodeItpython/gists{/gist_id}","starred_url":"https://api.github.com/users/CodeItpython/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/CodeItpython/subscriptions","organizations_url":"https://api.github.com/users/CodeItpython/orgs","repos_url":"https://api.github.com/users/CodeItpython/repos","events_url":"https://api.github.com/users/CodeItpython/events{/privacy}","received_events_url":"https://api.github.com/users/CodeItpython/received_events","type":"User","site_admin":false},"assignees":[{"login":"CodeItpython","id":99863853,"node_id":"U_kgDOBfPNLQ","avatar_url":"https://avatars.githubusercontent.com/u/99863853?v=4","gravatar_id":"","url":"https://api.github.com/users/CodeItpython","html_url":"https://github.com/CodeItpython","followers_url":"https://api.github.com/users/CodeItpython/followers","following_url":"https://api.github.com/users/CodeItpython/following{/other_user}","gists_url":"https://api.github.com/users/CodeItpython/gists{/gist_id}","starred_url":"https://api.github.com/users/CodeItpython/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/CodeItpython/subscriptions","organizations_url":"https://api.github.com/users/CodeItpython/orgs","repos_url":"https://api.github.com/users/CodeItpython/repos","events_url":"https://api.github.com/users/CodeItpython/events{/privacy}","received_events_url":"https://api.github.com/users/CodeItpython/received_events","type":"User","site_admin":false}],"requested_reviewers":[],"requested_teams":[{"name":"BE1 '
#  '07","id":11082983,"node_id":"T_kwDOBT8X1M4AqRzn","slug":"be1-07","description":"","privacy":"closed","notification_setting":"notifications_enabled","url":"https://api.github.com/organizations/88020948/team/11082983","html_url":"https://github.com/orgs/prgrms-be-devcourse/teams/be1-07","members_url":"https://api.github.com/organizations/88020948/team/11082983/members{/member}","repositories_url":"https://api.github.com/organizations/88020948/team/11082983/repos","permission":"pull","parent":null}],"labels":[{"id":7508341557,"node_id":"LA_kwDOM2M-4s8AAAABv4gzNQ","url":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/labels/Feat","name":"Feat","color":"06CDC2","default":false,"description":"새로운 '
#  '기능 '
#  '추가"}],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23/commits","review_comments_url":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23/comments","review_comment_url":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/comments{/number}","comments_url":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/issues/23/comments","statuses_url":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/statuses/4a9841cace7a96a5cf430dc9589f319a4c2d6405","head":{"label":"prgrms-be-devcourse:feat/#2","ref":"feat/#2","sha":"4a9841cace7a96a5cf430dc9589f319a4c2d6405","user":{"login":"prgrms-be-devcourse","id":88020948,"node_id":"MDEyOk9yZ2FuaXphdGlvbjg4MDIwOTQ4","avatar_url":"https://avatars.githubusercontent.com/u/88020948?v=4","gravatar_id":"","url":"https://api.github.com/users/prgrms-be-devcourse","html_url":"https://github.com/prgrms-be-devcourse","followers_url":"https://api.github.com/users/prgrms-be-devcourse/followers","following_url":"https://api.github.com/users/prgrms-be-devcourse/following{/other_user}","gists_url":"https://api.github.com/users/prgrms-be-devcourse/gists{/gist_id}","starred_url":"https://api.github.com/users/prgrms-be-devcourse/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/prgrms-be-devcourse/subscriptions","organizations_url":"https://api.github.com/users/prgrms-be-devcourse/orgs","repos_url":"https://api.github.com/users/prgrms-be-devcourse/repos","events_url":"https://api.github.com/users/prgrms-be-devcourse/events{/privacy}","received_events_url":"https://api.github.com/users/prgrms-be-devcourse/received_events","type":"Organization","site_admin":false},"repo":{"id":862142178,"node_id":"R_kgDOM2M-4g","name":"NBE1_2_Team07","full_name":"prgrms-be-devcourse/NBE1_2_Team07","private":false}},"base":{"label":"prgrms-be-devcourse:develop","ref":"develop","sha":"6e5d4c3a3c16a858612d6ce4f081861fd12df6db","user":{"login":"prgrms-be-devcourse","id":88020948,"node_id":"MDEyOk9yZ2FuaXphdGlvbjg4MDIwOTQ4","avatar_url":"https://avatars.githubusercontent.com/u/88020948?v=4","gravatar_id":"","url":"https://api.github.com/users/prgrms-be-devcourse","html_url":"https://github.com/prgrms-be-devcourse","followers_url":"https://api.github.com/users/prgrms-be-devcourse/followers","following_url":"https://api.github.com/users/prgrms-be-devcourse/following{/other_user}","gists_url":"https://api.github.com/users/prgrms-be-devcourse/gists{/gist_id}","starred_url":"https://api.github.com/users/prgrms-be-devcourse/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/prgrms-be-devcourse/subscriptions","organizations_url":"https://api.github.com/users/prgrms-be-devcourse/orgs","repos_url":"https://api.github.com/users/prgrms-be-devcourse/repos","events_url":"https://api.github.com/users/prgrms-be-devcourse/events{/privacy}","received_events_url":"https://api.github.com/users/prgrms-be-devcourse/received_events","type":"Organization","site_admin":false},"repo":{"id":862142178,"node_id":"R_kgDOM2M-4g","name":"NBE1_2_Team07","full_name":"prgrms-be-devcourse/NBE1_2_Team07","private":false}},"_links":{"self":{"href":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23"},"html":{"href":"https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23"},"issue":{"href":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/issues/23"},"comments":{"href":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/issues/23/comments"},"review_comments":{"href":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23/comments"},"review_comment":{"href":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23/commits"},"statuses":{"href":"https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/statuse ...

# %%
r.encoding
# Out:
# 'utf-8'

# %% [markdown]
# >> ### **Binary Response Content**

# %%
r.content
# Out:
# b'[{"id":"42509437768","type":"PushEvent","actor":{"id":161367810,"login":"aimme14","display_login":"aimme14","gravatar_id":"","url":"https://api.github.com/users/aimme14","avatar_url":"https://avatars.githubusercontent.com/u/161367810?"},"repo":{"id":867058423,"name":"aimme14/estudio-primer-parcial","url":"https://api.github.com/repos/aimme14/estudio-primer-parcial"},"payload":{"repository_id":867058423,"push_id":20536498670,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"ef0c13c38c0a1be7ac4dd43331cd401a29d6c692","before":"c015c1ee8f671a66b1f57824072ef8544a3460ad","commits":[{"sha":"ef0c13c38c0a1be7ac4dd43331cd401a29d6c692","author":{"email":"aylopezm@ufpso.edu.co","name":"aime"},"message":"estudio","distinct":true,"url":"https://api.github.com/repos/aimme14/estudio-primer-parcial/commits/ef0c13c38c0a1be7ac4dd43331cd401a29d6c692"}]},"public":true,"created_at":"2024-10-03T12:49:08Z"},{"id":"42509437745","type":"IssueCommentEvent","actor":{"id":178772239,"login":"suresh06-lv","display_login":"suresh06-lv","gravatar_id":"","url":"https://api.github.com/users/suresh06-lv","avatar_url":"https://avatars.githubusercontent.com/u/178772239?"},"repo":{"id":312372049,"name":"ni/grpc-labview","url":"https://api.github.com/repos/ni/grpc-labview"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/ni/grpc-labview/issues/374","repository_url":"https://api.github.com/repos/ni/grpc-labview","labels_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/labels{/name}","comments_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/comments","events_url":"https://api.github.com/repos/ni/grpc-labview/issues/374/events","html_url":"https://github.com/ni/grpc-labview/issues/374","id":2472747684,"node_id":"I_kwDOEp5rUc6TYyKk","number":374,"title":"Error when connecting LabVIEW gRPC client to C# server","user":{"login":"suresh06-lv","id":178772239,"node_id":"U_kgDOCqfZDw","avatar_url":"https://avatars.githubusercontent.com/u/178772239?v=4","gravatar_id":"","url":"https://api.github.com/users/suresh06-lv","html_url":"https://github.com/suresh06-lv","followers_url":"https://api.github.com/users/suresh06-lv/followers","following_url":"https://api.github.com/users/suresh06-lv/following{/other_user}","gists_url":"https://api.github.com/users/suresh06-lv/gists{/gist_id}","starred_url":"https://api.github.com/users/suresh06-lv/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/suresh06-lv/subscriptions","organizations_url":"https://api.github.com/users/suresh06-lv/orgs","repos_url":"https://api.github.com/users/suresh06-lv/repos","events_url":"https://api.github.com/users/suresh06-lv/events{/privacy}","received_events_url":"https://api.github.com/users/suresh06-lv/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":7,"created_at":"2024-08-19T08:17:58Z","updated_at":"2024-10-03T12:49:08Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"body":"**Description**\\r\\nTimeout error when trying to connect LabVIEW gRPC client to C# gRPC Server.  \\r\\nEncountered this problem when attempting to use the LabVIEW client to simulate TestStand operations by connecting to a C# server.  This issue was first seen when trying to connect to the C# server provided in https://github.com/ni/grpc-teststand-api.  I discovered that the problem persists even with a basic C# greeter gRPC service.\\r\\n\\r\\n**Steps to Reproduce**\\r\\n1. Create a C# greeter service based on the tutorial from https://learn.microsoft.com/en-us/aspnet/core/tutorials/grpc/grpc-start?view=aspnetcore-8.0&tabs=visual-studio.\\r\\n2. Create a LabVIEW client using the proto file generated from step1.\\r\\n3. Build a sample gRPC client VI. \\r\\n4. Run the service.  \\r\\n5. Connect LabVIEW greeter client using the address shown in the terminal and Run VI.\\r\\n\\r\\n**Expected Result**\\r\\nGreeter response string ...

# %% [markdown]
# >> ### **JSON Response Content**

# %%
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '42509437768',
#   'type': 'PushEvent',
#   'actor': {'id': 161367810,
#    'login': 'aimme14',
#    'display_login': 'aimme14',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aimme14',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/161367810?'},
#   'repo': {'id': 867058423,
#    'name': 'aimme14/estudio-primer-parcial',
#    'url': 'https://api.github.com/repos/aimme14/estudio-primer-parcial'},
#   'payload': {'repository_id': 867058423,
#    'push_id': 20536498670,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ef0c13c38c0a1be7ac4dd43331cd401a29d6c692',
#    'before': 'c015c1ee8f671a66b1f57824072ef8544a3460ad',
#    'commits': [{'sha': 'ef0c13c38c0a1be7ac4dd43331cd401a29d6c692',
#      'author': {'email': 'aylopezm@ufpso.edu.co', 'name': 'aime'},
#      'message': 'estudio',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aimme14/estudio-primer-parcial/commits/ef0c13c38c0a1be7ac4dd43331cd401a29d6c692'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z'},
#  {'id': '42509437745',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 178772239,
#    'login': 'suresh06-lv',
#    'display_login': 'suresh06-lv',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/suresh06-lv',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/178772239?'},
#   'repo': {'id': 312372049,
#    'name': 'ni/grpc-labview',
#    'url': 'https://api.github.com/repos/ni/grpc-labview'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ni/grpc-labview/issues/374',
#     'repository_url': 'https://api.github.com/repos/ni/grpc-labview',
#     'labels_url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/comments',
#     'events_url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/events',
#     'html_url': 'https://github.com/ni/grpc-labview/issues/374',
#     'id': 2472747684,
#     'node_id': 'I_kwDOEp5rUc6TYyKk',
#     'number': 374,
#     'title': 'Error when connecting LabVIEW gRPC client to C# server',
#     'user': {'login': 'suresh06-lv',
#      'id': 178772239,
#      'node_id': 'U_kgDOCqfZDw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/178772239?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/suresh06-lv',
#      'html_url': 'https://github.com/suresh06-lv',
#      'followers_url': 'https://api.github.com/users/suresh06-lv/followers',
#      'following_url': 'https://api.github.com/users/suresh06-lv/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/suresh06-lv/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/suresh06-lv/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/suresh06-lv/subscriptions',
#      'organizations_url': 'https://api.github.com/users/suresh06-lv/orgs',
#      'repos_url': 'https://api.github.com/users/suresh06-lv/repos',
#      'events_url': 'https://api.github.com/users/suresh06-lv/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/suresh06-lv/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 7,
#     'created_at': '2024-08-19T08:17:58Z',
#     'updated_at': '2024-10-03T12:49:08Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '**Description**\r\nTimeout error when trying to connect LabVIEW gRPC client to C# gRPC Server.  \r\nEncountered this problem when attempting to use the LabVIEW client to simulate TestStand operations by connecting to a C# server.  This issue was first seen when trying to connect to the C# server provided in https://github.com/ni/grpc-teststand-api.  I discovered that the problem persists even with a basic C# greeter gRPC service.\r\n\r\n**Steps to Reproduce**\r\n1. Create a C# greeter service based on the tutorial from https://learn.microsoft.com/en-us/aspnet/core/tutorials/grpc/grpc-start?view=aspnetcore-8.0&tabs=visual-studio.\r\n2. Create a LabVIEW client using the proto file generated from step1.\r\n3. Build a sample gRPC client VI. \r\n4. Run the service.  \r\n5. Connect LabVIEW greeter client using the address shown in the terminal and Run VI.\r\n\r\n**Expected Result**\r\nGreeter response string concatenated with \'Hello\' as prefix to client message input.\r\n"Hello " + Client Message\r\n\r\n**Actual Result**\r\n![image](https://github.com/user-attachments/assets/677d5a1c-ec8a-4606-9914-be0c1ebf5aac)\r\n\r\n**Version**\r\nLabVIEW - 2023 Q3\r\n\r\n**Images**\r\n![image](https://github.com/user-attachments/assets/2546c951-08b0-4faf-808b-2abe5c9b3523)\r\n\r\n\r\nAB#2832543',
#     'reactions': {'url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/ni/grpc-labview/issues/comments/2391338408',
#     'html_url': 'https://github.com/ni/grpc-labview/issues/374#issuecomment-2391338408',
#     'issue_url': 'https://api.github.com/repos/ni/grpc-labview/issues/374',
#     'id': 2391338408,
#     'node_id': 'IC_kwDOEp5rUc6OiO2o',
#     'user': {'login': 'suresh06-lv',
#      'id': 178772239,
#      'node_id': 'U_kgDOCqfZDw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/178772239?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/suresh06-lv',
#      'html_url': 'https://github.com/suresh06-lv',
#      'followers_url': 'https://api.github.com/users/suresh06-lv/followers',
#      'following_url': 'https://api.github.com/users/suresh06-lv/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/suresh06-lv/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/suresh06-lv/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/suresh06-lv/subscriptions',
#      'organizations_url': 'https://api.github.com/users/suresh06-lv/orgs',
#      'repos_url': 'https://api.github.com/users/suresh06-lv/repos',
#      'events_url': 'https://api.github.com/users/suresh06-lv/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/suresh06-lv/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2024-10-03T12:49:06Z',
#     'updated_at': '2024-10-03T12:49:06Z',
#     'author_association': 'NONE',
#     'body': 'Hi Jason, Thanks for the reply.  We were able to connect the LV client to the C# GRPC server for a sample greeter service.  It works fine and the message were passed as expected.  \r\nMay I know whether you tried connecting to the GRPC server given at [grpc-teststand-api](https://github.com/ni/grpc-teststand-api).  We also tried this case by providing the certificate files to the client and still got no luck.  All these tests were done by disabling the firewalls.  ',
#     'reactions': {'url': 'https://api.github.com/repos/ni/grpc-labview/issues/comments/2391338408/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z',
#   'org': {'id': 5598284,
#    'login': 'ni',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ni',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5598284?'}},
#  {'id': '42509437723',
#   'type': 'PushEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 340385345,
#    'name': 'DFE-Digital/prepare-academy-conversions',
#    'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions'},
#   'payload': {'repository_id': 340385345,
#    'push_id': 20536498633,
#    'size': 8,
#    'distinct_size': 1,
#    'ref': 'refs/heads/renovate/github.com-dfe-digital-terraform-azurerm-key-vault-tfvars-0.x',
#    'head': 'dddf95f9324652416706a60b96bb45a17b94060a',
#    'before': 'c0e85951efdb7bb1d08ec8a00dd19578edd573ab',
#    'commits': [{'sha': 'dd6f1a1e7e8d9338b21fb587f92db5bcc7db6f73',
#      'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK',
#       'name': 'SHAKIR, Muhammad'},
#      'message': 'Updated cookie banner',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/dd6f1a1e7e8d9338b21fb587f92db5bcc7db6f73'},
#     {'sha': '1a5cdbd156811953899f7b4de6bae4f2abb648f3',
#      'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK',
#       'name': 'SHAKIR, Muhammad'},
#      'message': 'Updated wording',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/1a5cdbd156811953899f7b4de6bae4f2abb648f3'},
#     {'sha': '068aa28e348f50626c6921e6762f11dda2655745',
#      'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK',
#       'name': 'SHAKIR, Muhammad'},
#      'message': "Merge branch 'main' of https://github.com/DFE-Digital/prepare-academy-conversions into feature/182329-update-cookie-banner",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/068aa28e348f50626c6921e6762f11dda2655745'},
#     {'sha': '7859b8a5172942409b49306f65a30e4d41c934e1',
#      'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK',
#       'name': 'SHAKIR, Muhammad'},
#      'message': 'Fixed tests and tidy up code',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/7859b8a5172942409b49306f65a30e4d41c934e1'},
#     {'sha': 'c20f8aead25eb2a4a10857a9bb4ce599f19cdb24',
#      'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK',
#       'name': 'SHAKIR, Muhammad'},
#      'message': 'Fixed cypress tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/c20f8aead25eb2a4a10857a9bb4ce599f19cdb24'},
#     {'sha': '141022026e180091196a22216ff31f4f0d6faeda',
#      'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK',
#       'name': 'SHAKIR, Muhammad'},
#      'message': 'Fixed tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/141022026e180091196a22216ff31f4f0d6faeda'},
#     {'sha': '465a0ead188ddc5a699444bcfb0beaf2291d4687',
#      'author': {'email': 'muhammad.shakir@education.gov.uk',
#       'name': 'mshakirdfe'},
#      'message': 'Merge pull request #1199 from DFE-Digital/feature/182329-update-cookie-banner\n\nFeature/182329 update cookie banner',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/465a0ead188ddc5a699444bcfb0beaf2291d4687'},
#     {'sha': 'dddf95f9324652416706a60b96bb45a17b94060a',
#      'author': {'email': '29139614+renovate[bot]@users.noreply.github.com',
#       'name': 'renovate[bot]'},
#      'message': 'Update Terraform github.com/DFE-Digital/terraform-azurerm-key-vault-tfvars to v0.5.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/dddf95f9324652416706a60b96bb45a17b94060a'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z',
#   'org': {'id': 30029772,
#    'login': 'DFE-Digital',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DFE-Digital',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30029772?'}},
#  {'id': '42509437737',
#   'type': 'CreateEvent',
#   'actor': {'id': 146189912,
#    'login': 'Shivanand-hulikatti',
#    'display_login': 'Shivanand-hulikatti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Shivanand-hulikatti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/146189912?'},
#   'repo': {'id': 867094419,
#    'name': 'Shivanand-hulikatti/assignmentsWebDev',
#    'url': 'https://api.github.com/repos/Shivanand-hulikatti/assignmentsWebDev'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z'},
#  {'id': '42509437721',
#   'type': 'PushEvent',
#   'actor': {'id': 120438850,
#    'login': '1992513',
#    'display_login': '1992513',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/1992513',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120438850?'},
#   'repo': {'id': 583676719,
#    'name': '1992513/djy',
#    'url': 'https://api.github.com/repos/1992513/djy'},
#   'payload': {'repository_id': 583676719,
#    'push_id': 20536498638,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7383edd5acd7c16631e12174098076b0c5a63f6e',
#    'before': '1e93d5e1e3451f390fcc340cec047559ea4d9062',
#    'commits': [{'sha': '7383edd5acd7c16631e12174098076b0c5a63f6e',
#      'author': {'email': '120438850+1992513@users.noreply.github.com',
#       'name': '1992513'},
#      'message': '2024-10-03',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/1992513/djy/commits/7383edd5acd7c16631e12174098076b0c5a63f6e'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z'},
#  {'id': '42509437720',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 1436948,
#    'login': 'radeusgd',
#    'display_login': 'radeusgd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/radeusgd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1436948?'},
#   'repo': {'id': 76672223,
#    'name': 'enso-org/enso',
#    'url': 'https://api.github.com/repos/enso-org/enso'},
#   'payload': {'action': 'created',
#    'review': {'id': 2345525742,
#     'node_id': 'PRR_kwDOBJHs386LzeHu',
#     'user': {'login': 'radeusgd',
#      'id': 1436948,
#      'node_id': 'MDQ6VXNlcjE0MzY5NDg=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1436948?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/radeusgd',
#      'html_url': 'https://github.com/radeusgd',
#      'followers_url': 'https://api.github.com/users/radeusgd/followers',
#      'following_url': 'https://api.github.com/users/radeusgd/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/radeusgd/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/radeusgd/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/radeusgd/subscriptions',
#      'organizations_url': 'https://api.github.com/users/radeusgd/orgs',
#      'repos_url': 'https://api.github.com/users/radeusgd/repos',
#      'events_url': 'https://api.github.com/users/radeusgd/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/radeusgd/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'commit_id': '40d06cce37e659f8ca38bf4fb53bb1c125a23ad9',
#     'submitted_at': '2024-10-03T12:49:07Z',
#     'state': 'commented',
#     'html_url': 'https://github.com/enso-org/enso/pull/11163#pullrequestreview-2345525742',
#     'pull_request_url': 'https://api.github.com/repos/enso-org/enso/pulls/11163',
#     'author_association': 'MEMBER',
#     '_links': {'html': {'href': 'https://github.com/enso-org/enso/pull/11163#pullrequestreview-2345525742'},
#      'pull_request': {'href': 'https://api.github.com/repos/enso-org/enso/pulls/11163'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/enso-org/enso/pulls/11163',
#     'id': 2090749538,
#     'node_id': 'PR_kwDOBJHs3858nk5i',
#     'html_url': 'https://github.com/enso-org/enso/pull/11163',
#     'diff_url': 'https://github.com/enso-org/enso/pull/11163.diff',
#     'patch_url': 'https://github.com/enso-org/enso/pull/11163.patch',
#     'issue_url': 'https://api.github.com/repos/enso-org/enso/issues/11163',
#     'number': 11163,
#     'state': 'open',
#     'locked': False,
#     'title': 'Add DB_Table feature flags',
#     'user': {'login': 'AdRiley',
#      'id': 1720119,
#      'node_id': 'MDQ6VXNlcjE3MjAxMTk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1720119?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/AdRiley',
#      'html_url': 'https://github.com/AdRiley',
#      'followers_url': 'https://api.github.com/users/AdRiley/followers',
#      'following_url': 'https://api.github.com/users/AdRiley/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/AdRiley/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/AdRiley/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/AdRiley/subscriptions',
#      'organizations_url': 'https://api.github.com/users/AdRiley/orgs',
#      'repos_url': 'https://api.github.com/users/AdRiley/repos',
#      'events_url': 'https://api.github.com/users/AdRiley/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/AdRiley/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '### Pull Request Description\r\n\r\nThis MR:\r\n- Introduces the framework for feature flags for the In Database processing engine\r\n- For everything other than SQLServer continues to have the same functionality and tests that they did before\r\n- For SQLServer removes all In-DB functionality other than being able to read a table and provides user friendly errors messages for all other In database funtionality\r\n\r\n### Important Notes\r\n\r\nNote the current set of flags may not be the final set and some of the flagging out of tests is probably coarser than it will eventually be. As we work through SQLServer enbaling functionality and tests we will clean these up.\r\n\r\nNext steps after this MR will be:\r\n- Decide on an order to approach adding SQLServer features\r\n- Enable flags for SQLServer one at a time and make the corresponding tests pass\r\n- I imagines we will need to extend the flags to Column level functionality\r\n- Look if we can swap some of the existing DB test flags for the new Feature flag system\r\n\r\n\r\n### Checklist\r\n\r\nPlease ensure that the following checklist has been satisfied before submitting the PR:\r\n\r\n- [ ] The documentation has been updated, if necessary.\r\n- [ ] Screenshots/screencasts have been attached, if there are any visual changes. For interactive or animated visual changes, a screencast is preferred.\r\n- [ ] All code follows the\r\n      [Scala](https://github.com/enso-org/enso/blob/develop/docs/style-guide/scala.md),\r\n      [Java](https://github.com/enso-org/enso/blob/develop/docs/style-guide/java.md),\r\n      [TypeScript](https://github.com/enso-org/enso/blob/develop/docs/style-guide/typescript.md),\r\n      and\r\n      [Rust](https://github.com/enso-org/enso/blob/develop/docs/style-guide/rust.md)\r\n      style guides. In case you are using a language not listed above, follow the [Rust](https://github.com/enso-org/enso/blob/develop/docs/style-guide/rust.md) style guide.\r\n- [ ] Unit tests have been written where possible.\r\n',
#     'created_at': '2024-09-25T08:02:24Z',
#     'updated_at': '2024-10-03T12:49:07Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '9c7ea67bc90dae721aee05af3eaa4534deee2204',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'radeusgd',
#       'id': 1436948,
#       'node_id': 'MDQ6VXNlcjE0MzY5NDg=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1436948?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/radeusgd',
#       'html_url': 'https://github.com/radeusgd',
#       'followers_url': 'https://api.github.com/users/radeusgd/followers',
#       'following_url': 'https://api.github.com/users/radeusgd/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/radeusgd/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/radeusgd/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/radeusgd/subscriptions',
#       'organizations_url': 'https://api.github.com/users/radeusgd/orgs',
#       'repos_url': 'https://api.github.com/users/radeusgd/repos',
#       'events_url': 'https://api.github.com/users/radeusgd/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/radeusgd/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'marthasharkey',
#       'id': 170310417,
#       'node_id': 'U_kgDOCia7EQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/170310417?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/marthasharkey',
#       'html_url': 'https://github.com/marthasharkey',
#       'followers_url': 'https://api.github.com/users/marthasharkey/followers',
#       'following_url': 'https://api.github.com/users/marthasharkey/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/marthasharkey/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/marthasharkey/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/marthasharkey/subscriptions',
#       'organizations_url': 'https://api.github.com/users/marthasharkey/orgs',
#       'repos_url': 'https://api.github.com/users/marthasharkey/repos',
#       'events_url': 'https://api.github.com/users/marthasharkey/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/marthasharkey/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [{'id': 4569515226,
#       'node_id': 'LA_kwDOBJHs388AAAABEF1E2g',
#       'url': 'https://api.github.com/repos/enso-org/enso/labels/CI:%20No%20changelog%20needed',
#       'name': 'CI: No changelog needed',
#       'color': 'ffffff',
#       'default': False,
#       'description': 'Do not require a changelog entry for this PR.'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/enso-org/enso/pulls/11163/commits',
#     'review_comments_url': 'https://api.github.com/repos/enso-org/enso/pulls/11163/comments',
#     'review_comment_url': 'https://api.github.com/repos/enso-org/enso/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/enso-org/enso/issues/11163/comments',
#     'statuses_url': 'https://api.github.com/repos/enso-org/enso/statuses/40d06cce37e659f8ca38bf4fb53bb1c125a23ad9',
#     'head': {'label': 'enso-org:wip/adr/add-db-feature-flags',
#      'ref': 'wip/adr/add-db-feature-flags',
#      'sha': '40d06cce37e659f8ca38bf4fb53bb1c125a23ad9',
#      'user': {'login': 'enso-org',
#       'id': 17415943,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3NDE1OTQz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/17415943?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/enso-org',
#       'html_url': 'https://github.com/enso-org',
#       'followers_url': 'https://api.github.com/users/enso-org/followers',
#       'following_url': 'https://api.github.com/users/enso-org/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/enso-org/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/enso-org/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/enso-org/subscriptions',
#       'organizations_url': 'https://api.github.com/users/enso-org/orgs',
#       'repos_url': 'https://api.github.com/users/enso-org/repos',
#       'events_url': 'https://api.github.com/users/enso-org/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/enso-org/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 76672223,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NjY3MjIyMw==',
#       'name': 'enso',
#       'full_name': 'enso-org/enso',
#       'private': False}},
#     'base': {'label': 'enso-org:develop',
#      'ref': 'develop',
#      'sha': '7f9cf7a916d82e1e5b16feb27c20969014964945',
#      'user': {'login': 'enso-org',
#       'id': 17415943,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3NDE1OTQz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/17415943?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/enso-org',
#       'html_url': 'https://github.com/enso-org',
#       'followers_url': 'https://api.github.com/users/enso-org/followers',
#       'following_url': 'https://api.github.com/users/enso-org/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/enso-org/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/enso-org/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/enso-org/subscriptions',
#       'organizations_url': 'https://api.github.com/users/enso-org/orgs',
#       'repos_url': 'https://api.github.com/users/enso-org/repos',
#       'events_url': 'https://api.github.com/users/enso-org/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/enso-org/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 76672223,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NjY3MjIyMw==',
#       'name': 'enso',
#       'full_name': 'enso-org/enso',
#       'private': False}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/enso-org/enso/pulls/11163'},
#      'html': {'href': 'https://github.com/enso-org/enso/pull/11163'},
#      'issue': {'href': 'https://api.github.com/repos/enso-org/enso/issues/11163'},
#      'comments': {'href': 'https://api.github.com/repos/enso-org/enso/issues/11163/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/enso-org/enso/pulls/11163/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/enso-org/enso/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/enso-org/enso/pulls/11163/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/enso-org/enso/statuses/40d06cce37e659f8ca38bf4fb53bb1c125a23ad9'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z',
#   'org': {'id': 17415943,
#    'login': 'enso-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/enso-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17415943?'}},
#  {'id': '42509437709',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 77981300,
#    'login': 'dgodinez-dh',
#    'display_login': 'dgodinez-dh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dgodinez-dh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77981300?'},
#   'repo': {'id': 688538805,
#    'name': 'deephaven/deephaven-plugins',
#    'url': 'https://api.github.com/repos/deephaven/deephaven-plugins'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments/1786168349',
#     'pull_request_review_id': 2345525731,
#     'id': 1786168349,
#     'node_id': 'PRRC_kwDOKQpEtc5qdsQd',
#     'diff_hunk': '@@ -374,6 +382,32 @@ def no_error_date_callable(date: Date) -> None:\n     return no_error_date_callable\n \n \n+def wrap_local_date_callable(\n+    date_callable: Callable[[LocalDateConvertible], None],\n+) -> Callable[[LocalDate], None]:\n+    """\n+    Wrap a callable to convert the Date argument to a Java date type.\n+    This maintains the original callable signature so that the Date argument can be dropped.\n+\n+    Args:\n+        date_callable: The callable to wrap.\n+        converter: The date converter to use.\n+\n+    Returns:\n+        The wrapped callable.\n+    """\n+    # When the user is typing a date, they may enter a value that does not parse\n+    # This will skip those errors rather than printing them to the screen\n+    def no_error_date_callable(date: LocalDateConvertible) -> None:\n+        wrapped_date_callable = wrap_callable(date_callable)\n+        try:\n+            wrapped_date_callable(to_j_local_date(date))\n+        except Exception:\n+            pass\n+',
#     'path': 'plugins/ui/src/deephaven/ui/_internal/utils.py',
#     'commit_id': 'a67c800012c357d61f8c13d695ec41fb3ae20deb',
#     'original_commit_id': '1766eda874b261149b460c334855c3b4979d8b55',
#     'user': {'login': 'dgodinez-dh',
#      'id': 77981300,
#      'node_id': 'MDQ6VXNlcjc3OTgxMzAw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/77981300?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dgodinez-dh',
#      'html_url': 'https://github.com/dgodinez-dh',
#      'followers_url': 'https://api.github.com/users/dgodinez-dh/followers',
#      'following_url': 'https://api.github.com/users/dgodinez-dh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dgodinez-dh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dgodinez-dh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dgodinez-dh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dgodinez-dh/orgs',
#      'repos_url': 'https://api.github.com/users/dgodinez-dh/repos',
#      'events_url': 'https://api.github.com/users/dgodinez-dh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dgodinez-dh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Do you mean create a new function called `_wrap_date_time_callable_skip_errors` that encapsulates the `try/except`? I'm not sure I see the advantage of this. I think it will create a bunch of single use functions that are only called in one place.",
#     'created_at': '2024-10-03T12:49:07Z',
#     'updated_at': '2024-10-03T12:49:07Z',
#     'html_url': 'https://github.com/deephaven/deephaven-plugins/pull/918#discussion_r1786168349',
#     'pull_request_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments/1786168349'},
#      'html': {'href': 'https://github.com/deephaven/deephaven-plugins/pull/918#discussion_r1786168349'},
#      'pull_request': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918'}},
#     'reactions': {'url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments/1786168349/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': 401,
#     'original_start_line': 401,
#     'start_side': 'RIGHT',
#     'line': 407,
#     'original_line': 407,
#     'side': 'RIGHT',
#     'in_reply_to_id': 1784942407,
#     'original_position': 43,
#     'position': 43,
#     'subject_type': 'line'},
#    'pull_request': {'url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918',
#     'id': 2102178306,
#     'node_id': 'PR_kwDOKQpEtc59TLIC',
#     'html_url': 'https://github.com/deephaven/deephaven-plugins/pull/918',
#     'diff_url': 'https://github.com/deephaven/deephaven-plugins/pull/918.diff',
#     'patch_url': 'https://github.com/deephaven/deephaven-plugins/pull/918.patch',
#     'issue_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/issues/918',
#     'number': 918,
#     'state': 'open',
#     'locked': False,
#     'title': 'feat: UI Calendar Component',
#     'user': {'login': 'dgodinez-dh',
#      'id': 77981300,
#      'node_id': 'MDQ6VXNlcjc3OTgxMzAw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/77981300?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dgodinez-dh',
#      'html_url': 'https://github.com/dgodinez-dh',
#      'followers_url': 'https://api.github.com/users/dgodinez-dh/followers',
#      'following_url': 'https://api.github.com/users/dgodinez-dh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dgodinez-dh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dgodinez-dh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dgodinez-dh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dgodinez-dh/orgs',
#      'repos_url': 'https://api.github.com/users/dgodinez-dh/repos',
#      'events_url': 'https://api.github.com/users/dgodinez-dh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dgodinez-dh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Closes https://github.com/deephaven/deephaven-plugins/issues/905 for implementation.\r\nCloses https://github.com/deephaven/deephaven-plugins/issues/851 for docs.',
#     'created_at': '2024-10-01T19:45:45Z',
#     'updated_at': '2024-10-03T12:49:07Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'accf4aca5171f1edc2086c9c60b81b0369ffcde3',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'margaretkennedy',
#       'id': 82049573,
#       'node_id': 'MDQ6VXNlcjgyMDQ5NTcz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/82049573?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/margaretkennedy',
#       'html_url': 'https://github.com/margaretkennedy',
#       'followers_url': 'https://api.github.com/users/margaretkennedy/followers',
#       'following_url': 'https://api.github.com/users/margaretkennedy/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/margaretkennedy/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/margaretkennedy/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/margaretkennedy/subscriptions',
#       'organizations_url': 'https://api.github.com/users/margaretkennedy/orgs',
#       'repos_url': 'https://api.github.com/users/margaretkennedy/repos',
#       'events_url': 'https://api.github.com/users/margaretkennedy/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/margaretkennedy/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918/commits',
#     'review_comments_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918/comments',
#     'review_comment_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/issues/918/comments',
#     'statuses_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/statuses/a67c800012c357d61f8c13d695ec41fb3ae20deb',
#     'head': {'label': 'dgodinez-dh:dag_Calendar',
#      'ref': 'dag_Calendar',
#      'sha': 'a67c800012c357d61f8c13d695ec41fb3ae20deb',
#      'user': {'login': 'dgodinez-dh',
#       'id': 77981300,
#       'node_id': 'MDQ6VXNlcjc3OTgxMzAw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/77981300?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dgodinez-dh',
#       'html_url': 'https://github.com/dgodinez-dh',
#       'followers_url': 'https://api.github.com/users/dgodinez-dh/followers',
#       'following_url': 'https://api.github.com/users/dgodinez-dh/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dgodinez-dh/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dgodinez-dh/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dgodinez-dh/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dgodinez-dh/orgs',
#       'repos_url': 'https://api.github.com/users/dgodinez-dh/repos',
#       'events_url': 'https://api.github.com/users/dgodinez-dh/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dgodinez-dh/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 832656531,
#       'node_id': 'R_kgDOMaFUkw',
#       'name': 'deephaven-plugins',
#       'full_name': 'dgodinez-dh/deephaven-plugins',
#       'private': False}},
#     'base': {'label': 'deephaven:main',
#      'ref': 'main',
#      'sha': '863655b391424bc23bf7fc50faaae28ef213c4a6',
#      'user': {'login': 'deephaven',
#       'id': 44370703,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MzcwNzAz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/44370703?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/deephaven',
#       'html_url': 'https://github.com/deephaven',
#       'followers_url': 'https://api.github.com/users/deephaven/followers',
#       'following_url': 'https://api.github.com/users/deephaven/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/deephaven/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/deephaven/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/deephaven/subscriptions',
#       'organizations_url': 'https://api.github.com/users/deephaven/orgs',
#       'repos_url': 'https://api.github.com/users/deephaven/repos',
#       'events_url': 'https://api.github.com/users/deephaven/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/deephaven/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 688538805,
#       'node_id': 'R_kgDOKQpEtQ',
#       'name': 'deephaven-plugins',
#       'full_name': 'deephaven/deephaven-plugins',
#       'private': False}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918'},
#      'html': {'href': 'https://github.com/deephaven/deephaven-plugins/pull/918'},
#      'issue': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/issues/918'},
#      'comments': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/issues/918/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/statuses/a67c800012c357d61f8c13d695ec41fb3ae20deb'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2024-10-03T12:49:07Z',
#   'org': {'id': 44370703,
#    'login': 'deephaven',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/deephaven',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44370703?'}},
#  {'id': '42509437654',
#   'type': 'PushEvent',
#   'actor': {'id': 28728982,
#    'login': 'GoncaloaaF',
#    'display_login': 'GoncaloaaF',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GoncaloaaF',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28728982?'},
#   'repo': {'id': 865819656,
#    'name': 'GoncaloaaF-ATEC/PIPL0923',
#    'url': 'https://api.github.com/repos/GoncaloaaF-ATEC/PIPL0923'},
#   'payload': {'repository_id': 865819656,
#    'push_id': 20536498616,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b2201d13d1bb9cfb995149ba21c3ae944c2a7a83',
#    'before': '2aa44aa327b966679e08b64ce58607f08ec6875a',
#    'commits': [{'sha': 'b2201d13d1bb9cfb995149ba21c3ae944c2a7a83',
#      'author': {'email': 'goncaloaaf@gmail.com', 'name': 'Gonçalo Feliciano'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GoncaloaaF-ATEC/PIPL0923/commits/b2201d13d1bb9cfb995149ba21c3ae944c2a7a83'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z',
#   'org': {'id': 172500943,
#    'login': 'GoncaloaaF-ATEC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/GoncaloaaF-ATEC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/172500943?'}},
#  {'id': '42509437663',
#   'type': 'PushEvent',
#   'actor': {'id': 63259982,
#    'login': 'JotaPrimo',
#    'display_login': 'JotaPrimo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JotaPrimo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63259982?'},
#   'repo': {'id': 866758374,
#    'name': 'JotaPrimo/selectores',
#    'url': 'https://api.github.com/repos/JotaPrimo/selectores'},
#   'payload': {'repository_id': 866758374,
#    'push_id': 20536498610,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4d35ab2d5ae472cd64a1352ac3813e161a2ad4a5',
#    'before': '7af0b9ecf3ef2d0208e49707d6a117e1ee21d7d3',
#    'commits': [{'sha': '4d35ab2d5ae472cd64a1352ac3813e161a2ad4a5',
#      'author': {'email': 'gestald118@email.com', 'name': 'jota santos'},
#      'message': '273. Información de las fronteras',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JotaPrimo/selectores/commits/4d35ab2d5ae472cd64a1352ac3813e161a2ad4a5'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z'},
#  {'id': '42509437632',
#   'type': 'CreateEvent',
#   'actor': {'id': 156696627,
#    'login': 'Ruslan0192',
#    'display_login': 'Ruslan0192',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ruslan0192',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/156696627?'},
#   'repo': {'id': 867094418,
#    'name': 'Ruslan0192/TradeVisualization',
#    'url': 'https://api.github.com/repos/Ruslan0192/TradeVisualization'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z'},
#  {'id': '42509437609',
#   'type': 'PushEvent',
#   'actor': {'id': 99333578,
#    'login': 'M7-M7-M7',
#    'display_login': 'M7-M7-M7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/M7-M7-M7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99333578?'},
#   'repo': {'id': 843638456,
#    'name': 'M7-M7-M7/m7777',
#    'url': 'https://api.github.com/repos/M7-M7-M7/m7777'},
#   'payload': {'repository_id': 843638456,
#    'push_id': 20536498595,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0ba3a81242b92ce1e86742427559e9431cf2e90a',
#    'before': '434fd260cb378c3b3ce81a817d4ba9b96d8a9654',
#    'commits': [{'sha': '0ba3a81242b92ce1e86742427559e9431cf2e90a',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Update files',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/M7-M7-M7/m7777/commits/0ba3a81242b92ce1e86742427559e9431cf2e90a'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z'},
#  {'id': '42509437606',
#   'type': 'PushEvent',
#   'actor': {'id': 97571741,
#    'login': 'alfianto21',
#    'display_login': 'alfianto21',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alfianto21',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97571741?'},
#   'repo': {'id': 864189659,
#    'name': 'alfianto21/poem.github.io',
#    'url': 'https://api.github.com/repos/alfianto21/poem.github.io'},
#   'payload': {'repository_id': 864189659,
#    'push_id': 20536498589,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '836e1073abb33ea17f1d41353928973b798e66b7',
#    'before': '3ce53a2dcee48a0f5ad9648be2952273072eaf32',
#    'commits': [{'sha': '836e1073abb33ea17f1d41353928973b798e66b7',
#      'author': {'email': '97571741+alfianto21@users.noreply.github.com',
#       'name': 'alfianto21'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alfianto21/poem.github.io/commits/836e1073abb33ea17f1d41353928973b798e66b7'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z'},
#  {'id': '42509437572',
#   'type': 'PushEvent',
#   'actor': {'id': 93773753,
#    'login': 'BlaaSwe',
#    'display_login': 'BlaaSwe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BlaaSwe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93773753?'},
#   'repo': {'id': 544882036,
#    'name': 'BlaaSwe/Trend-Soaring-1min',
#    'url': 'https://api.github.com/repos/BlaaSwe/Trend-Soaring-1min'},
#   'payload': {'repository_id': 544882036,
#    'push_id': 20536498581,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aff92883e792d72497a87e2a44a5a6b87010f746',
#    'before': '3eed84ed59dd38921eb8e7c40b51525f6fa40ce4',
#    'commits': [{'sha': 'aff92883e792d72497a87e2a44a5a6b87010f746',
#      'author': {'email': '93773753+BlaaSwe@users.noreply.github.com',
#       'name': 'Blaa'},
#      'message': 'Open Storage: New File.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/BlaaSwe/Trend-Soaring-1min/commits/aff92883e792d72497a87e2a44a5a6b87010f746'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z'},
#  {'id': '42509437593',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 661535205,
#    'name': 'thedoggybrad/easylist-mirror',
#    'url': 'https://api.github.com/repos/thedoggybrad/easylist-mirror'},
#   'payload': {'repository_id': 661535205,
#    'push_id': 20536498587,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fb6b6682d93640e883edf1ac17298f4d153f6cd5',
#    'before': '9e5513e280daa89ee1dd35cd1f92038dc164a50e',
#    'commits': [{'sha': 'fb6b6682d93640e883edf1ac17298f4d153f6cd5',
#      'author': {'email': '142152315+syncbot-easylistmirror@users.noreply.github.com',
#       'name': 'syncbot-easylistmirror'},
#      'message': 'Sync rolist.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/thedoggybrad/easylist-mirror/commits/fb6b6682d93640e883edf1ac17298f4d153f6cd5'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:08Z'},
#  {'id': '42509437582',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 637784737,
#    'name': 'equinor/nrresqml',
#    'url': 'https://api.github.com/repos/equinor/nrresqml'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/equinor/nrresqml/issues/17',
#     'repository_url': 'https://api.github.com/repos/equinor/nrresqml',
#     'labels_url': 'https://api.github.com/repos/equinor/nrresqml/issues/17/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/equinor/nrresqml/issues/17/comments',
#     'events_url': 'https://api.github.com/repos/equinor/nrresqml/issues/17/events',
#     'html_url': 'https://github.com/equinor/nrresqml/pull/17',
#     'id': 2563971127,
#     'node_id': 'PR_kwDOJgPSoc59fyh4',
#     'number': 17,
#     'title': 'chore(main): release 1.2.2',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
# ...
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '23308566f8c34a4b7781a90215b343788906629b',
#    'before': '8f44dfe9b6e97f360d5b05499ec8164017c32407',
#    'commits': [{'sha': '23308566f8c34a4b7781a90215b343788906629b',
#      'author': {'email': 'vince_voo@yahoo.com', 'name': 'Voo Tzuen Hau'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LiquidSi1k/LiquidSi1k/commits/23308566f8c34a4b7781a90215b343788906629b'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:07Z'},
#  {'id': '42509437418',
#   'type': 'PushEvent',
#   'actor': {'id': 125495087,
#    'login': 'ndahtems',
#    'display_login': 'ndahtems',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ndahtems',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125495087?'},
#   'repo': {'id': 858291574,
#    'name': 'ndahtems/Terraform-Jenkins',
#    'url': 'https://api.github.com/repos/ndahtems/Terraform-Jenkins'},
#   'payload': {'repository_id': 858291574,
#    'push_id': 20536498505,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '21250c8e7a370c35efad5d45f23da06f6be1ffbe',
#    'before': '8488ba297cf26b839a34106e01660c06fcbbfcd0',
#    'commits': [{'sha': '21250c8e7a370c35efad5d45f23da06f6be1ffbe',
#      'author': {'email': 'ndahtembi@gmail.com', 'name': 'Tembi'},
#      'message': 'updated repo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ndahtems/Terraform-Jenkins/commits/21250c8e7a370c35efad5d45f23da06f6be1ffbe'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:07Z'},
#  {'id': '42509437404',
#   'type': 'PushEvent',
#   'actor': {'id': 36563672,
#    'login': 'Mmx233',
#    'display_login': 'Mmx233',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mmx233',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36563672?'},
#   'repo': {'id': 850380663,
#    'name': 'Mmx233/BackoffCli',
#    'url': 'https://api.github.com/repos/Mmx233/BackoffCli'},
#   'payload': {'repository_id': 850380663,
#    'push_id': 20536498511,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '657194ccba996d0026c64db7b1f50c41483c3290',
#    'before': 'd3a8dd34d1ca34dd5879aeb9a3bd4756a281dd4f',
#    'commits': [{'sha': '657194ccba996d0026c64db7b1f50c41483c3290',
#      'author': {'email': 'green.dusk8264@fastmail.com', 'name': 'Mmx'},
#      'message': 'sync: backoff',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mmx233/BackoffCli/commits/657194ccba996d0026c64db7b1f50c41483c3290'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:07Z'},
#  {'id': '42509437414',
#   'type': 'PushEvent',
#   'actor': {'id': 76231708,
#    'login': 'nicholasalvesx',
#    'display_login': 'nicholasalvesx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nicholasalvesx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76231708?'},
#   'repo': {'id': 852190273,
#    'name': 'Ranbu100/Projeto-Estacionamento',
#    'url': 'https://api.github.com/repos/Ranbu100/Projeto-Estacionamento'},
#   'payload': {'repository_id': 852190273,
#    'push_id': 20536498520,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e70a98f5308ebd588e2a3763c9abc729bb11b808',
#    'before': '459fa0ff0c1b4d36e538d936d2781dc15e4da8a8',
#    'commits': [{'sha': 'e70a98f5308ebd588e2a3763c9abc729bb11b808',
#      'author': {'email': 'nicholas.alves2007@gmail.com', 'name': 'Nicholas'},
#      'message': 'att backend 3/10',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ranbu100/Projeto-Estacionamento/commits/e70a98f5308ebd588e2a3763c9abc729bb11b808'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:07Z'},
#  {'id': '42509437385',
#   'type': 'PushEvent',
#   'actor': {'id': 136606032,
#    'login': 'theanujsinha01',
#    'display_login': 'theanujsinha01',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/theanujsinha01',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136606032?'},
#   'repo': {'id': 867076636,
#    'name': 'theanujsinha01/Data-Analysis-Projects',
#    'url': 'https://api.github.com/repos/theanujsinha01/Data-Analysis-Projects'},
#   'payload': {'repository_id': 867076636,
#    'push_id': 20536498482,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1e3d3e1ace4d088361d04b56cd01ea07250f901e',
#    'before': '62be5faa7fb64327fe958eec3c96b0e1c87d2d3a',
#    'commits': [{'sha': '1e3d3e1ace4d088361d04b56cd01ea07250f901e',
#      'author': {'email': '136606032+theanujsinha01@users.noreply.github.com',
#       'name': 'Anuj Kumar'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/theanujsinha01/Data-Analysis-Projects/commits/1e3d3e1ace4d088361d04b56cd01ea07250f901e'}]},
#   'public': True,
#   'created_at': '2024-10-03T12:49:07Z'},
#  {'id': '42509437410',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 99863853,
#    'login': 'CodeItpython',
#    'display_login': 'CodeItpython',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CodeItpython',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99863853?'},
#   'repo': {'id': 862142178,
#    'name': 'prgrms-be-devcourse/NBE1_2_Team07',
#    'url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07'},
#   'payload': {'action': 'closed',
#    'number': 23,
#    'pull_request': {'url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23',
#     'id': 2102913367,
#     'node_id': 'PR_kwDOM2M-4s59V-lX',
#     'html_url': 'https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23',
#     'diff_url': 'https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23.diff',
#     'patch_url': 'https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23.patch',
#     'issue_url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/issues/23',
#     'number': 23,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Feat/#2 유저 회원가입 및 로그인 구현',
#     'user': {'login': 'CodeItpython',
#      'id': 99863853,
#      'node_id': 'U_kgDOBfPNLQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/99863853?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/CodeItpython',
#      'html_url': 'https://github.com/CodeItpython',
#      'followers_url': 'https://api.github.com/users/CodeItpython/followers',
#      'following_url': 'https://api.github.com/users/CodeItpython/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/CodeItpython/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/CodeItpython/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/CodeItpython/subscriptions',
#      'organizations_url': 'https://api.github.com/users/CodeItpython/orgs',
#      'repos_url': 'https://api.github.com/users/CodeItpython/repos',
#      'events_url': 'https://api.github.com/users/CodeItpython/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/CodeItpython/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '## 📌 과제 설명 <!-- 어떤 걸 만들었는지 대략적으로 설명해주세요 -->\r\n- #2 \r\n\r\n- 유저의 회원가입기능을 개발\r\n- 관리자계정과 일반사용자를 구분하여 회원가입\r\n- 이메일 인증을 통한 회원가입\r\n\r\n\r\n## 👩\u200d💻 요구 사항과 구현 내용 <!-- 기능을 Commit 별로 잘개 쪼개고, Commit 별로 설명해주세요 -->\r\n- 아이디 중복체크기능\r\n- 이메일 발송기능\r\n- 이메일 발송코드 검증기능\r\n- 회원가입기능(+ROLE_USER, ROLE_ADMIN 선택)\r\n- 로그인기능\r\n\r\n## ✅ PR 포인트 & 궁금한 점 <!-- 리뷰어 분들이 집중적으로 보셨으면 하는 내용을 적어주세요 -->\r\n- fe 코드와 함께 카카오, 네이버 로그인 구현 예정\r\n',
#     'created_at': '2024-10-02T08:11:37Z',
#     'updated_at': '2024-10-03T12:49:07Z',
#     'closed_at': '2024-10-03T12:49:06Z',
#     'merged_at': None,
#     'merge_commit_sha': '454e259127886ab88c560ce8af870232253e0341',
#     'assignee': {'login': 'CodeItpython',
#      'id': 99863853,
#      'node_id': 'U_kgDOBfPNLQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/99863853?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/CodeItpython',
#      'html_url': 'https://github.com/CodeItpython',
#      'followers_url': 'https://api.github.com/users/CodeItpython/followers',
#      'following_url': 'https://api.github.com/users/CodeItpython/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/CodeItpython/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/CodeItpython/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/CodeItpython/subscriptions',
#      'organizations_url': 'https://api.github.com/users/CodeItpython/orgs',
#      'repos_url': 'https://api.github.com/users/CodeItpython/repos',
#      'events_url': 'https://api.github.com/users/CodeItpython/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/CodeItpython/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'CodeItpython',
#       'id': 99863853,
#       'node_id': 'U_kgDOBfPNLQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/99863853?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/CodeItpython',
#       'html_url': 'https://github.com/CodeItpython',
#       'followers_url': 'https://api.github.com/users/CodeItpython/followers',
#       'following_url': 'https://api.github.com/users/CodeItpython/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/CodeItpython/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/CodeItpython/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/CodeItpython/subscriptions',
#       'organizations_url': 'https://api.github.com/users/CodeItpython/orgs',
#       'repos_url': 'https://api.github.com/users/CodeItpython/repos',
#       'events_url': 'https://api.github.com/users/CodeItpython/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/CodeItpython/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [],
#     'requested_teams': [{'name': 'BE1 07',
#       'id': 11082983,
#       'node_id': 'T_kwDOBT8X1M4AqRzn',
#       'slug': 'be1-07',
#       'description': '',
#       'privacy': 'closed',
#       'notification_setting': 'notifications_enabled',
#       'url': 'https://api.github.com/organizations/88020948/team/11082983',
#       'html_url': 'https://github.com/orgs/prgrms-be-devcourse/teams/be1-07',
#       'members_url': 'https://api.github.com/organizations/88020948/team/11082983/members{/member}',
#       'repositories_url': 'https://api.github.com/organizations/88020948/team/11082983/repos',
#       'permission': 'pull',
#       'parent': None}],
#     'labels': [{'id': 7508341557,
#       'node_id': 'LA_kwDOM2M-4s8AAAABv4gzNQ',
#       'url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/labels/Feat',
#       'name': 'Feat',
#       'color': '06CDC2',
#       'default': False,
#       'description': '새로운 기능 추가'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23/commits',
#     'review_comments_url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23/comments',
#     'review_comment_url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/issues/23/comments',
#     'statuses_url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/statuses/4a9841cace7a96a5cf430dc9589f319a4c2d6405',
#     'head': {'label': 'prgrms-be-devcourse:feat/#2',
#      'ref': 'feat/#2',
#      'sha': '4a9841cace7a96a5cf430dc9589f319a4c2d6405',
#      'user': {'login': 'prgrms-be-devcourse',
#       'id': 88020948,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg4MDIwOTQ4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/88020948?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/prgrms-be-devcourse',
#       'html_url': 'https://github.com/prgrms-be-devcourse',
#       'followers_url': 'https://api.github.com/users/prgrms-be-devcourse/followers',
#       'following_url': 'https://api.github.com/users/prgrms-be-devcourse/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/prgrms-be-devcourse/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/prgrms-be-devcourse/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/prgrms-be-devcourse/subscriptions',
#       'organizations_url': 'https://api.github.com/users/prgrms-be-devcourse/orgs',
#       'repos_url': 'https://api.github.com/users/prgrms-be-devcourse/repos',
#       'events_url': 'https://api.github.com/users/prgrms-be-devcourse/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/prgrms-be-devcourse/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 862142178,
#       'node_id': 'R_kgDOM2M-4g',
#       'name': 'NBE1_2_Team07',
#       'full_name': 'prgrms-be-devcourse/NBE1_2_Team07',
#       'private': False}},
#     'base': {'label': 'prgrms-be-devcourse:develop',
#      'ref': 'develop',
#      'sha': '6e5d4c3a3c16a858612d6ce4f081861fd12df6db',
#      'user': {'login': 'prgrms-be-devcourse',
#       'id': 88020948,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg4MDIwOTQ4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/88020948?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/prgrms-be-devcourse',
#       'html_url': 'https://github.com/prgrms-be-devcourse',
#       'followers_url': 'https://api.github.com/users/prgrms-be-devcourse/followers',
#       'following_url': 'https://api.github.com/users/prgrms-be-devcourse/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/prgrms-be-devcourse/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/prgrms-be-devcourse/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/prgrms-be-devcourse/subscriptions',
#       'organizations_url': 'https://api.github.com/users/prgrms-be-devcourse/orgs',
#       'repos_url': 'https://api.github.com/users/prgrms-be-devcourse/repos',
#       'events_url': 'https://api.github.com/users/prgrms-be-devcourse/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/prgrms-be-devcourse/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 862142178,
#       'node_id': 'R_kgDOM2M-4g',
#       'name': 'NBE1_2_Team07',
#       'full_name': 'prgrms-be-devcourse/NBE1_2_Team07',
#       'private': False}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23'},
#      'html': {'href': 'https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23'},
#      'issue': {'href': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/issues/23'},
#      'comments': {'href': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/issues/23/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/statuses/4a9841cace7a96a5cf430dc9589f319a4c2d6405'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 3,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 15,
#     'additions': 1559,
#     'deletions': 13,
#     'changed_files': 37}},
#   'public': True,
#   'created_at': '2024-10-03T12:49:07Z',
#   'org': {'id': 88020948,
#    'login': 'prgrms-be-devcourse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/prgrms-be-devcourse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88020948?'}}]

# %%
d_json = r.json()

# %%
type(d_json)
# Out:
# list

# %%
len(d_json)
# Out:
# 30

# %%
for text in d_json:
    print(text)
# Out:
# {'id': '42509437768', 'type': 'PushEvent', 'actor': {'id': 161367810, 'login': 'aimme14', 'display_login': 'aimme14', 'gravatar_id': '', 'url': 'https://api.github.com/users/aimme14', 'avatar_url': 'https://avatars.githubusercontent.com/u/161367810?'}, 'repo': {'id': 867058423, 'name': 'aimme14/estudio-primer-parcial', 'url': 'https://api.github.com/repos/aimme14/estudio-primer-parcial'}, 'payload': {'repository_id': 867058423, 'push_id': 20536498670, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'ef0c13c38c0a1be7ac4dd43331cd401a29d6c692', 'before': 'c015c1ee8f671a66b1f57824072ef8544a3460ad', 'commits': [{'sha': 'ef0c13c38c0a1be7ac4dd43331cd401a29d6c692', 'author': {'email': 'aylopezm@ufpso.edu.co', 'name': 'aime'}, 'message': 'estudio', 'distinct': True, 'url': 'https://api.github.com/repos/aimme14/estudio-primer-parcial/commits/ef0c13c38c0a1be7ac4dd43331cd401a29d6c692'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437745', 'type': 'IssueCommentEvent', 'actor': {'id': 178772239, 'login': 'suresh06-lv', 'display_login': 'suresh06-lv', 'gravatar_id': '', 'url': 'https://api.github.com/users/suresh06-lv', 'avatar_url': 'https://avatars.githubusercontent.com/u/178772239?'}, 'repo': {'id': 312372049, 'name': 'ni/grpc-labview', 'url': 'https://api.github.com/repos/ni/grpc-labview'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/ni/grpc-labview/issues/374', 'repository_url': 'https://api.github.com/repos/ni/grpc-labview', 'labels_url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/labels{/name}', 'comments_url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/comments', 'events_url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/events', 'html_url': 'https://github.com/ni/grpc-labview/issues/374', 'id': 2472747684, 'node_id': 'I_kwDOEp5rUc6TYyKk', 'number': 374, 'title': 'Error when connecting LabVIEW gRPC client to C# server', 'user': {'login': 'suresh06-lv', 'id': 178772239, 'node_id': 'U_kgDOCqfZDw', 'avatar_url': 'https://avatars.githubusercontent.com/u/178772239?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/suresh06-lv', 'html_url': 'https://github.com/suresh06-lv', 'followers_url': 'https://api.github.com/users/suresh06-lv/followers', 'following_url': 'https://api.github.com/users/suresh06-lv/following{/other_user}', 'gists_url': 'https://api.github.com/users/suresh06-lv/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/suresh06-lv/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/suresh06-lv/subscriptions', 'organizations_url': 'https://api.github.com/users/suresh06-lv/orgs', 'repos_url': 'https://api.github.com/users/suresh06-lv/repos', 'events_url': 'https://api.github.com/users/suresh06-lv/events{/privacy}', 'received_events_url': 'https://api.github.com/users/suresh06-lv/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 7, 'created_at': '2024-08-19T08:17:58Z', 'updated_at': '2024-10-03T12:49:08Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'body': '**Description**\r\nTimeout error when trying to connect LabVIEW gRPC client to C# gRPC Server.  \r\nEncountered this problem when attempting to use the LabVIEW client to simulate TestStand operations by connecting to a C# server.  This issue was first seen when trying to connect to the C# server provided in https://github.com/ni/grpc-teststand-api.  I discovered that the problem persists even with a basic C# greeter gRPC service.\r\n\r\n**Steps to Reproduce**\r\n1. Create a C# greeter service based on the tutorial from https://learn.microsoft.com/en-us/aspnet/core/tutorials/grpc/grpc-start?view=aspnetcore-8.0&tabs=visual-studio.\r\n2. Create a LabVIEW client using the proto file generated from step1.\r\n3. Build a sample gRPC client VI. \r\n4. Run the service.  \r\n5. Connect LabVIEW greeter client using the address shown in the terminal and Run VI.\r\n\r\n**Expected Result**\r\nGreeter response string concatenated with \'Hello\' as prefix to client message input.\r\n"Hello " + Client Message\r\n\r\n**Actual Result**\r\n![image](https://github.com/user-attachments/assets/677d5a1c-ec8a-4606-9914-be0c1ebf5aac)\r\n\r\n**Version**\r\nLabVIEW - 2023 Q3\r\n\r\n**Images**\r\n![image](https://github.com/user-attachments/assets/2546c951-08b0-4faf-808b-2abe5c9b3523)\r\n\r\n\r\nAB#2832543', 'reactions': {'url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/ni/grpc-labview/issues/374/timeline', 'performed_via_github_app': None, 'state_reason': None}, 'comment': {'url': 'https://api.github.com/repos/ni/grpc-labview/issues/comments/2391338408' ...
# {'id': '42509437723', 'type': 'PushEvent', 'actor': {'id': 29139614, 'login': 'renovate[bot]', 'display_login': 'renovate', 'gravatar_id': '', 'url': 'https://api.github.com/users/renovate[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'}, 'repo': {'id': 340385345, 'name': 'DFE-Digital/prepare-academy-conversions', 'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions'}, 'payload': {'repository_id': 340385345, 'push_id': 20536498633, 'size': 8, 'distinct_size': 1, 'ref': 'refs/heads/renovate/github.com-dfe-digital-terraform-azurerm-key-vault-tfvars-0.x', 'head': 'dddf95f9324652416706a60b96bb45a17b94060a', 'before': 'c0e85951efdb7bb1d08ec8a00dd19578edd573ab', 'commits': [{'sha': 'dd6f1a1e7e8d9338b21fb587f92db5bcc7db6f73', 'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK', 'name': 'SHAKIR, Muhammad'}, 'message': 'Updated cookie banner', 'distinct': False, 'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/dd6f1a1e7e8d9338b21fb587f92db5bcc7db6f73'}, {'sha': '1a5cdbd156811953899f7b4de6bae4f2abb648f3', 'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK', 'name': 'SHAKIR, Muhammad'}, 'message': 'Updated wording', 'distinct': False, 'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/1a5cdbd156811953899f7b4de6bae4f2abb648f3'}, {'sha': '068aa28e348f50626c6921e6762f11dda2655745', 'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK', 'name': 'SHAKIR, Muhammad'}, 'message': "Merge branch 'main' of https://github.com/DFE-Digital/prepare-academy-conversions into feature/182329-update-cookie-banner", 'distinct': False, 'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/068aa28e348f50626c6921e6762f11dda2655745'}, {'sha': '7859b8a5172942409b49306f65a30e4d41c934e1', 'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK', 'name': 'SHAKIR, Muhammad'}, 'message': 'Fixed tests and tidy up code', 'distinct': False, 'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/7859b8a5172942409b49306f65a30e4d41c934e1'}, {'sha': 'c20f8aead25eb2a4a10857a9bb4ce599f19cdb24', 'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK', 'name': 'SHAKIR, Muhammad'}, 'message': 'Fixed cypress tests', 'distinct': False, 'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/c20f8aead25eb2a4a10857a9bb4ce599f19cdb24'}, {'sha': '141022026e180091196a22216ff31f4f0d6faeda', 'author': {'email': 'Muhammad.SHAKIR@EDUCATION.GOV.UK', 'name': 'SHAKIR, Muhammad'}, 'message': 'Fixed tests', 'distinct': False, 'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/141022026e180091196a22216ff31f4f0d6faeda'}, {'sha': '465a0ead188ddc5a699444bcfb0beaf2291d4687', 'author': {'email': 'muhammad.shakir@education.gov.uk', 'name': 'mshakirdfe'}, 'message': 'Merge pull request #1199 from DFE-Digital/feature/182329-update-cookie-banner\n\nFeature/182329 update cookie banner', 'distinct': False, 'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/465a0ead188ddc5a699444bcfb0beaf2291d4687'}, {'sha': 'dddf95f9324652416706a60b96bb45a17b94060a', 'author': {'email': '29139614+renovate[bot]@users.noreply.github.com', 'name': 'renovate[bot]'}, 'message': 'Update Terraform github.com/DFE-Digital/terraform-azurerm-key-vault-tfvars to v0.5.0', 'distinct': True, 'url': 'https://api.github.com/repos/DFE-Digital/prepare-academy-conversions/commits/dddf95f9324652416706a60b96bb45a17b94060a'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z', 'org': {'id': 30029772, 'login': 'DFE-Digital', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DFE-Digital', 'avatar_url': 'https://avatars.githubusercontent.com/u/30029772?'}}
# {'id': '42509437737', 'type': 'CreateEvent', 'actor': {'id': 146189912, 'login': 'Shivanand-hulikatti', 'display_login': 'Shivanand-hulikatti', 'gravatar_id': '', 'url': 'https://api.github.com/users/Shivanand-hulikatti', 'avatar_url': 'https://avatars.githubusercontent.com/u/146189912?'}, 'repo': {'id': 867094419, 'name': 'Shivanand-hulikatti/assignmentsWebDev', 'url': 'https://api.github.com/repos/Shivanand-hulikatti/assignmentsWebDev'}, 'payload': {'ref': 'main', 'ref_type': 'branch', 'master_branch': 'main', 'description': None, 'pusher_type': 'user'}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437721', 'type': 'PushEvent', 'actor': {'id': 120438850, 'login': '1992513', 'display_login': '1992513', 'gravatar_id': '', 'url': 'https://api.github.com/users/1992513', 'avatar_url': 'https://avatars.githubusercontent.com/u/120438850?'}, 'repo': {'id': 583676719, 'name': '1992513/djy', 'url': 'https://api.github.com/repos/1992513/djy'}, 'payload': {'repository_id': 583676719, 'push_id': 20536498638, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '7383edd5acd7c16631e12174098076b0c5a63f6e', 'before': '1e93d5e1e3451f390fcc340cec047559ea4d9062', 'commits': [{'sha': '7383edd5acd7c16631e12174098076b0c5a63f6e', 'author': {'email': '120438850+1992513@users.noreply.github.com', 'name': '1992513'}, 'message': '2024-10-03', 'distinct': True, 'url': 'https://api.github.com/repos/1992513/djy/commits/7383edd5acd7c16631e12174098076b0c5a63f6e'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437720', 'type': 'PullRequestReviewEvent', 'actor': {'id': 1436948, 'login': 'radeusgd', 'display_login': 'radeusgd', 'gravatar_id': '', 'url': 'https://api.github.com/users/radeusgd', 'avatar_url': 'https://avatars.githubusercontent.com/u/1436948?'}, 'repo': {'id': 76672223, 'name': 'enso-org/enso', 'url': 'https://api.github.com/repos/enso-org/enso'}, 'payload': {'action': 'created', 'review': {'id': 2345525742, 'node_id': 'PRR_kwDOBJHs386LzeHu', 'user': {'login': 'radeusgd', 'id': 1436948, 'node_id': 'MDQ6VXNlcjE0MzY5NDg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1436948?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/radeusgd', 'html_url': 'https://github.com/radeusgd', 'followers_url': 'https://api.github.com/users/radeusgd/followers', 'following_url': 'https://api.github.com/users/radeusgd/following{/other_user}', 'gists_url': 'https://api.github.com/users/radeusgd/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/radeusgd/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/radeusgd/subscriptions', 'organizations_url': 'https://api.github.com/users/radeusgd/orgs', 'repos_url': 'https://api.github.com/users/radeusgd/repos', 'events_url': 'https://api.github.com/users/radeusgd/events{/privacy}', 'received_events_url': 'https://api.github.com/users/radeusgd/received_events', 'type': 'User', 'site_admin': False}, 'body': None, 'commit_id': '40d06cce37e659f8ca38bf4fb53bb1c125a23ad9', 'submitted_at': '2024-10-03T12:49:07Z', 'state': 'commented', 'html_url': 'https://github.com/enso-org/enso/pull/11163#pullrequestreview-2345525742', 'pull_request_url': 'https://api.github.com/repos/enso-org/enso/pulls/11163', 'author_association': 'MEMBER', '_links': {'html': {'href': 'https://github.com/enso-org/enso/pull/11163#pullrequestreview-2345525742'}, 'pull_request': {'href': 'https://api.github.com/repos/enso-org/enso/pulls/11163'}}}, 'pull_request': {'url': 'https://api.github.com/repos/enso-org/enso/pulls/11163', 'id': 2090749538, 'node_id': 'PR_kwDOBJHs3858nk5i', 'html_url': 'https://github.com/enso-org/enso/pull/11163', 'diff_url': 'https://github.com/enso-org/enso/pull/11163.diff', 'patch_url': 'https://github.com/enso-org/enso/pull/11163.patch', 'issue_url': 'https://api.github.com/repos/enso-org/enso/issues/11163', 'number': 11163, 'state': 'open', 'locked': False, 'title': 'Add DB_Table feature flags', 'user': {'login': 'AdRiley', 'id': 1720119, 'node_id': 'MDQ6VXNlcjE3MjAxMTk=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1720119?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/AdRiley', 'html_url': 'https://github.com/AdRiley', 'followers_url': 'https://api.github.com/users/AdRiley/followers', 'following_url': 'https://api.github.com/users/AdRiley/following{/other_user}', 'gists_url': 'https://api.github.com/users/AdRiley/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/AdRiley/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/AdRiley/subscriptions', 'organizations_url': 'https://api.github.com/users/AdRiley/orgs', 'repos_url': 'https://api.github.com/users/AdRiley/repos', 'events_url': 'https://api.github.com/users/AdRiley/events{/privacy}', 'received_events_url': 'https://api.github.com/users/AdRiley/received_events', 'type': 'User', 'site_admin': False}, 'body': '### Pull Request Description\r\n\r\nThis MR:\r\n- Introduces the framework for feature flags for the In Database processing engine\r\n- For everything other than SQLServer continues to have the same functionality and tests that they did before\r\n- For SQLServer removes all In-DB functionality other than being able to read a table and provides user friendly errors messages for all other In database funtionality\r\n\r\n### Important Notes\r\n\r\nNote the current set of flags may not be the final set and some of the flagging out of tests is probably coarser than it will eventually be. As we work through SQLServer enbaling fu ...
# {'id': '42509437709', 'type': 'PullRequestReviewCommentEvent', 'actor': {'id': 77981300, 'login': 'dgodinez-dh', 'display_login': 'dgodinez-dh', 'gravatar_id': '', 'url': 'https://api.github.com/users/dgodinez-dh', 'avatar_url': 'https://avatars.githubusercontent.com/u/77981300?'}, 'repo': {'id': 688538805, 'name': 'deephaven/deephaven-plugins', 'url': 'https://api.github.com/repos/deephaven/deephaven-plugins'}, 'payload': {'action': 'created', 'comment': {'url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments/1786168349', 'pull_request_review_id': 2345525731, 'id': 1786168349, 'node_id': 'PRRC_kwDOKQpEtc5qdsQd', 'diff_hunk': '@@ -374,6 +382,32 @@ def no_error_date_callable(date: Date) -> None:\n     return no_error_date_callable\n \n \n+def wrap_local_date_callable(\n+    date_callable: Callable[[LocalDateConvertible], None],\n+) -> Callable[[LocalDate], None]:\n+    """\n+    Wrap a callable to convert the Date argument to a Java date type.\n+    This maintains the original callable signature so that the Date argument can be dropped.\n+\n+    Args:\n+        date_callable: The callable to wrap.\n+        converter: The date converter to use.\n+\n+    Returns:\n+        The wrapped callable.\n+    """\n+    # When the user is typing a date, they may enter a value that does not parse\n+    # This will skip those errors rather than printing them to the screen\n+    def no_error_date_callable(date: LocalDateConvertible) -> None:\n+        wrapped_date_callable = wrap_callable(date_callable)\n+        try:\n+            wrapped_date_callable(to_j_local_date(date))\n+        except Exception:\n+            pass\n+', 'path': 'plugins/ui/src/deephaven/ui/_internal/utils.py', 'commit_id': 'a67c800012c357d61f8c13d695ec41fb3ae20deb', 'original_commit_id': '1766eda874b261149b460c334855c3b4979d8b55', 'user': {'login': 'dgodinez-dh', 'id': 77981300, 'node_id': 'MDQ6VXNlcjc3OTgxMzAw', 'avatar_url': 'https://avatars.githubusercontent.com/u/77981300?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dgodinez-dh', 'html_url': 'https://github.com/dgodinez-dh', 'followers_url': 'https://api.github.com/users/dgodinez-dh/followers', 'following_url': 'https://api.github.com/users/dgodinez-dh/following{/other_user}', 'gists_url': 'https://api.github.com/users/dgodinez-dh/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dgodinez-dh/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dgodinez-dh/subscriptions', 'organizations_url': 'https://api.github.com/users/dgodinez-dh/orgs', 'repos_url': 'https://api.github.com/users/dgodinez-dh/repos', 'events_url': 'https://api.github.com/users/dgodinez-dh/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dgodinez-dh/received_events', 'type': 'User', 'site_admin': False}, 'body': "Do you mean create a new function called `_wrap_date_time_callable_skip_errors` that encapsulates the `try/except`? I'm not sure I see the advantage of this. I think it will create a bunch of single use functions that are only called in one place.", 'created_at': '2024-10-03T12:49:07Z', 'updated_at': '2024-10-03T12:49:07Z', 'html_url': 'https://github.com/deephaven/deephaven-plugins/pull/918#discussion_r1786168349', 'pull_request_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918', 'author_association': 'CONTRIBUTOR', '_links': {'self': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments/1786168349'}, 'html': {'href': 'https://github.com/deephaven/deephaven-plugins/pull/918#discussion_r1786168349'}, 'pull_request': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918'}}, 'reactions': {'url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/comments/1786168349/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'start_line': 401, 'original_start_line': 401, 'start_side': 'RIGHT' ...
# {'id': '42509437654', 'type': 'PushEvent', 'actor': {'id': 28728982, 'login': 'GoncaloaaF', 'display_login': 'GoncaloaaF', 'gravatar_id': '', 'url': 'https://api.github.com/users/GoncaloaaF', 'avatar_url': 'https://avatars.githubusercontent.com/u/28728982?'}, 'repo': {'id': 865819656, 'name': 'GoncaloaaF-ATEC/PIPL0923', 'url': 'https://api.github.com/repos/GoncaloaaF-ATEC/PIPL0923'}, 'payload': {'repository_id': 865819656, 'push_id': 20536498616, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'b2201d13d1bb9cfb995149ba21c3ae944c2a7a83', 'before': '2aa44aa327b966679e08b64ce58607f08ec6875a', 'commits': [{'sha': 'b2201d13d1bb9cfb995149ba21c3ae944c2a7a83', 'author': {'email': 'goncaloaaf@gmail.com', 'name': 'Gonçalo Feliciano'}, 'message': 'Update README.md', 'distinct': True, 'url': 'https://api.github.com/repos/GoncaloaaF-ATEC/PIPL0923/commits/b2201d13d1bb9cfb995149ba21c3ae944c2a7a83'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z', 'org': {'id': 172500943, 'login': 'GoncaloaaF-ATEC', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/GoncaloaaF-ATEC', 'avatar_url': 'https://avatars.githubusercontent.com/u/172500943?'}}
# {'id': '42509437663', 'type': 'PushEvent', 'actor': {'id': 63259982, 'login': 'JotaPrimo', 'display_login': 'JotaPrimo', 'gravatar_id': '', 'url': 'https://api.github.com/users/JotaPrimo', 'avatar_url': 'https://avatars.githubusercontent.com/u/63259982?'}, 'repo': {'id': 866758374, 'name': 'JotaPrimo/selectores', 'url': 'https://api.github.com/repos/JotaPrimo/selectores'}, 'payload': {'repository_id': 866758374, 'push_id': 20536498610, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '4d35ab2d5ae472cd64a1352ac3813e161a2ad4a5', 'before': '7af0b9ecf3ef2d0208e49707d6a117e1ee21d7d3', 'commits': [{'sha': '4d35ab2d5ae472cd64a1352ac3813e161a2ad4a5', 'author': {'email': 'gestald118@email.com', 'name': 'jota santos'}, 'message': '273. Información de las fronteras', 'distinct': True, 'url': 'https://api.github.com/repos/JotaPrimo/selectores/commits/4d35ab2d5ae472cd64a1352ac3813e161a2ad4a5'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437632', 'type': 'CreateEvent', 'actor': {'id': 156696627, 'login': 'Ruslan0192', 'display_login': 'Ruslan0192', 'gravatar_id': '', 'url': 'https://api.github.com/users/Ruslan0192', 'avatar_url': 'https://avatars.githubusercontent.com/u/156696627?'}, 'repo': {'id': 867094418, 'name': 'Ruslan0192/TradeVisualization', 'url': 'https://api.github.com/repos/Ruslan0192/TradeVisualization'}, 'payload': {'ref': None, 'ref_type': 'repository', 'master_branch': 'main', 'description': None, 'pusher_type': 'user'}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437609', 'type': 'PushEvent', 'actor': {'id': 99333578, 'login': 'M7-M7-M7', 'display_login': 'M7-M7-M7', 'gravatar_id': '', 'url': 'https://api.github.com/users/M7-M7-M7', 'avatar_url': 'https://avatars.githubusercontent.com/u/99333578?'}, 'repo': {'id': 843638456, 'name': 'M7-M7-M7/m7777', 'url': 'https://api.github.com/repos/M7-M7-M7/m7777'}, 'payload': {'repository_id': 843638456, 'push_id': 20536498595, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '0ba3a81242b92ce1e86742427559e9431cf2e90a', 'before': '434fd260cb378c3b3ce81a817d4ba9b96d8a9654', 'commits': [{'sha': '0ba3a81242b92ce1e86742427559e9431cf2e90a', 'author': {'email': 'you@example.com', 'name': 'Your Name'}, 'message': 'Update files', 'distinct': True, 'url': 'https://api.github.com/repos/M7-M7-M7/m7777/commits/0ba3a81242b92ce1e86742427559e9431cf2e90a'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437606', 'type': 'PushEvent', 'actor': {'id': 97571741, 'login': 'alfianto21', 'display_login': 'alfianto21', 'gravatar_id': '', 'url': 'https://api.github.com/users/alfianto21', 'avatar_url': 'https://avatars.githubusercontent.com/u/97571741?'}, 'repo': {'id': 864189659, 'name': 'alfianto21/poem.github.io', 'url': 'https://api.github.com/repos/alfianto21/poem.github.io'}, 'payload': {'repository_id': 864189659, 'push_id': 20536498589, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '836e1073abb33ea17f1d41353928973b798e66b7', 'before': '3ce53a2dcee48a0f5ad9648be2952273072eaf32', 'commits': [{'sha': '836e1073abb33ea17f1d41353928973b798e66b7', 'author': {'email': '97571741+alfianto21@users.noreply.github.com', 'name': 'alfianto21'}, 'message': 'Update README.md', 'distinct': True, 'url': 'https://api.github.com/repos/alfianto21/poem.github.io/commits/836e1073abb33ea17f1d41353928973b798e66b7'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437572', 'type': 'PushEvent', 'actor': {'id': 93773753, 'login': 'BlaaSwe', 'display_login': 'BlaaSwe', 'gravatar_id': '', 'url': 'https://api.github.com/users/BlaaSwe', 'avatar_url': 'https://avatars.githubusercontent.com/u/93773753?'}, 'repo': {'id': 544882036, 'name': 'BlaaSwe/Trend-Soaring-1min', 'url': 'https://api.github.com/repos/BlaaSwe/Trend-Soaring-1min'}, 'payload': {'repository_id': 544882036, 'push_id': 20536498581, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'aff92883e792d72497a87e2a44a5a6b87010f746', 'before': '3eed84ed59dd38921eb8e7c40b51525f6fa40ce4', 'commits': [{'sha': 'aff92883e792d72497a87e2a44a5a6b87010f746', 'author': {'email': '93773753+BlaaSwe@users.noreply.github.com', 'name': 'Blaa'}, 'message': 'Open Storage: New File.', 'distinct': True, 'url': 'https://api.github.com/repos/BlaaSwe/Trend-Soaring-1min/commits/aff92883e792d72497a87e2a44a5a6b87010f746'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437593', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 661535205, 'name': 'thedoggybrad/easylist-mirror', 'url': 'https://api.github.com/repos/thedoggybrad/easylist-mirror'}, 'payload': {'repository_id': 661535205, 'push_id': 20536498587, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'fb6b6682d93640e883edf1ac17298f4d153f6cd5', 'before': '9e5513e280daa89ee1dd35cd1f92038dc164a50e', 'commits': [{'sha': 'fb6b6682d93640e883edf1ac17298f4d153f6cd5', 'author': {'email': '142152315+syncbot-easylistmirror@users.noreply.github.com', 'name': 'syncbot-easylistmirror'}, 'message': 'Sync rolist.txt', 'distinct': True, 'url': 'https://api.github.com/repos/thedoggybrad/easylist-mirror/commits/fb6b6682d93640e883edf1ac17298f4d153f6cd5'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437582', 'type': 'IssueCommentEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 637784737, 'name': 'equinor/nrresqml', 'url': 'https://api.github.com/repos/equinor/nrresqml'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/equinor/nrresqml/issues/17', 'repository_url': 'https://api.github.com/repos/equinor/nrresqml', 'labels_url': 'https://api.github.com/repos/equinor/nrresqml/issues/17/labels{/name}', 'comments_url': 'https://api.github.com/repos/equinor/nrresqml/issues/17/comments', 'events_url': 'https://api.github.com/repos/equinor/nrresqml/issues/17/events', 'html_url': 'https://github.com/equinor/nrresqml/pull/17', 'id': 2563971127, 'node_id': 'PR_kwDOJgPSoc59fyh4', 'number': 17, 'title': 'chore(main): release 1.2.2', 'user': {'login': 'github-actions[bot]', 'id': 41898282, 'node_id': 'MDM6Qm90NDE4OTgyODI=', 'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions%5Bbot%5D', 'html_url': 'https://github.com/apps/github-actions', 'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers', 'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}', 'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions', 'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs', 'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos', 'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}', 'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events', 'type': 'Bot', 'site_admin': False}, 'labels': [{'id': 5927284411, 'node_id': 'LA_kwDOJgPSoc8AAAABYUsuuw', 'url': 'https://api.github.com/repos/equinor/nrresqml/labels/autorelease:%20tagged', 'name': 'autorelease: tagged', 'color': 'ededed', 'default': False, 'description': None}], 'state': 'closed', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-10-03T12:45:01Z', 'updated_at': '2024-10-03T12:49:08Z', 'closed_at': '2024-10-03T12:48:53Z', 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/equinor/nrresqml/pulls/17', 'html_url': 'https://github.com/equinor/nrresqml/pull/17', 'diff_url': 'https://github.com/equinor/nrresqml/pull/17.diff', 'patch_url': 'https://github.com/equinor/nrresqml/pull/17.patch', 'merged_at': '2024-10-03T12:48:53Z'}, 'body': ':robot: I have created a release *beep* *boop*\n---\n\n\n## [1.2.2](https://github.com/equinor/nrresqml/compare/v1.2.1...v1.2.2) (2024-10-03)\n\n\n### Bug Fixes\n\n* Fix issue with wrong archel count ([ca78d67](https://github.com/equinor/nrresqml/commit/ca78d677e6f904b87034e492fb691ee2dcf3c797))\n\n---\nThis PR was generated with [Release Please](https://github.com/googleapis/release-please). See [documentation](https://github.com/googleapis/release-please#release-please).', 'reactions': {'url': 'https://api.github.com/repos/equinor/nrresqml/issues/17/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/equinor/nrresqml/issues/17/timeline', 'performed_via_github_app': None, 'state_reason': None}, 'comment': {'url': 'https://api.github.com/repos/equinor/nrresqml/issues/comments/2391338412', 'html_url': 'https://github.com/equinor/nrresqml/pull/17#issuecomment-2391338412', 'issue_url': 'https:// ...
# {'id': '42509437561', 'type': 'IssueCommentEvent', 'actor': {'id': 107444360, 'login': 'ocpdocs-previewbot', 'display_login': 'ocpdocs-previewbot', 'gravatar_id': '', 'url': 'https://api.github.com/users/ocpdocs-previewbot', 'avatar_url': 'https://avatars.githubusercontent.com/u/107444360?'}, 'repo': {'id': 21740844, 'name': 'openshift/openshift-docs', 'url': 'https://api.github.com/repos/openshift/openshift-docs'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/openshift/openshift-docs/issues/82959', 'repository_url': 'https://api.github.com/repos/openshift/openshift-docs', 'labels_url': 'https://api.github.com/repos/openshift/openshift-docs/issues/82959/labels{/name}', 'comments_url': 'https://api.github.com/repos/openshift/openshift-docs/issues/82959/comments', 'events_url': 'https://api.github.com/repos/openshift/openshift-docs/issues/82959/events', 'html_url': 'https://github.com/openshift/openshift-docs/pull/82959', 'id': 2563941042, 'node_id': 'PR_kwDOAUu9LM59fsEZ', 'number': 82959, 'title': "OBSDOCS-1356/TRACING-4621: Max's edit", 'user': {'login': 'max-cx', 'id': 78564304, 'node_id': 'MDQ6VXNlcjc4NTY0MzA0', 'avatar_url': 'https://avatars.githubusercontent.com/u/78564304?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/max-cx', 'html_url': 'https://github.com/max-cx', 'followers_url': 'https://api.github.com/users/max-cx/followers', 'following_url': 'https://api.github.com/users/max-cx/following{/other_user}', 'gists_url': 'https://api.github.com/users/max-cx/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/max-cx/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/max-cx/subscriptions', 'organizations_url': 'https://api.github.com/users/max-cx/orgs', 'repos_url': 'https://api.github.com/users/max-cx/repos', 'events_url': 'https://api.github.com/users/max-cx/events{/privacy}', 'received_events_url': 'https://api.github.com/users/max-cx/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 751797317, 'node_id': 'MDU6TGFiZWw3NTE3OTczMTc=', 'url': 'https://api.github.com/repos/openshift/openshift-docs/labels/size/L', 'name': 'size/L', 'color': 'ee9900', 'default': False, 'description': 'Denotes a PR that changes 100-499 lines, ignoring generated files.'}, {'id': 4969762889, 'node_id': 'LA_kwDOAUu9LM8AAAABKDiQSQ', 'url': 'https://api.github.com/repos/openshift/openshift-docs/labels/jira/valid-reference', 'name': 'jira/valid-reference', 'color': '15dd18', 'default': False, 'description': 'Indicates that this PR references a valid Jira ticket of any type.'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 3, 'created_at': '2024-10-03T12:33:15Z', 'updated_at': '2024-10-03T12:49:07Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/openshift/openshift-docs/pulls/82959', 'html_url': 'https://github.com/openshift/openshift-docs/pull/82959', 'diff_url': 'https://github.com/openshift/openshift-docs/pull/82959.diff', 'patch_url': 'https://github.com/openshift/openshift-docs/pull/82959.patch', 'merged_at': None}, 'body': "- [TRACING-4621](https://issues.redhat.com//browse/TRACING-4621): add troubleshooting guide for Instrumentation\n- Fix CI\n- Apply changes requested in code review\n- Fix exporter name\n- Fix CI\n- Max's edit\n\n<!--- PR title format: [GH#<gh-issue-id>][BZ#<bz-issue-id>][OCPBUGS#<jira-issue-id>][OSDOCS#<jira-issue-id>]: <short-description-of-the-pr> --->\n\n<!--- If your changes apply to the latest release and/or in-development version of OpenShift, open your PR against the `main` branch.\n\n* For more details about the information requested in this template, see:\n  https://github.com/openshift/openshift-docs/blob/main/contributing_to_docs/create_or_edit_content.adoc#submit-PR --->\n\nVersion(s):\n<!--- Specify the version or versions of OpenShift your PR  ...
# {'id': '42509437544', 'type': 'IssueCommentEvent', 'actor': {'id': 2588851, 'login': 'jansol', 'display_login': 'jansol', 'gravatar_id': '', 'url': 'https://api.github.com/users/jansol', 'avatar_url': 'https://avatars.githubusercontent.com/u/2588851?'}, 'repo': {'id': 340547520, 'name': 'zed-industries/zed', 'url': 'https://api.github.com/repos/zed-industries/zed'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/zed-industries/zed/issues/18524', 'repository_url': 'https://api.github.com/repos/zed-industries/zed', 'labels_url': 'https://api.github.com/repos/zed-industries/zed/issues/18524/labels{/name}', 'comments_url': 'https://api.github.com/repos/zed-industries/zed/issues/18524/comments', 'events_url': 'https://api.github.com/repos/zed-industries/zed/issues/18524/events', 'html_url': 'https://github.com/zed-industries/zed/issues/18524', 'id': 2555478052, 'node_id': 'I_kwDOFExXwM6YUYAk', 'number': 18524, 'title': 'Allow a way to apply color to a regex pattern', 'user': {'login': 'johnfercher', 'id': 4752636, 'node_id': 'MDQ6VXNlcjQ3NTI2MzY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4752636?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/johnfercher', 'html_url': 'https://github.com/johnfercher', 'followers_url': 'https://api.github.com/users/johnfercher/followers', 'following_url': 'https://api.github.com/users/johnfercher/following{/other_user}', 'gists_url': 'https://api.github.com/users/johnfercher/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/johnfercher/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/johnfercher/subscriptions', 'organizations_url': 'https://api.github.com/users/johnfercher/orgs', 'repos_url': 'https://api.github.com/users/johnfercher/repos', 'events_url': 'https://api.github.com/users/johnfercher/events{/privacy}', 'received_events_url': 'https://api.github.com/users/johnfercher/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 2756624492, 'node_id': 'MDU6TGFiZWwyNzU2NjI0NDky', 'url': 'https://api.github.com/repos/zed-industries/zed/labels/enhancement', 'name': 'enhancement', 'color': 'B47B9E', 'default': True, 'description': '[core label]'}, {'id': 6463186616, 'node_id': 'LA_kwDOFExXwM8AAAABgTxmuA', 'url': 'https://api.github.com/repos/zed-industries/zed/labels/triage', 'name': 'triage', 'color': 'c2e0c6', 'default': False, 'description': 'Maintainer needs to classify the issue'}, {'id': 6463186785, 'node_id': 'LA_kwDOFExXwM8AAAABgTxnYQ', 'url': 'https://api.github.com/repos/zed-industries/zed/labels/admin%20read', 'name': 'admin read', 'color': '0e8a16', 'default': False, 'description': 'Pending admin review'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 3, 'created_at': '2024-09-30T04:03:19Z', 'updated_at': '2024-10-03T12:49:07Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'body': '### Check for existing issues\n\n- [X] Completed\n\n### Describe the feature\n\nI want to change de color of some items, which I could not change based on examples.\r\n\r\n![Screenshot from 2024-09-30 00-51-37](https://github.com/user-attachments/assets/6b9290c8-0bdd-4ac1-a623-5dee680c1ee6)\r\n\r\n1. `package main` : I want to change the **main** color, in this scenario that is a package. (Kinda a namespace in other languages than Go)\r\n2. `http2 "import"`: I want to change the **http2** color, in this scenario that is an alias.\r\n3. `context.TODO()`, `os.Args` or `anything.Something`:  when there is a scenario where I have `anything.Something`, I would like to be able to change the `anything` color. This kinda based on a bunch of themes from other APIs of Golang.\r\n4. `if err != nil`: I would like to be able to change the color of some keyworkds. Kinda, `nil = purple`, `string == green` and etc.\r\n\n\n### If applicable, add mockups / screenshots to help present your vision of the feature\n\n\n_No resp ...
# {'id': '42509437532', 'type': 'PullRequestReviewEvent', 'actor': {'id': 77981300, 'login': 'dgodinez-dh', 'display_login': 'dgodinez-dh', 'gravatar_id': '', 'url': 'https://api.github.com/users/dgodinez-dh', 'avatar_url': 'https://avatars.githubusercontent.com/u/77981300?'}, 'repo': {'id': 688538805, 'name': 'deephaven/deephaven-plugins', 'url': 'https://api.github.com/repos/deephaven/deephaven-plugins'}, 'payload': {'action': 'created', 'review': {'id': 2345525731, 'node_id': 'PRR_kwDOKQpEtc6LzeHj', 'user': {'login': 'dgodinez-dh', 'id': 77981300, 'node_id': 'MDQ6VXNlcjc3OTgxMzAw', 'avatar_url': 'https://avatars.githubusercontent.com/u/77981300?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dgodinez-dh', 'html_url': 'https://github.com/dgodinez-dh', 'followers_url': 'https://api.github.com/users/dgodinez-dh/followers', 'following_url': 'https://api.github.com/users/dgodinez-dh/following{/other_user}', 'gists_url': 'https://api.github.com/users/dgodinez-dh/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dgodinez-dh/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dgodinez-dh/subscriptions', 'organizations_url': 'https://api.github.com/users/dgodinez-dh/orgs', 'repos_url': 'https://api.github.com/users/dgodinez-dh/repos', 'events_url': 'https://api.github.com/users/dgodinez-dh/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dgodinez-dh/received_events', 'type': 'User', 'site_admin': False}, 'body': None, 'commit_id': '1766eda874b261149b460c334855c3b4979d8b55', 'submitted_at': '2024-10-03T12:49:07Z', 'state': 'commented', 'html_url': 'https://github.com/deephaven/deephaven-plugins/pull/918#pullrequestreview-2345525731', 'pull_request_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918', 'author_association': 'CONTRIBUTOR', '_links': {'html': {'href': 'https://github.com/deephaven/deephaven-plugins/pull/918#pullrequestreview-2345525731'}, 'pull_request': {'href': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918'}}}, 'pull_request': {'url': 'https://api.github.com/repos/deephaven/deephaven-plugins/pulls/918', 'id': 2102178306, 'node_id': 'PR_kwDOKQpEtc59TLIC', 'html_url': 'https://github.com/deephaven/deephaven-plugins/pull/918', 'diff_url': 'https://github.com/deephaven/deephaven-plugins/pull/918.diff', 'patch_url': 'https://github.com/deephaven/deephaven-plugins/pull/918.patch', 'issue_url': 'https://api.github.com/repos/deephaven/deephaven-plugins/issues/918', 'number': 918, 'state': 'open', 'locked': False, 'title': 'feat: UI Calendar Component', 'user': {'login': 'dgodinez-dh', 'id': 77981300, 'node_id': 'MDQ6VXNlcjc3OTgxMzAw', 'avatar_url': 'https://avatars.githubusercontent.com/u/77981300?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dgodinez-dh', 'html_url': 'https://github.com/dgodinez-dh', 'followers_url': 'https://api.github.com/users/dgodinez-dh/followers', 'following_url': 'https://api.github.com/users/dgodinez-dh/following{/other_user}', 'gists_url': 'https://api.github.com/users/dgodinez-dh/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dgodinez-dh/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dgodinez-dh/subscriptions', 'organizations_url': 'https://api.github.com/users/dgodinez-dh/orgs', 'repos_url': 'https://api.github.com/users/dgodinez-dh/repos', 'events_url': 'https://api.github.com/users/dgodinez-dh/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dgodinez-dh/received_events', 'type': 'User', 'site_admin': False}, 'body': 'Closes https://github.com/deephaven/deephaven-plugins/issues/905 for implementation.\r\nCloses https://github.com/deephaven/deephaven-plugins/issues/851 for docs.', 'created_at': '2024-10-01T19:45:45Z', 'updated_at': '2024-10-03T12:49:07Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': 'accf4aca5171f1edc2086c9c60b81b0369ffcde3', 'assignee': None, 'assignees': [], 'requested_r ...
# {'id': '42509437556', 'type': 'CreateEvent', 'actor': {'id': 118344674, 'login': 'github-merge-queue[bot]', 'display_login': 'github-merge-queue', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-merge-queue[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/118344674?'}, 'repo': {'id': 297302063, 'name': 'memgraph/memgraph', 'url': 'https://api.github.com/repos/memgraph/memgraph'}, 'payload': {'ref': 'gh-readonly-queue/master/pr-2358-75e0224a6782b7bbc60b114a7cb04884cb22f1db', 'ref_type': 'branch', 'master_branch': 'master', 'description': 'Open-source graph database, tuned for dynamic analytics environments. Easy to adopt, scale and own.', 'pusher_type': 'user'}, 'public': True, 'created_at': '2024-10-03T12:49:08Z', 'org': {'id': 17707542, 'login': 'memgraph', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/memgraph', 'avatar_url': 'https://avatars.githubusercontent.com/u/17707542?'}}
# {'id': '42509437527', 'type': 'IssueCommentEvent', 'actor': {'id': 22429695, 'login': 'codecov[bot]', 'display_login': 'codecov', 'gravatar_id': '', 'url': 'https://api.github.com/users/codecov[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/22429695?'}, 'repo': {'id': 120805786, 'name': 'tskit-dev/tskit', 'url': 'https://api.github.com/repos/tskit-dev/tskit'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/tskit-dev/tskit/issues/3007', 'repository_url': 'https://api.github.com/repos/tskit-dev/tskit', 'labels_url': 'https://api.github.com/repos/tskit-dev/tskit/issues/3007/labels{/name}', 'comments_url': 'https://api.github.com/repos/tskit-dev/tskit/issues/3007/comments', 'events_url': 'https://api.github.com/repos/tskit-dev/tskit/issues/3007/events', 'html_url': 'https://github.com/tskit-dev/tskit/pull/3007', 'id': 2563966067, 'node_id': 'PR_kwDOBzNZms59fxjr', 'number': 3007, 'title': 'Add title attributes to SVG symbols', 'user': {'login': 'hyanwong', 'id': 4699014, 'node_id': 'MDQ6VXNlcjQ2OTkwMTQ=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4699014?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/hyanwong', 'html_url': 'https://github.com/hyanwong', 'followers_url': 'https://api.github.com/users/hyanwong/followers', 'following_url': 'https://api.github.com/users/hyanwong/following{/other_user}', 'gists_url': 'https://api.github.com/users/hyanwong/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/hyanwong/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/hyanwong/subscriptions', 'organizations_url': 'https://api.github.com/users/hyanwong/orgs', 'repos_url': 'https://api.github.com/users/hyanwong/repos', 'events_url': 'https://api.github.com/users/hyanwong/events{/privacy}', 'received_events_url': 'https://api.github.com/users/hyanwong/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-10-03T12:43:27Z', 'updated_at': '2024-10-03T12:49:07Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/tskit-dev/tskit/pulls/3007', 'html_url': 'https://github.com/tskit-dev/tskit/pull/3007', 'diff_url': 'https://github.com/tskit-dev/tskit/pull/3007.diff', 'patch_url': 'https://github.com/tskit-dev/tskit/pull/3007.patch', 'merged_at': None}, 'body': 'So we can reveal node and mutation details on SVG mouseover\r\n', 'reactions': {'url': 'https://api.github.com/repos/tskit-dev/tskit/issues/3007/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/tskit-dev/tskit/issues/3007/timeline', 'performed_via_github_app': None, 'state_reason': None}, 'comment': {'url': 'https://api.github.com/repos/tskit-dev/tskit/issues/comments/2391338387', 'html_url': 'https://github.com/tskit-dev/tskit/pull/3007#issuecomment-2391338387', 'issue_url': 'https://api.github.com/repos/tskit-dev/tskit/issues/3007', 'id': 2391338387, 'node_id': 'IC_kwDOBzNZms6OiO2T', 'user': {'login': 'codecov[bot]', 'id': 22429695, 'node_id': 'MDM6Qm90MjI0Mjk2OTU=', 'avatar_url': 'https://avatars.githubusercontent.com/in/254?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/codecov%5Bbot%5D', 'html_url': 'https://github.com/apps/codecov', 'followers_url': 'https://api.github.com/users/codecov%5Bbot%5D/followers', 'following_url': 'https://api.github.com/users/codecov%5Bbot%5D/following{/other_user}', 'gists_url': 'https://api.github.com/users/codecov%5Bbot%5D/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/codecov%5Bbot%5D/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/codecov%5Bbot%5D/subscriptions', 'organizations_url': 'https://api.github.com/users/codecov%5Bbot%5D/orgs ...
# {'id': '42509437503', 'type': 'CreateEvent', 'actor': {'id': 156696627, 'login': 'Ruslan0192', 'display_login': 'Ruslan0192', 'gravatar_id': '', 'url': 'https://api.github.com/users/Ruslan0192', 'avatar_url': 'https://avatars.githubusercontent.com/u/156696627?'}, 'repo': {'id': 867094418, 'name': 'Ruslan0192/TradeVisualization', 'url': 'https://api.github.com/repos/Ruslan0192/TradeVisualization'}, 'payload': {'ref': 'main', 'ref_type': 'branch', 'master_branch': 'main', 'description': None, 'pusher_type': 'user'}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437523', 'type': 'CreateEvent', 'actor': {'id': 131700992, 'login': 'Chrissankov', 'display_login': 'Chrissankov', 'gravatar_id': '', 'url': 'https://api.github.com/users/Chrissankov', 'avatar_url': 'https://avatars.githubusercontent.com/u/131700992?'}, 'repo': {'id': 867092177, 'name': 'Chrissankov/Responsive-Shopping-Cart-with-Modal-Confirmation-using-React', 'url': 'https://api.github.com/repos/Chrissankov/Responsive-Shopping-Cart-with-Modal-Confirmation-using-React'}, 'payload': {'ref': 'main', 'ref_type': 'branch', 'master_branch': 'main', 'description': 'A responsive shopping cart built with React, featuring a modal confirmation dialog for viewing selected items and confirming checkout, optimized for all screen sizes.', 'pusher_type': 'user'}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437475', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 460805243, 'name': 'luanjubica/statuspage', 'url': 'https://api.github.com/repos/luanjubica/statuspage'}, 'payload': {'repository_id': 460805243, 'push_id': 20536498537, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '7a50257fda104fcf18470c20a2e5a0735d3399f0', 'before': '07c439bf5c7d5284e54f6cc9fb3c6aef50912956', 'commits': [{'sha': '7a50257fda104fcf18470c20a2e5a0735d3399f0', 'author': {'email': 'luanjubica@gmail.com', 'name': 'Luan Jubica'}, 'message': '[Automated] Update Health Check Logs', 'distinct': True, 'url': 'https://api.github.com/repos/luanjubica/statuspage/commits/7a50257fda104fcf18470c20a2e5a0735d3399f0'}]}, 'public': True, 'created_at': '2024-10-03T12:49:08Z'}
# {'id': '42509437451', 'type': 'CreateEvent', 'actor': {'id': 104969449, 'login': 'vishal230503', 'display_login': 'vishal230503', 'gravatar_id': '', 'url': 'https://api.github.com/users/vishal230503', 'avatar_url': 'https://avatars.githubusercontent.com/u/104969449?'}, 'repo': {'id': 867094417, 'name': 'vishal230503/terraform-repo', 'url': 'https://api.github.com/repos/vishal230503/terraform-repo'}, 'payload': {'ref': None, 'ref_type': 'repository', 'master_branch': 'main', 'description': None, 'pusher_type': 'user'}, 'public': True, 'created_at': '2024-10-03T12:49:07Z'}
# {'id': '42509437405', 'type': 'PushEvent', 'actor': {'id': 111508010, 'login': 'LiquidSi1k', 'display_login': 'LiquidSi1k', 'gravatar_id': '', 'url': 'https://api.github.com/users/LiquidSi1k', 'avatar_url': 'https://avatars.githubusercontent.com/u/111508010?'}, 'repo': {'id': 867093144, 'name': 'LiquidSi1k/LiquidSi1k', 'url': 'https://api.github.com/repos/LiquidSi1k/LiquidSi1k'}, 'payload': {'repository_id': 867093144, 'push_id': 20536498509, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '23308566f8c34a4b7781a90215b343788906629b', 'before': '8f44dfe9b6e97f360d5b05499ec8164017c32407', 'commits': [{'sha': '23308566f8c34a4b7781a90215b343788906629b', 'author': {'email': 'vince_voo@yahoo.com', 'name': 'Voo Tzuen Hau'}, 'message': 'Update README.md', 'distinct': True, 'url': 'https://api.github.com/repos/LiquidSi1k/LiquidSi1k/commits/23308566f8c34a4b7781a90215b343788906629b'}]}, 'public': True, 'created_at': '2024-10-03T12:49:07Z'}
# {'id': '42509437418', 'type': 'PushEvent', 'actor': {'id': 125495087, 'login': 'ndahtems', 'display_login': 'ndahtems', 'gravatar_id': '', 'url': 'https://api.github.com/users/ndahtems', 'avatar_url': 'https://avatars.githubusercontent.com/u/125495087?'}, 'repo': {'id': 858291574, 'name': 'ndahtems/Terraform-Jenkins', 'url': 'https://api.github.com/repos/ndahtems/Terraform-Jenkins'}, 'payload': {'repository_id': 858291574, 'push_id': 20536498505, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '21250c8e7a370c35efad5d45f23da06f6be1ffbe', 'before': '8488ba297cf26b839a34106e01660c06fcbbfcd0', 'commits': [{'sha': '21250c8e7a370c35efad5d45f23da06f6be1ffbe', 'author': {'email': 'ndahtembi@gmail.com', 'name': 'Tembi'}, 'message': 'updated repo', 'distinct': True, 'url': 'https://api.github.com/repos/ndahtems/Terraform-Jenkins/commits/21250c8e7a370c35efad5d45f23da06f6be1ffbe'}]}, 'public': True, 'created_at': '2024-10-03T12:49:07Z'}
# {'id': '42509437404', 'type': 'PushEvent', 'actor': {'id': 36563672, 'login': 'Mmx233', 'display_login': 'Mmx233', 'gravatar_id': '', 'url': 'https://api.github.com/users/Mmx233', 'avatar_url': 'https://avatars.githubusercontent.com/u/36563672?'}, 'repo': {'id': 850380663, 'name': 'Mmx233/BackoffCli', 'url': 'https://api.github.com/repos/Mmx233/BackoffCli'}, 'payload': {'repository_id': 850380663, 'push_id': 20536498511, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '657194ccba996d0026c64db7b1f50c41483c3290', 'before': 'd3a8dd34d1ca34dd5879aeb9a3bd4756a281dd4f', 'commits': [{'sha': '657194ccba996d0026c64db7b1f50c41483c3290', 'author': {'email': 'green.dusk8264@fastmail.com', 'name': 'Mmx'}, 'message': 'sync: backoff', 'distinct': True, 'url': 'https://api.github.com/repos/Mmx233/BackoffCli/commits/657194ccba996d0026c64db7b1f50c41483c3290'}]}, 'public': True, 'created_at': '2024-10-03T12:49:07Z'}
# {'id': '42509437414', 'type': 'PushEvent', 'actor': {'id': 76231708, 'login': 'nicholasalvesx', 'display_login': 'nicholasalvesx', 'gravatar_id': '', 'url': 'https://api.github.com/users/nicholasalvesx', 'avatar_url': 'https://avatars.githubusercontent.com/u/76231708?'}, 'repo': {'id': 852190273, 'name': 'Ranbu100/Projeto-Estacionamento', 'url': 'https://api.github.com/repos/Ranbu100/Projeto-Estacionamento'}, 'payload': {'repository_id': 852190273, 'push_id': 20536498520, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'e70a98f5308ebd588e2a3763c9abc729bb11b808', 'before': '459fa0ff0c1b4d36e538d936d2781dc15e4da8a8', 'commits': [{'sha': 'e70a98f5308ebd588e2a3763c9abc729bb11b808', 'author': {'email': 'nicholas.alves2007@gmail.com', 'name': 'Nicholas'}, 'message': 'att backend 3/10', 'distinct': True, 'url': 'https://api.github.com/repos/Ranbu100/Projeto-Estacionamento/commits/e70a98f5308ebd588e2a3763c9abc729bb11b808'}]}, 'public': True, 'created_at': '2024-10-03T12:49:07Z'}
# {'id': '42509437385', 'type': 'PushEvent', 'actor': {'id': 136606032, 'login': 'theanujsinha01', 'display_login': 'theanujsinha01', 'gravatar_id': '', 'url': 'https://api.github.com/users/theanujsinha01', 'avatar_url': 'https://avatars.githubusercontent.com/u/136606032?'}, 'repo': {'id': 867076636, 'name': 'theanujsinha01/Data-Analysis-Projects', 'url': 'https://api.github.com/repos/theanujsinha01/Data-Analysis-Projects'}, 'payload': {'repository_id': 867076636, 'push_id': 20536498482, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '1e3d3e1ace4d088361d04b56cd01ea07250f901e', 'before': '62be5faa7fb64327fe958eec3c96b0e1c87d2d3a', 'commits': [{'sha': '1e3d3e1ace4d088361d04b56cd01ea07250f901e', 'author': {'email': '136606032+theanujsinha01@users.noreply.github.com', 'name': 'Anuj Kumar'}, 'message': 'Add files via upload', 'distinct': True, 'url': 'https://api.github.com/repos/theanujsinha01/Data-Analysis-Projects/commits/1e3d3e1ace4d088361d04b56cd01ea07250f901e'}]}, 'public': True, 'created_at': '2024-10-03T12:49:07Z'}
# {'id': '42509437410', 'type': 'PullRequestEvent', 'actor': {'id': 99863853, 'login': 'CodeItpython', 'display_login': 'CodeItpython', 'gravatar_id': '', 'url': 'https://api.github.com/users/CodeItpython', 'avatar_url': 'https://avatars.githubusercontent.com/u/99863853?'}, 'repo': {'id': 862142178, 'name': 'prgrms-be-devcourse/NBE1_2_Team07', 'url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07'}, 'payload': {'action': 'closed', 'number': 23, 'pull_request': {'url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/pulls/23', 'id': 2102913367, 'node_id': 'PR_kwDOM2M-4s59V-lX', 'html_url': 'https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23', 'diff_url': 'https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23.diff', 'patch_url': 'https://github.com/prgrms-be-devcourse/NBE1_2_Team07/pull/23.patch', 'issue_url': 'https://api.github.com/repos/prgrms-be-devcourse/NBE1_2_Team07/issues/23', 'number': 23, 'state': 'closed', 'locked': False, 'title': 'Feat/#2 유저 회원가입 및 로그인 구현', 'user': {'login': 'CodeItpython', 'id': 99863853, 'node_id': 'U_kgDOBfPNLQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/99863853?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/CodeItpython', 'html_url': 'https://github.com/CodeItpython', 'followers_url': 'https://api.github.com/users/CodeItpython/followers', 'following_url': 'https://api.github.com/users/CodeItpython/following{/other_user}', 'gists_url': 'https://api.github.com/users/CodeItpython/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/CodeItpython/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/CodeItpython/subscriptions', 'organizations_url': 'https://api.github.com/users/CodeItpython/orgs', 'repos_url': 'https://api.github.com/users/CodeItpython/repos', 'events_url': 'https://api.github.com/users/CodeItpython/events{/privacy}', 'received_events_url': 'https://api.github.com/users/CodeItpython/received_events', 'type': 'User', 'site_admin': False}, 'body': '## 📌 과제 설명 <!-- 어떤 걸 만들었는지 대략적으로 설명해주세요 -->\r\n- #2 \r\n\r\n- 유저의 회원가입기능을 개발\r\n- 관리자계정과 일반사용자를 구분하여 회원가입\r\n- 이메일 인증을 통한 회원가입\r\n\r\n\r\n## 👩\u200d💻 요구 사항과 구현 내용 <!-- 기능을 Commit 별로 잘개 쪼개고, Commit 별로 설명해주세요 -->\r\n- 아이디 중복체크기능\r\n- 이메일 발송기능\r\n- 이메일 발송코드 검증기능\r\n- 회원가입기능(+ROLE_USER, ROLE_ADMIN 선택)\r\n- 로그인기능\r\n\r\n## ✅ PR 포인트 & 궁금한 점 <!-- 리뷰어 분들이 집중적으로 보셨으면 하는 내용을 적어주세요 -->\r\n- fe 코드와 함께 카카오, 네이버 로그인 구현 예정\r\n', 'created_at': '2024-10-02T08:11:37Z', 'updated_at': '2024-10-03T12:49:07Z', 'closed_at': '2024-10-03T12:49:06Z', 'merged_at': None, 'merge_commit_sha': '454e259127886ab88c560ce8af870232253e0341', 'assignee': {'login': 'CodeItpython', 'id': 99863853, 'node_id': 'U_kgDOBfPNLQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/99863853?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/CodeItpython', 'html_url': 'https://github.com/CodeItpython', 'followers_url': 'https://api.github.com/users/CodeItpython/followers', 'following_url': 'https://api.github.com/users/CodeItpython/following{/other_user}', 'gists_url': 'https://api.github.com/users/CodeItpython/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/CodeItpython/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/CodeItpython/subscriptions', 'organizations_url': 'https://api.github.com/users/CodeItpython/orgs', 'repos_url': 'https://api.github.com/users/CodeItpython/repos', 'events_url': 'https://api.github.com/users/CodeItpython/events{/privacy}', 'received_events_url': 'https://api.github.com/users/CodeItpython/received_events', 'type': 'User', 'site_admin': False}, 'assignees': [{'login': 'CodeItpython', 'id': 99863853, 'node_id': 'U_kgDOBfPNLQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/99863853?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/CodeItpython', 'html_url': 'https://github.com/CodeItpython', 'followers_url': 'https://api.github.com/users/CodeItpython/followers', 'following_url' ...

# %% [markdown]
# >> ### **데이터 구조 이해 해보기**

# %%
import pandas as pd

for text in d_json:
    display(pd.DataFrame(text).head())
    print('*'*100)
# Out:
#                         id       type                                 actor  \
# id             42509437768  PushEvent                             161367810
# login          42509437768  PushEvent                               aimme14
# display_login  42509437768  PushEvent                               aimme14
# gravatar_id    42509437768  PushEvent
# url            42509437768  PushEvent  https://api.github.com/users/aimme14
#
#                                                             repo payload  \
# id                                                     867058423     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/aimme14/estudio-p...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id               type  \
# id             42509437745  IssueCommentEvent
# login          42509437745  IssueCommentEvent
# display_login  42509437745  IssueCommentEvent
# gravatar_id    42509437745  IssueCommentEvent
# url            42509437745  IssueCommentEvent
#
#                                                   actor  \
# id                                            178772239
# login                                       suresh06-lv
# display_login                               suresh06-lv
# gravatar_id
# url            https://api.github.com/users/suresh06-lv
#
#                                                        repo payload  public  \
# id                                                312372049     NaN    True
# login                                                   NaN     NaN    True
# display_login                                           NaN     NaN    True
# gravatar_id                                             NaN     NaN    True
# url            https://api.github.com/repos/ni/grpc-labview     NaN    True
#
#                          created_at                             org
# id             2024-10-03T12:49:08Z                         5598284
# login          2024-10-03T12:49:08Z                              ni
# display_login  2024-10-03T12:49:08Z                             NaN
# gravatar_id    2024-10-03T12:49:08Z
# url            2024-10-03T12:49:08Z  https://api.github.com/orgs/ni
# ****************************************************************************************************
#                         id       type  \
# id             42509437723  PushEvent
# login          42509437723  PushEvent
# display_login  42509437723  PushEvent
# gravatar_id    42509437723  PushEvent
# url            42509437723  PushEvent
#
#                                                     actor  \
# id                                               29139614
# login                                       renovate[bot]
# display_login                                    renovate
# gravatar_id
# url            https://api.github.com/users/renovate[bot]
#
#                                                             repo payload  \
# id                                                     340385345     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/DFE-Digital/prepa...     NaN
#
#                public            created_at  \
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
#
#                                                    org
# id                                            30029772
# login                                      DFE-Digital
# display_login                                      NaN
# gravatar_id
# url            https://api.github.com/orgs/DFE-Digital
# ****************************************************************************************************
#                         id         type  \
# id             42509437737  CreateEvent
# login          42509437737  CreateEvent
# display_login  42509437737  CreateEvent
# gravatar_id    42509437737  CreateEvent
# url            42509437737  CreateEvent
#
#                                                           actor  \
# id                                                    146189912
# login                                       Shivanand-hulikatti
# display_login                               Shivanand-hulikatti
# gravatar_id
# url            https://api.github.com/users/Shivanand-hulikatti
#
#                                                             repo payload  \
# id                                                     867094419     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/Shivanand-hulikat...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id       type                                 actor  \
# id             42509437721  PushEvent                             120438850
# login          42509437721  PushEvent                               1992513
# display_login  42509437721  PushEvent                               1992513
# gravatar_id    42509437721  PushEvent
# url            42509437721  PushEvent  https://api.github.com/users/1992513
#
#                                                    repo payload  public  \
# id                                            583676719     NaN    True
# login                                               NaN     NaN    True
# display_login                                       NaN     NaN    True
# gravatar_id                                         NaN     NaN    True
# url            https://api.github.com/repos/1992513/djy     NaN    True
#
#                          created_at
# id             2024-10-03T12:49:08Z
# login          2024-10-03T12:49:08Z
# display_login  2024-10-03T12:49:08Z
# gravatar_id    2024-10-03T12:49:08Z
# url            2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id                    type  \
# id             42509437720  PullRequestReviewEvent
# login          42509437720  PullRequestReviewEvent
# display_login  42509437720  PullRequestReviewEvent
# gravatar_id    42509437720  PullRequestReviewEvent
# url            42509437720  PullRequestReviewEvent
#
#                                                actor  \
# id                                           1436948
# login                                       radeusgd
# display_login                               radeusgd
# gravatar_id
# url            https://api.github.com/users/radeusgd
#
#                                                      repo payload  public  \
# id                                               76672223     NaN    True
# login                                                 NaN     NaN    True
# display_login                                         NaN     NaN    True
# gravatar_id                                           NaN     NaN    True
# url            https://api.github.com/repos/enso-org/enso     NaN    True
#
#                          created_at                                   org
# id             2024-10-03T12:49:08Z                              17415943
# login          2024-10-03T12:49:08Z                              enso-org
# display_login  2024-10-03T12:49:08Z                                   NaN
# gravatar_id    2024-10-03T12:49:08Z
# url            2024-10-03T12:49:08Z  https://api.github.com/orgs/enso-org
# ****************************************************************************************************
#                         id                           type  \
# id             42509437709  PullRequestReviewCommentEvent
# login          42509437709  PullRequestReviewCommentEvent
# display_login  42509437709  PullRequestReviewCommentEvent
# gravatar_id    42509437709  PullRequestReviewCommentEvent
# url            42509437709  PullRequestReviewCommentEvent
#
#                                                   actor  \
# id                                             77981300
# login                                       dgodinez-dh
# display_login                               dgodinez-dh
# gravatar_id
# url            https://api.github.com/users/dgodinez-dh
#
#                                                             repo payload  \
# id                                                     688538805     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/deephaven/deephav...     NaN
#
#                public            created_at  \
# id               True  2024-10-03T12:49:07Z
# login            True  2024-10-03T12:49:07Z
# display_login    True  2024-10-03T12:49:07Z
# gravatar_id      True  2024-10-03T12:49:07Z
# url              True  2024-10-03T12:49:07Z
#
#                                                  org
# id                                          44370703
# login                                      deephaven
# display_login                                    NaN
# gravatar_id
# url            https://api.github.com/orgs/deephaven
# ****************************************************************************************************
#                         id       type  \
# id             42509437654  PushEvent
# login          42509437654  PushEvent
# display_login  42509437654  PushEvent
# gravatar_id    42509437654  PushEvent
# url            42509437654  PushEvent
#
#                                                  actor  \
# id                                            28728982
# login                                       GoncaloaaF
# display_login                               GoncaloaaF
# gravatar_id
# url            https://api.github.com/users/GoncaloaaF
#
#                                                             repo payload  \
# id                                                     865819656     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/GoncaloaaF-ATEC/P...     NaN
#
#                public            created_at  \
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
#
#                                                        org
# id                                               172500943
# login                                      GoncaloaaF-ATEC
# display_login                                          NaN
# gravatar_id
# url            https://api.github.com/orgs/GoncaloaaF-ATEC
# ****************************************************************************************************
#                         id       type                                   actor  \
# id             42509437663  PushEvent                                63259982
# login          42509437663  PushEvent                               JotaPrimo
# display_login  42509437663  PushEvent                               JotaPrimo
# gravatar_id    42509437663  PushEvent
# url            42509437663  PushEvent  https://api.github.com/users/JotaPrimo
#
#                                                             repo payload  \
# id                                                     866758374     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/JotaPrimo/selectores     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id         type  \
# id             42509437632  CreateEvent
# login          42509437632  CreateEvent
# display_login  42509437632  CreateEvent
# gravatar_id    42509437632  CreateEvent
# url            42509437632  CreateEvent
#
#                                                  actor  \
# id                                           156696627
# login                                       Ruslan0192
# display_login                               Ruslan0192
# gravatar_id
# url            https://api.github.com/users/Ruslan0192
#
#                                                             repo payload  \
# id                                                     867094418     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/Ruslan0192/TradeV...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id       type                                  actor  \
# id             42509437609  PushEvent                               99333578
# login          42509437609  PushEvent                               M7-M7-M7
# display_login  42509437609  PushEvent                               M7-M7-M7
# gravatar_id    42509437609  PushEvent
# url            42509437609  PushEvent  https://api.github.com/users/M7-M7-M7
#
#                                                       repo payload  public  \
# id                                               843638456     NaN    True
# login                                                  NaN     NaN    True
# display_login                                          NaN     NaN    True
# gravatar_id                                            NaN     NaN    True
# url            https://api.github.com/repos/M7-M7-M7/m7777     NaN    True
#
#                          created_at
# id             2024-10-03T12:49:08Z
# login          2024-10-03T12:49:08Z
# display_login  2024-10-03T12:49:08Z
# gravatar_id    2024-10-03T12:49:08Z
# url            2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id       type  \
# id             42509437606  PushEvent
# login          42509437606  PushEvent
# display_login  42509437606  PushEvent
# gravatar_id    42509437606  PushEvent
# url            42509437606  PushEvent
#
#                                                  actor  \
# id                                            97571741
# login                                       alfianto21
# display_login                               alfianto21
# gravatar_id
# url            https://api.github.com/users/alfianto21
#
#                                                             repo payload  \
# id                                                     864189659     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/alfianto21/poem.g...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id       type                                 actor  \
# id             42509437572  PushEvent                              93773753
# login          42509437572  PushEvent                               BlaaSwe
# display_login  42509437572  PushEvent                               BlaaSwe
# gravatar_id    42509437572  PushEvent
# url            42509437572  PushEvent  https://api.github.com/users/BlaaSwe
#
#                                                             repo payload  \
# id                                                     544882036     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/BlaaSwe/Trend-Soa...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id       type  \
# id             42509437593  PushEvent
# login          42509437593  PushEvent
# display_login  42509437593  PushEvent
# gravatar_id    42509437593  PushEvent
# url            42509437593  PushEvent
#
#                                                           actor  \
# id                                                     41898282
# login                                       github-actions[bot]
# display_login                                    github-actions
# gravatar_id
# url            https://api.github.com/users/github-actions[bot]
#
#                                                             repo payload  \
# id                                                     661535205     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/thedoggybrad/easy...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id               type  \
# id             42509437582  IssueCommentEvent
# login          42509437582  IssueCommentEvent
# display_login  42509437582  IssueCommentEvent
# gravatar_id    42509437582  IssueCommentEvent
# url            42509437582  IssueCommentEvent
#
#                                                           actor  \
# id                                                     41898282
# login                                       github-actions[bot]
# display_login                                    github-actions
# gravatar_id
# url            https://api.github.com/users/github-actions[bot]
#
#                                                         repo payload  public  \
# id                                                 637784737     NaN    True
# login                                                    NaN     NaN    True
# display_login                                            NaN     NaN    True
# gravatar_id                                              NaN     NaN    True
# url            https://api.github.com/repos/equinor/nrresqml     NaN    True
#
#                          created_at                                  org
# id             2024-10-03T12:49:08Z                               525862
# login          2024-10-03T12:49:08Z                              equinor
# display_login  2024-10-03T12:49:08Z                                  NaN
# gravatar_id    2024-10-03T12:49:08Z
# url            2024-10-03T12:49:08Z  https://api.github.com/orgs/equinor
# ****************************************************************************************************
#                         id               type  \
# id             42509437561  IssueCommentEvent
# login          42509437561  IssueCommentEvent
# display_login  42509437561  IssueCommentEvent
# gravatar_id    42509437561  IssueCommentEvent
# url            42509437561  IssueCommentEvent
#
#                                                          actor  \
# id                                                   107444360
# login                                       ocpdocs-previewbot
# display_login                               ocpdocs-previewbot
# gravatar_id
# url            https://api.github.com/users/ocpdocs-previewbot
#
#                                                             repo payload  \
# id                                                      21740844     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/openshift/openshi...     NaN
#
#                public            created_at  \
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
#
#                                                  org
# id                                            792337
# login                                      openshift
# display_login                                    NaN
# gravatar_id
# url            https://api.github.com/orgs/openshift
# ****************************************************************************************************
#                         id               type  \
# id             42509437544  IssueCommentEvent
# login          42509437544  IssueCommentEvent
# display_login  42509437544  IssueCommentEvent
# gravatar_id    42509437544  IssueCommentEvent
# url            42509437544  IssueCommentEvent
#
#                                              actor  \
# id                                         2588851
# login                                       jansol
# display_login                               jansol
# gravatar_id
# url            https://api.github.com/users/jansol
#
#                                                           repo payload  \
# id                                                   340547520     NaN
# login                                                      NaN     NaN
# display_login                                              NaN     NaN
# gravatar_id                                                NaN     NaN
# url            https://api.github.com/repos/zed-industries/zed     NaN
#
#                public            created_at  \
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
#
#                                                       org
# id                                               79345384
# login                                      zed-industries
# display_login                                         NaN
# gravatar_id
# url            https://api.github.com/orgs/zed-industries
# ****************************************************************************************************
#                         id                    type  \
# id             42509437532  PullRequestReviewEvent
# login          42509437532  PullRequestReviewEvent
# display_login  42509437532  PullRequestReviewEvent
# gravatar_id    42509437532  PullRequestReviewEvent
# url            42509437532  PullRequestReviewEvent
#
#                                                   actor  \
# id                                             77981300
# login                                       dgodinez-dh
# display_login                               dgodinez-dh
# gravatar_id
# url            https://api.github.com/users/dgodinez-dh
#
#                                                             repo payload  \
# id                                                     688538805     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/deephaven/deephav...     NaN
#
#                public            created_at  \
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
#
#                                                  org
# id                                          44370703
# login                                      deephaven
# display_login                                    NaN
# gravatar_id
# url            https://api.github.com/orgs/deephaven
# ****************************************************************************************************
#                         id         type  \
# id             42509437556  CreateEvent
# login          42509437556  CreateEvent
# display_login  42509437556  CreateEvent
# gravatar_id    42509437556  CreateEvent
# url            42509437556  CreateEvent
#
#                                                            actor  \
# id                                                     118344674
# login                                    github-merge-queue[bot]
# display_login                                 github-merge-queue
# gravatar_id
# url            https://api.github.com/users/github-merge-queu...
#
#                                                          repo payload  public  \
# id                                                  297302063     NaN    True
# login                                                     NaN     NaN    True
# display_login                                             NaN     NaN    True
# gravatar_id                                               NaN     NaN    True
# url            https://api.github.com/repos/memgraph/memgraph     NaN    True
#
#                          created_at                                   org
# id             2024-10-03T12:49:08Z                              17707542
# login          2024-10-03T12:49:08Z                              memgraph
# display_login  2024-10-03T12:49:08Z                                   NaN
# gravatar_id    2024-10-03T12:49:08Z
# url            2024-10-03T12:49:08Z  https://api.github.com/orgs/memgraph
# ****************************************************************************************************
#                         id               type  \
# id             42509437527  IssueCommentEvent
# login          42509437527  IssueCommentEvent
# display_login  42509437527  IssueCommentEvent
# gravatar_id    42509437527  IssueCommentEvent
# url            42509437527  IssueCommentEvent
#
#                                                    actor  \
# id                                              22429695
# login                                       codecov[bot]
# display_login                                    codecov
# gravatar_id
# url            https://api.github.com/users/codecov[bot]
#
#                                                        repo payload  public  \
# id                                                120805786     NaN    True
# login                                                   NaN     NaN    True
# display_login                                           NaN     NaN    True
# gravatar_id                                             NaN     NaN    True
# url            https://api.github.com/repos/tskit-dev/tskit     NaN    True
#
#                          created_at                                    org
# id             2024-10-03T12:49:08Z                               36278110
# login          2024-10-03T12:49:08Z                              tskit-dev
# display_login  2024-10-03T12:49:08Z                                    NaN
# gravatar_id    2024-10-03T12:49:08Z
# url            2024-10-03T12:49:08Z  https://api.github.com/orgs/tskit-dev
# ****************************************************************************************************
#                         id         type  \
# id             42509437503  CreateEvent
# login          42509437503  CreateEvent
# display_login  42509437503  CreateEvent
# gravatar_id    42509437503  CreateEvent
# url            42509437503  CreateEvent
#
#                                                  actor  \
# id                                           156696627
# login                                       Ruslan0192
# display_login                               Ruslan0192
# gravatar_id
# url            https://api.github.com/users/Ruslan0192
#
#                                                             repo payload  \
# id                                                     867094418     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/Ruslan0192/TradeV...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id         type  \
# id             42509437523  CreateEvent
# login          42509437523  CreateEvent
# display_login  42509437523  CreateEvent
# gravatar_id    42509437523  CreateEvent
# url            42509437523  CreateEvent
#
#                                                   actor  \
# id                                            131700992
# login                                       Chrissankov
# display_login                               Chrissankov
# gravatar_id
# url            https://api.github.com/users/Chrissankov
#
#                                                             repo payload  \
# id                                                     867092177     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/Chrissankov/Respo...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id       type  \
# id             42509437475  PushEvent
# login          42509437475  PushEvent
# display_login  42509437475  PushEvent
# gravatar_id    42509437475  PushEvent
# url            42509437475  PushEvent
#
#                                                           actor  \
# id                                                     41898282
# login                                       github-actions[bot]
# display_login                                    github-actions
# gravatar_id
# url            https://api.github.com/users/github-actions[bot]
#
#                                                             repo payload  \
# id                                                     460805243     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/luanjubica/status...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:08Z
# login            True  2024-10-03T12:49:08Z
# display_login    True  2024-10-03T12:49:08Z
# gravatar_id      True  2024-10-03T12:49:08Z
# url              True  2024-10-03T12:49:08Z
# ****************************************************************************************************
#                         id         type  \
# id             42509437451  CreateEvent
# login          42509437451  CreateEvent
# display_login  42509437451  CreateEvent
# gravatar_id    42509437451  CreateEvent
# url            42509437451  CreateEvent
#
#                                                    actor  \
# id                                             104969449
# login                                       vishal230503
# display_login                               vishal230503
# gravatar_id
# url            https://api.github.com/users/vishal230503
#
#                                                             repo payload  \
# id                                                     867094417     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/vishal230503/terr...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:07Z
# login            True  2024-10-03T12:49:07Z
# display_login    True  2024-10-03T12:49:07Z
# gravatar_id      True  2024-10-03T12:49:07Z
# url              True  2024-10-03T12:49:07Z
# ****************************************************************************************************
#                         id       type  \
# id             42509437405  PushEvent
# login          42509437405  PushEvent
# display_login  42509437405  PushEvent
# gravatar_id    42509437405  PushEvent
# url            42509437405  PushEvent
#
#                                                  actor  \
# id                                           111508010
# login                                       LiquidSi1k
# display_login                               LiquidSi1k
# gravatar_id
# url            https://api.github.com/users/LiquidSi1k
#
#                                                             repo payload  \
# id                                                     867093144     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/LiquidSi1k/Liquid...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:07Z
# login            True  2024-10-03T12:49:07Z
# display_login    True  2024-10-03T12:49:07Z
# gravatar_id      True  2024-10-03T12:49:07Z
# url              True  2024-10-03T12:49:07Z
# ****************************************************************************************************
#                         id       type                                  actor  \
# id             42509437418  PushEvent                              125495087
# login          42509437418  PushEvent                               ndahtems
# display_login  42509437418  PushEvent                               ndahtems
# gravatar_id    42509437418  PushEvent
# url            42509437418  PushEvent  https://api.github.com/users/ndahtems
#
#                                                             repo payload  \
# id                                                     858291574     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/ndahtems/Terrafor...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:07Z
# login            True  2024-10-03T12:49:07Z
# display_login    True  2024-10-03T12:49:07Z
# gravatar_id      True  2024-10-03T12:49:07Z
# url              True  2024-10-03T12:49:07Z
# ****************************************************************************************************
#                         id       type                                actor  \
# id             42509437404  PushEvent                             36563672
# login          42509437404  PushEvent                               Mmx233
# display_login  42509437404  PushEvent                               Mmx233
# gravatar_id    42509437404  PushEvent
# url            42509437404  PushEvent  https://api.github.com/users/Mmx233
#
#                                                          repo payload  public  \
# id                                                  850380663     NaN    True
# login                                                     NaN     NaN    True
# display_login                                             NaN     NaN    True
# gravatar_id                                               NaN     NaN    True
# url            https://api.github.com/repos/Mmx233/BackoffCli     NaN    True
#
#                          created_at
# id             2024-10-03T12:49:07Z
# login          2024-10-03T12:49:07Z
# display_login  2024-10-03T12:49:07Z
# gravatar_id    2024-10-03T12:49:07Z
# url            2024-10-03T12:49:07Z
# ****************************************************************************************************
#                         id       type  \
# id             42509437414  PushEvent
# login          42509437414  PushEvent
# display_login  42509437414  PushEvent
# gravatar_id    42509437414  PushEvent
# url            42509437414  PushEvent
#
#                                                      actor  \
# id                                                76231708
# login                                       nicholasalvesx
# display_login                               nicholasalvesx
# gravatar_id
# url            https://api.github.com/users/nicholasalvesx
#
#                                                             repo payload  \
# id                                                     852190273     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/Ranbu100/Projeto-...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:07Z
# login            True  2024-10-03T12:49:07Z
# display_login    True  2024-10-03T12:49:07Z
# gravatar_id      True  2024-10-03T12:49:07Z
# url              True  2024-10-03T12:49:07Z
# ****************************************************************************************************
#                         id       type  \
# id             42509437385  PushEvent
# login          42509437385  PushEvent
# display_login  42509437385  PushEvent
# gravatar_id    42509437385  PushEvent
# url            42509437385  PushEvent
#
#                                                      actor  \
# id                                               136606032
# login                                       theanujsinha01
# display_login                               theanujsinha01
# gravatar_id
# url            https://api.github.com/users/theanujsinha01
#
#                                                             repo payload  \
# id                                                     867076636     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/theanujsinha01/Da...     NaN
#
#                public            created_at
# id               True  2024-10-03T12:49:07Z
# login            True  2024-10-03T12:49:07Z
# display_login    True  2024-10-03T12:49:07Z
# gravatar_id      True  2024-10-03T12:49:07Z
# url              True  2024-10-03T12:49:07Z
# ****************************************************************************************************
#                         id              type  \
# id             42509437410  PullRequestEvent
# login          42509437410  PullRequestEvent
# display_login  42509437410  PullRequestEvent
# gravatar_id    42509437410  PullRequestEvent
# url            42509437410  PullRequestEvent
#
#                                                    actor  \
# id                                              99863853
# login                                       CodeItpython
# display_login                               CodeItpython
# gravatar_id
# url            https://api.github.com/users/CodeItpython
#
#                                                             repo payload  \
# id                                                     862142178     NaN
# login                                                        NaN     NaN
# display_login                                                NaN     NaN
# gravatar_id                                                  NaN     NaN
# url            https://api.github.com/repos/prgrms-be-devcour...     NaN
#
#                public            created_at  \
# id               True  2024-10-03T12:49:07Z
# login            True  2024-10-03T12:49:07Z
# display_login    True  2024-10-03T12:49:07Z
# gravatar_id      True  2024-10-03T12:49:07Z
# url              True  2024-10-03T12:49:07Z
#
#                                                            org
# id                                                    88020948
# login                                      prgrms-be-devcourse
# display_login                                              NaN
# gravatar_id
# url            https://api.github.com/orgs/prgrms-be-devcourse
# ****************************************************************************************************

# %% [markdown]
# >> ### **BeautifulSoup**

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# >> ### **Quick Start**

# %%
soup = BeautifulSoup("<p>Some<b>bad<i>HTML")

# %%
soup
# Out:
# <html><body><p>Some<b>bad<i>HTML</i></b></p></body></html>

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    Some
#    <b>
#     bad
#     <i>
#      HTML
#     </i>
#    </b>
#   </p>
#  </body>
# </html>

# %%
soup.find(string="bad")
# Out:
# 'bad'

# %%
soup.i
# Out:
# <i>HTML</i>

# %%
soup = BeautifulSoup("<tag1>Some<tag2/>bad<tag3>XML", "xml")
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <tag1>
#  Some
#  <tag2/>
#  bad
#  <tag3>
#   XML
#  </tag3>
# </tag1>

# %% [markdown]
# ## **실전문제**

# %%
url = 'https://www.lieder.net/lieder/get_text.html?TextId=21635'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Mockturtle Soup | Beautiful Soup, so rich and green | LiederNet
#   </title>
#   <!--<link rel="preconnect" href="https://fonts.gstatic.com/" crossorigin />-->
#   <meta content="1X0R00VYafsido-bovKUJjyCu4rra_W_9elarBiO8H8" name="google-site-verification"/>
#   <meta charset="utf-8"/>
#   <meta content="https://www.lieder.net/" name="identifier-url"/>
#   <meta content="Â© The LiederNet Archive" name="copyright"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/favicon/favicon.ico?v=2" id="favicon" rel="shortcut icon" type="image/x-icon"/>
#   <link href="favicon/favicon-32x32.png?v=2" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="favicon/favicon-16x16.png?v=2" rel="icon" sizes="16x16" type="image/png"/>
#   <meta content="#284358" name="theme-color"/>
#   <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="favicon/apple-touch-icon.png?v=2" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="favicon/site.webmanifest?v=2" rel="manifest"/>
#   <link color="#3b6f96" href="favicon/safari-pinned-tab.svg?v=2" rel="mask-icon"/>
#   <meta content="Texts and Translations to Lieder and other classical vocal works in more than a hundred languages" name="description"/>
#   <meta content="Lieder, translation, lyrics, art song, poetry, vocal text, kunstlieder, uebersetzungen, gedichte, melodie, traductions, Liederen, canzoni, laulua, piosenki, pisne, letra, cancoe" name="keywords"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <style type="text/css">
#    @media print {
#     main { display:none; }
#   }
#   </style>
#   <link as="style" href="/lieder/style/style_sheet.css?v=122" rel="preload" type="text/css"/>
#   <link href="/lieder/style/style_sheet.css?v=122" rel="stylesheet" type="text/css"/>
#   <link as="image" fetchpriority="high" href="../images/Hirt4transp.png" rel="preload" type="image/png"/>
#   <link as="font" crossorigin="" href="/lieder/fonts/lato-v24-latin-ext-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/lieder/fonts/lato-v24-latin-ext-700.woff2" rel="preload" type="font/woff2"/>
#   <link as="script" href="/lieder/jquery/jquery-3.7.1.min.js" rel="preload" type="text/javascript"/>
#   <script fetchpriority="high" src="/lieder/jquery/jquery-3.7.1.min.js">
#   </script>
#   <script>
#    function delete_my_cookie ( cookie_name )
# {
#   var cookie_date = new Date ( );  // current date & time
#   cookie_date.setTime ( cookie_date.getTime() - 1 );
#   document.cookie = cookie_name + "=X;expires=" + cookie_date.toGMTString();
# }
#
# function sign_out() {
#   delete_my_cookie("lieder");
#   location.reload();
# }
#   </script>
#   <script async="" src="/lieder/js/sha3.js">
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function() {
#         $("body").show();
#         sf();
#     });
#
# function sf() {
#     if (document.f) {
#         if (document.f.username) {
#             document.f.username.focus();
#         } else {
#             document.f.submit.focus();
#         }
#     }
# }
#
# function hashIt() {
#    var hash = CryptoJS.SHA3($("#password").val(), { outputLength: 224 });
#    $("#password").val(hash);
#    return true;
# }
#   </script>
#   <script>
#    function getCookie(cname) {
#     var name = cname + "=";
#     var ca = document.cookie.split(';');
#     for(var i=0; i<ca.length; i++) {
#         var c = ca[i];
#         while (c.charAt(0)==' ') c = c.substring(1);
#         if (c.indexOf(name) == 0) return c.substring(name.length,c.length);
#     }
#     return "";
# }
#
# function setCookie(cname, cvalue, exdays) {
#     var d = new Date();
#     d.setTime(d.getTime() + (exdays*24*60*60*1000));
#     var expires = "expires="+d.toUTCString();
#     document.cookie = cname + "=" + cvalue + "; " + expires;
# }
#
# function readCookie(desc) {
#   var nameEq = desc + "=";
#   var decodedCookie = decodeURIComponent(document.cookie);
#   var cArray = decodedCookie.split(';');
#   for(var i = 0; i < cArray.length; i++) {
#     var ck = cArray[i];
#     while (ck.charAt(0) == ' ') {
#       ck = ck.substring(1);
#     }
#     if (ck.indexOf(nameEq) == 0) {
#       return ck.substring(nameEq.length, ck.length);
#     }
#   }
#   return "";
# }
#
# function createCookie(keyName,value,days) {
#     var today = new Date();
#     var expiry = new Date(today.getTime() + (days*24*60*60*1000));
#     document.cookie = keyName + "=" + value + ";expires=" + expiry.toUTCString() + ";path=/";
# }
#
# function accept() {
#     createCookie('accepts','Y','60');
#     hasAccepted();
# }
#
# function hasAccepted() {
#     var accepted = readCookie('accepts');
#     if (accepted != 'Y') {
#         document.getElementById('cookie-notice').style.visibility='visible';
#         document.getElementById('cookie-notice').style.opacity=1;
#     } else {
#         document.getElementById('cookie-notice').style.visibility='hidden';
#         document.getElementById('cookie-notice').style.opacity=0;
#     }
# }
#
# document.addEventListener('DOMContentLoaded', hasAccepted);
#
# function toggle(div_id) {
# 	var el = document.getElementById(div_id);
# 	if ( el.style.display == 'none' ) {	el.style.display = 'block';}
# 	else {el.style.display = 'none';}
# }
#
# function toggleMenu() {
#     var menu = document.getElementById('left-nav');
#     if (menu.classList.contains('nav-hidden')) {
#         openMenu();
#     } else {
#         closeMenu();
#     }
# }
#
# document.addEventListener("DOMContentLoaded", function(e) {
#     var w = window.matchMedia("screen and (min-width: 100rem)");
#     autoMenu();
#     w.addListener(autoMenu);
#     function autoMenu() {
#         if (w.matches) {
#             openMenu();
#         } else {
#             closeMenu();
#         }
#     }
# });
#
# window.addEventListener('load', () => {
#     const emails = document.getElementsByClassName('email');
#         Array.from(emails).forEach(function(email) {
#             const decoded = atob(email.name);
#             email.href = "mailto:" + decoded;
#     });
# });
#
# function openMenu() {
#     var menu = document.getElementById('left-nav');
#     var arrow = document.getElementById('menu-toggle-arrow');
#     menu.classList.remove('nav-hidden');
#     menu.classList.add('nav-show');
#     arrow.classList.add('menu-close-arrow');
#     if (window.matchMedia("(min-width: 1600px)").matches) {
#         menu.classList.add('menu-width');
#         document.getElementById('donations-card').classList.add('donations-wide');
#     }
#     document.getElementById('menu-toggle-text').textContent = 'Close Menu';
# }
#
# function closeMenu() {
#     document.getElementById('menu-toggle-text').textContent = 'MENU';
#     var menu = document.getElementById('left-nav');
#     var arrow = document.getElementById('menu-toggle-arrow');
#     arrow.classList.remove('menu-close-arrow');
#     menu.classList.remove('nav-show');
#     menu.classList.add('nav-hidden');
#     menu.classList.remove('menu-width');
#     document.getElementById('donations-card').classList.remove('donations-wide');
# }
#
# document.addEventListener('keyup', function (event) {
#     var key = event.key;
#     if (key === 'Escape' || key === 'Esc' || key === 27)  {
#         if (document.getElementById('left-nav').classList.contains('nav-show')) {
#             closeMenu();
#         }
#     }
# });
#
# window.addEventListener('beforeunload', function() {
#     var spinner = document.querySelector('.loader');
#     spinner.style.visibility = 'visible';
#     spinner.style.opacity = 1;
# });
#
# window.addEventListener('pageshow', function() {
#     var spinner = document.querySelector('.loader');
#     spinner.style.visibility = 'hidden';
#     spinner.style.opacity = 0;
# });
#   </script>
#   <!-- Needed for subdirectories like guest_editors to override -->
#   <!-- ANALYTICS -->
#   <link href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
#   <link as="script" href="https://www.googletagmanager.com/gtag/js?id=UA-34594381-1" rel="preload"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-34594381-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'UA-34594381-1');
#   gtag('config', 'G-TZQ9RWX000');
#   </script>
#   <!-- /ANALYTICS -->
#   <!-- GOOGLE ADS -->
#   <!-- /GOOGLE ADS -->
#  </head>
#  <body onload="sf()">
#   <div class="loader">
#   </div>
#   <!-- FUNDRAISING BANNER -->
#   <div class="fundraise-banner" id="fundraiser">
#    <div style="padding:0.5rem;margin:auto; max-width:52em;text-align:center;">
#     <h3>
#      <strong>
#       Help us stay free of annoying ads
#      </strong>
#     </h3>
#     <p style="padding-bottom:0.5em; text-wrap:balance;">
#      <br/>
#      LiederNet ran no external ads last month...
#      <br/>
#      but donations only matched part of our usual ad revenue.
#     </p>
#     <p style="padding-bottom:0.5em; text-wrap:balance;">
#      Please help us to cover our costs as we share this one-of-a-kind resource with the world.
#     </p>
#    </div>
#    <div class="donate-page-btn" style="border-color: rgb(140, 171, 195); background-color: hsl(206,70%,65%);">
#     <a href="/lieder/donate.html" style="font-family: Lato, Helvetica, Geneva, Arial, sans-serif; font-size: 1.25rem; font-weight: 700; color:white;">
#      Donate Today
#     </a>
#    </div>
#    <span class="close-warning" onclick="dismiss()" style="border-color:#c0abab; color:#a78989; font-size: 1.25em; padding-bottom: 3px;" title="Dismiss for 1 day">
#     ×
#    </span>
#   </div>
#   <script>
#    function dismiss() {
#     createCookie('dismissed','Y','1');
#     hasDismissed();
# }
#
# function hasDismissed() {
#     var dismissed = readCookie('dismissed');
#     if (dismissed === 'Y') {
#         var fundraiser = document.getElementById('fundraiser');
#         void fundraiser.offsetWidth;
#         fundraiser.classList.add('hidden');
#     }
# }
#
# document.addEventListener('DOMContentLoaded', hasDismissed);
#   </script>
#   <!-- /FUNDRAISING BANNER -->
#   <!-- Maintenance window banner -->
#   <!-- Maintenance window banner -->
#   <!-- SITE BANNER -->
#   <header class="site-header" role="banner">
#    <div class="banner">
#     <div class="banner-background">
#     </div>
#     <div class="logo-box">
#      <a class="logo-home" href="/lieder/">
#       <object aria-label="LiederNet Archive logo" class="logo-large" data="/../images/LN_logo_colour.svg" type="image/svg+xml">
#        LiederNet logo
#       </object>
#      </a>
#     </div>
#     <!-- no log-in button for now
#         <a href="/lieder/my_account.html?sign_in=1">
#             <div class="login-button">
#                 <p class="login-btn-text">Log in</p>
#             </div>
#         </a>
#         -->
#    </div>
#   </header>
#   <!-- /SITE BANNER -->
#   <!-- MAIN -->
#   <main class="main" id="main">
#    <!-- INFO BAR -->
#    <div class="info-bar">
#     <span class="menu-toggle" id="menu-toggle" onclick="toggleMenu()">
#      <span class="arrow-container">
#       <svg height="19" width="19">
#        <polygon class="menu-arrow" id="menu-toggle-arrow" points="4,3 4,19 19,11">
#        </polygon>
#       </svg>
#      </span>
#      <span class="menu-toggle-text" id="menu-toggle-text">
#      </span>
#     </span>
#     <span class="user-info">
#     </span>
#    </div>
#    <!-- /INFO BAR -->
#    <!-- NAVBAR + CONTENT -->
#    <div class="nav-and-content">
#     <!-- NAVBAR -->
#     <nav class="left-nav nav-hidden" id="left-nav">
#      <p class="nav-title">
#       CONTENTS
#      </p>
#      <span class="mobile-menu-close" onclick="toggleMenu()">
#       ×
#      </span>
#      <ul>
#       <li class="nav-item">
#        <a href="/lieder/">
#         Home
#        </a>
#        |
#        <a href="/lieder/intro.html">
#         Introduction
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/cindex.html">
#         Composers (19,597)
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/pindex.html">
#         Text Authors (18,806)
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/random.html?82585">
#         Go to a Random Text
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/tour.html">
#         A Small Tour
#        </a>
#        |
#        <a href="https://shop.lieder.net/" target="_blank">
#         Shop
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/new.html">
#         What’s New
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/faq.html">
#         FAQ &amp; Links
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/donors.html">
#         Donors
#        </a>
#       </li>
#      </ul>
#      <ul>
#       <li class="nav-item donate-page-btn">
#        <a href="/lieder/donate.html">
#         DONATE
#        </a>
#       </li>
#      </ul>
#      <p class="nav-title">
#       UTILITIES
#      </p>
#      <ul>
#       <li class="nav-item">
#        <a href="/lieder/search.html">
#         Search Everything
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/quick_find.html">
#         Search by Surname
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/find_titles_and_first_lines.html">
#         Search by Title or First Line
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/find_settings_by_date.html">
#         Search by Year
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/find_text_compilations.html">
#         Search by Collection
#        </a>
#       </li>
#       <!-- <li class="nav-item"><a href="/lieder/random.html?type=sc">Random&nbsp;Song&nbsp;Cycle</a></li> -->
#      </ul>
#      <p class="nav-title">
#       CREDITS
#      </p>
#      <ul>
#       <li class="nav-item">
#        <a href="/lieder/emily_ezust.html">
#         Emily Ezust
#        </a>
#       </li>
#       <!-- New page? -->
#       <li class="nav-item">
#        <a href="/lieder/contrib.html">
#         Contributors (1,105)
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/contact.html">
#         Contact Information
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/biblio.html">
#         Bibliography
#        </a>
#       </li>
#       <li class="nav-item">
#        <hr aria-label="separator"/>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/copyright.html">
#         Copyright Statement
#        </a>
#       </li>
#       <li class="nav-item">
#        <a href="/lieder/privacy_policy.html">
#         Privacy Policy
#        </a>
#       </li>
#       <li class="nav-item">
#       </li>
#      </ul>
#      <p style="text-align: center; margin: 0.5rem;">
#       <a class="fb-link" href="https://www.facebook.com/TheLiedArtSongAndChoralTextsArchive">
#        Follow us on Facebook
#       </a>
#      </p>
#     </nav>
#     <!-- /NAVBAR -->
#     <!-- PRIMARY CONTENT AND ASSOCIATED ELEMENTS -->
#     <section class="content" id="content">
#      <a class="placard" href="donate.html" id="placard" style="display: none;" target="_blank">
#      </a>
#      <div id="text-buttons">
#      </div>
#      <div id="related-ad-and-text">
#       <!-- logic for the related ad -->
#       <div class="text-table" id="text-table">
#        <div class="auth tr-auth" id="tr-auth">
#         by
#         <a href="/lieder/get_author_texts.html?AuthorId=472">
#          Charles Lutwidge Dodgson
#         </a>
#         (1832 - 1898), as Lewis Carroll
#        </div>
#        <br/>
#        <div class="title tr-title" id="tr-title">
#         <i>
#          Beautiful Soup, so rich and green
#         </i>
#        </div>
#        <div class="lang tr-lang detail" id="tr-lang">
#         Language:
#         <span class="orig">
#          English
#         </span>
#        </div>
#        <div class="trs tr-trs detail" id="tr-trs">
#        </div>
#        <div class="prm-links tr-prmlinks detail" id="tr-prmlinks">
#        </div>
#        <div class="ge-links tr-gelinks detail" id="tr-gelinks">
#        </div>
#        <div class="adm-links tr-admlinks detail" id="tr-admlinks">
#        </div>
#        <div class="text the-tr notranslate" id="the-tr">
#         <pre>Beautiful Soup, so rich and green,
# Waiting in a hot tureen!
# Who for such dainties would not stoop?
# Soup of the evening, beautiful Soup!
# Beautiful Soup!
# Beautiful Soup!
# Soup of the evening,
# Beautiful, beautiful Soup!
#
# Beautiful Soup!  Who cares for fish,
# Game, or any other dish?
# Who would not give all else for two
# Pennyworth only of beautiful Soup?
# Beautiful Soup!
# Beautiful Soup!
# Soup of the evening,
# Beautiful, beautiful soup!</pre>
#        </div>
#        <div class="notes tr-notes detail notranslate" id="tr-notes">
#         <p>
#         </p>
#         <p>
#          <a href="/lieder/faq.html#italic_headlines" target="_blank">
#           About the headline
#          </a>
#          (FAQ)
#         </p>
#         <p>
#         </p>
#         <p class="text-info">
#          Text Authorship:
#         </p>
#         <ul>
#          <li>
#           by
#           <a href="/lieder/get_author_texts.html?AuthorId=472">
#            Charles Lutwidge Dodgson
#           </a>
#           (1832 - 1898), as Lewis Carroll, no title, appears in
#           <i>
#            <a href="/lieder/show_poems_in_group.html?CID=1932">
#             Alice's Adventures in Wonderland
#            </a>
#           </i>
#           , London, Macmillan; chapter 10, first published 1865&amp;emsp13;
#           <a href="/lieder/status_info.html">
#            <span class="verified">
#             [author's text checked 1 time against a primary source]
#            </span>
#           </a>
#          </li>
#         </ul>
#         <a id="settings">
#         </a>
#         <p class="text-info">
#          Musical settings
#          <span style="font-weight:normal;">
#           (art songs, Lieder, mélodies, (etc.), choral pieces, and other vocal works set to this text), listed by composer (not necessarily exhaustive):
#          </span>
#         </p>
#         <ul>
#          <li>
#           by
#           <a href="/lieder/get_settings.html?ComposerId=8142">
#            Gary Bachlund
#           </a>
#           (b. 1947), "The Mock Turtle's Lament", 1991, published 1996 [ high voice or medium voice and piano ], from
#           <a href="/lieder/assemble_texts.html?SongCycleId=1382">
#            "Alice" Songs
#           </a>
#           , no. 4&amp;emsp13;
#           <a href="/lieder/status_info.html">
#            <span class="verified" data-nosnippet="">
#             [sung text checked 1 time]
#            </span>
#           </a>
#          </li>
#          <li>
#           by
#           <a href="/lieder/get_settings.html?ComposerId=3920">
#            John Woods Duke
#           </a>
#           (1899 - 1984), "The Mock Turtle's song", 1982 [ baritone and piano ], from
#           <a href="/lieder/assemble_texts.html?SongCycleId=1039">
#            Five Lewis Carroll Poems
#           </a>
#           , no. 4, Recital Publ.&amp;emsp13;
#           <a href="/lieder/status_info.html">
#            <span class="verified" data-nosnippet="">
#             [sung text checked 1 time]
#            </span>
#           </a>
#          </li>
#          <li>
#           by
#           <a href="/lieder/get_settings.html?ComposerId=9165">
#            Richard Farber
#           </a>
#           (b. 1945), "Beautiful Soup", 2020 [ voice and piano ], from
#           <a href="/lieder/assemble_texts.html?SongCycleId=15091">
#            Songs on Verse by Lewis Carroll
#           </a>
#           , no. 5&amp;emsp13;
#           <a href="/lieder/status_info.html">
#            <span class="unverified" data-nosnippet="">
#             [sung text not yet checked]
#            </span>
#           </a>
#          </li>
#          <li>
#           by
#           <a href="/lieder/get_settings.html?ComposerId=4810">
#            Liza Lehmann
#           </a>
#           (1862 - 1918), "Mockturtle Soup", published 1908 [ tenor ], from
#           <a href="/lieder/assemble_texts.html?SongCycleId=1040">
#            Nonsense Songs: The Songs That Came Out Wrong
#           </a>
#           , no. 6&amp;emsp13;
#           <a href="/lieder/status_info.html">
#            <span class="unverified" data-nosnippet="">
#             [sung text not yet checked]
#            </span>
#           </a>
#          </li>
#         </ul>
#         <p>
#         </p>
#         <p class="text-info">
#          Available translations, adaptations or excerpts, and transliterations (if applicable):
#         </p>
#         <ul>
#          <li>
#           <b class="tr">
#            FRE
#           </b>
#           <a href="/lieder/get_text.html?TextId=114865">
#            French (FranÃ§ais)
#           </a>
#           (Henri BuÃ©)  , no title
#          </li>
#         </ul>
#         <br/>
#         Researcher  for this page: Barbara Miller
#         <p>
#          This text was added to the website: 2004-04-27
#          <br/>
#          Line count:
#          <b>
#           16
#          </b>
#          <br/>
#          Word count:
#          <b>
#           70
#          </b>
#         </p>
#        </div>
#       </div>
#      </div>
#      <script src="/lieder/js/placard.js?v=2">
#      </script>
#      <script>
#       function toggleInterleaved() {
#         if (document.getElementById('text-table').classList.contains('combined-columns')) {
#             separate();
#         } else {
#             combine();
#         }
#     }
#
#     function combine() {
#         showFewer();
#         document.getElementById('text-table').classList.add('combined-columns');
#         document.getElementById('text-title').classList.add('interleaved');
#         document.getElementById('the-text').classList.add('interleaved');
#         document.getElementById('tr-title').classList.add('interleaved', 'interleaved-tr-title');
#         document.getElementById('the-tr').classList.add('interleaved', 'interleaved-tr');
#         document.getElementById('text-auth').classList.add('interleaved');
#         document.getElementById('tr-auth').classList.add('interleaved', 'interleaved-tr-auth');
#         document.getElementById('combine-columns').textContent = 'Show text and translation separately';
#     }
#
#     function separate() {
#         showMore();
#         document.getElementById('text-table').classList.remove('combined-columns');
#         document.getElementById('text-title').classList.remove('interleaved');
#         document.getElementById('the-text').classList.remove('interleaved');
#         document.getElementById('tr-title').classList.remove('interleaved','interleaved-tr-title');
#         document.getElementById('the-tr').classList.remove('interleaved', 'interleaved-tr');
#         document.getElementById('text-auth').classList.remove('interleaved');
#         document.getElementById('tr-auth').classList.remove('interleaved', 'interleaved-tr-auth');
#         document.getElementById('combine-columns').textContent = 'Show text and translation together';
#     }
#
#     function toggleDetails() {
#         if (document.getElementById('details-btn').textContent === 'Show fewer details') {
#             showFewer();
#         }
#         else {
#             if (document.getElementById('text-table').classList.contains('combined-columns')) {
#                 separate();
#             } else {
#                 showMore();
#             }
#         }
#     }
#
#     function showMore() {
#         var elements = document.getElementsByClassName('detail')
#         for (var i = 0; i < elements.length; i++) {
#         elements[i].style.display = '';
#         }
#         document.getElementById('text-auth').classList.remove('show');
#         document.getElementById('tr-auth').classList.remove('show');
#         document.getElementById('details-btn').textContent = 'Show fewer details';
#     }
#
#     function showFewer() {
#         var elements = document.getElementsByClassName('detail')
#         for (var i = 0; i < elements.length; i++) {
#         elements[i].style.display = 'none';
#         }
#         document.getElementById('text-auth').classList.add('show');
#         document.getElementById('tr-auth').classList.add('show');
#         document.getElementById('details-btn').textContent = 'Show more details';
#     }
#      </script>
#     </section>
#     <!-- / PRIMARY CONTENT AND ASSOCIATED ELEMENTS -->
#    </div>
#    <!-- /NAV + CONTENT -->
#   </main>
#   <!-- /MAIN -->
#   <!-- ANYTHING THAT FOLLOWS THE CONTENT -->
#   <aside id="after-the-content">
#    <div class="donations-card" id="donations-card">
#     <div class="donations-title">
#      Gentle Reminder
#     </div>
#     <p>
#      This website began in 1995 as a personal project by Emily Ezust, who has
# been working on it full-time without a salary since 2008. Our research has
# never had any government or institutional funding, so if you
#
# found
#
# the information here useful, please consider making a
# donation.
# Your help is greatly appreciated!
#      <br/>
#      –Emily Ezust, Founder
#     </p>
#     <div style="margin-left:auto;margin-right:auto">
#      <a class="donate-page-btn" href="/lieder/donate.html">
#       Donate
#      </a>
#     </div>
#    </div>
#    <script>
#     function showSometimes() {
#   var rnd = Math.random();
#     if (rnd < .2) {
#       document.getElementById('donations-card').style.display='block';
#   }
# }
#
# document.addEventListener('DOMContentLoaded', showSometimes);
#    </script>
#    <br/>
#   </aside>
#   <!-- /ANYTHING THAT FOLLOWS THE CONTENT -->
#   <div class="cookie-notice" id="cookie-notice">
#    <p class="cookie-msg">
#     We use cookies for internal analytics and to earn much-needed advertising revenue. (Did you know you can help support us by turning off ad-blockers?) To learn more, see our
#     <a href="/lieder/privacy_policy.html">
#      Privacy Policy
#     </a>
#     . To learn how to opt out of cookies, please visit
#     <a href="https://www.cookiesandyou.com/" target="_blank">
#      this site
#     </a>
#     .
#    </p>
#    <p class="cookie-btn" onclick="accept()">
#     I acknowledge the use of cookies
#    </p>
#   </div>
#   <!-- FOOTER -->
#   <footer class="footer">
#    <p>
#     <a href="/lieder/contact.html">
#      Contact
#     </a>
#     <br/>
#     <a href="/lieder/copyright.html">
#      Copyright
#     </a>
#     <br/>
#     <a href="/lieder/privacy_policy.html">
#      Privacy
#     </a>
#     <br/>
#    </p>
#    <p>
#     Copyright © 2024 The LiederNet Archive
#    </p>
#    <a href="https://www.thuris.com" id="design" target="_blank">
#     Site redesign by Shawn Thuris
#    </a>
#   </footer>
#   <!-- /FOOTER -->
#  </body>
# </html>
